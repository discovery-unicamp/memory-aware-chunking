# %% [markdown]
# # Benchmarking
#
# In this notebook, we are going to automatically extract data and evaluate all attributes, creating the model and testing it based on a given dataset.

# %% [markdown]
# ## Bootstraping

# %%
import json
import os
import sys
import warnings
from datetime import datetime

import dowser
import numpy as np
import pandas as pd
from dasf_seismic.datasets import F3
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split

warnings.filterwarnings("ignore", category=FutureWarning)

notebook_path = os.getcwd()
model_path = os.path.dirname(notebook_path)
memory_usage_path = os.path.join(model_path, 'memory_usage')
if memory_usage_path not in sys.path:
    sys.path.append(memory_usage_path)

from seismic.data.synthetic import generate_and_save_synthetic_data


def load_session(session_id):
    return json.load(open(f"../output/{session_id}/collected_data.json"))


def extract_features(df):
    df["volume"] = df["inlines"] * df["crosslines"] * df["samples"]

    return df


def load_data(session_id):
    collected_data = load_session(session_id)
    df = pd.DataFrame(collected_data['peaks'].items(), columns=['keys', 'memory_usage_kb'])
    df[['inlines', 'crosslines', 'samples']] = df['keys'].str.split('-', expand=True)
    df = df.drop(columns=['keys'])
    df = df.apply(pd.to_numeric)
    df = extract_features(df)

    return df


def calculate_accuracy(y_true, y_pred, tolerance=0.1):
    return np.mean(np.abs((y_true - y_pred) / y_true) <= tolerance)


def evaluate_model(model, X_train, y_train, cv):
    model.fit(X_train, y_train)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='neg_mean_squared_error')
    rmse_scores = np.sqrt(-scores)
    return rmse_scores.mean()


def train_model(df, cv=5, augmentation=3):
    df_augmented = pd.concat([df] * augmentation, ignore_index=True)
    X = df_augmented.drop(columns=["memory_usage_kb"])
    y = df_augmented["memory_usage_kb"]

    random_state = None  # 42
    test_size = 0.1
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    lin_reg = LinearRegression()
    lin_reg_rmse = evaluate_model(lin_reg, X_train, y_train, cv=cv)

    print(f"RMSE: {lin_reg_rmse}")

    y_pred = lin_reg.predict(X_test)

    lin_reg_acc = calculate_accuracy(y_test, y_pred)
    print(f"Accuracy: {lin_reg_acc * 100:.2f}%")

    return lin_reg


def get_peak_from_profile(profile) -> float:
    return max(profile["experiment"], key=lambda x: x["kernel_memory_usage"])[
        "kernel_memory_usage"
    ]


def validate_model(model, attribute, session_id, dataset_path, dataset_shape):
    target_df = pd.DataFrame([dataset_shape], columns=['inlines', 'crosslines', 'samples'])
    target_df = extract_features(target_df)
    expected_memory_usage = model.predict(target_df)[0]

    print(f"The expected memory usage is {expected_memory_usage:.2f} KB for the target shape {dataset_shape}")

    output_dir = f"../output/{session_id}/validation"

    dowser.load_config(
        {
            "output_dir": output_dir,
            ""
            "profiler": {
                "session_id": session_id,
                "precision": 1,
            },
        }
    )

    dowser.profile(attribute, dataset_path)

    validation_profile = dowser.profiler.load_profile(f"{output_dir}/{session_id}.prof")
    validation_peak_memory_usage = get_peak_from_profile(validation_profile)

    print(f"The actual peak memory usage of the validation dataset is {validation_peak_memory_usage} KB")

    validation_difference = abs(validation_peak_memory_usage - expected_memory_usage)
    validation_difference_in_mb = validation_difference / 1024
    validation_difference_in_pct = (validation_difference / expected_memory_usage) * 100

    print(f"The difference between the expected and actual peak memory usage is {validation_difference_in_mb:.2f} MB")
    print(f"This is a {validation_difference_in_pct:.2f}% difference")


def get_validation_dataset(small_validation, session_id):
    if small_validation:
        output_dir = f"../output/{session_id}/validation"
        small_shape = (325, 475, 231)
        small_dataset_path = generate_and_save_synthetic_data(*small_shape, output_dir=f"{output_dir}/experiment")

        return small_dataset_path, small_shape

    return F3()._root_file, F3().shape


def train_and_validate_session(session_id, attribute, small_validation):
    df_session = load_data(session_id)
    model_session = train_model(df_session)
    dataset_path, dataset_shape = get_validation_dataset(small_validation, session_id)
    validate_model(model_session, attribute, session_id, dataset_path, dataset_shape)

    return model_session


def generate_cube_shapes(max, min):
    return [
        (min, min, min),
        (min, min, max),
        (min, max, min),
        (max, min, min),
        (max, max, min),
        (max, min, max),
        (min, max, max),
        (max, max, max),
    ]


def create_datasets(output_dir, max, min):
    shapes = generate_cube_shapes(max, min)
    dataset_dir = f"{output_dir}/experiment"
    return [
        generate_and_save_synthetic_data(*shape, output_dir=dataset_dir)
        for shape in shapes
    ]


def dataset_shape_from_path(dataset_path: str) -> str:
    return dataset_path.split("/")[-1].split(".")[0]


def group_output_to_folder(folder: str) -> str:
    already_is_using_folder = dowser.context.config.output_dir.as_posix().endswith(
        folder
    )

    return (
        dowser.context.config.output_dir
        if already_is_using_folder
        else f"{dowser.context.config.output_dir}/{folder}"
    )


def profile_dataset(attribute, dataset_path):
    session_id = dataset_shape_from_path(dataset_path)
    output_dir = group_output_to_folder("profiles")

    dowser.load_config(
        {
            "output_dir": output_dir,
            "profiler": {
                "session_id": session_id,
            },
        }
    )
    dowser.profile(attribute, dataset_path)

    return f"{output_dir}/{session_id}.prof"


def read_profiles(profile_paths):
    return [
        dowser.profiler.load_profile(profile_path) for profile_path in profile_paths
    ]


def get_peak_from_profile(profile):
    return max(profile["experiment"], key=lambda x: x["kernel_memory_usage"])[
        "kernel_memory_usage"
    ]


def save_collected_data(profiles, output_dir):
    profiles = read_profiles(profiles)
    data = {
        "memory_unit": None,
        "peaks": {},
    }

    for profile in profiles:
        if data["memory_unit"] is None:
            data["memory_unit"] = profile["metadata"]["kernel_memory_usage_unit"]

        shape = dataset_shape_from_path(profile["metadata"]["entrypoint_segy_filepath"])

        peak = get_peak_from_profile(profile)
        data["peaks"][shape] = peak

    output_path = f"{output_dir}/collected_data.json"
    json.dump(data, open(output_path, "w"), indent=4, sort_keys=True)


def create_model(attribute_module, max=300, min=100, small_validation=False):
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    attribute_name = attribute_module.__name__.split('.')[-1]
    session_id = f"{attribute_name}-{timestamp}"
    output_dir = f"../output/{session_id}"

    dowser.load_config(
        {
            "output_dir": output_dir,
            "profiler": {
                "session_id": session_id,
                "precision": 1,
            },
        }
    )

    datasets = create_datasets(output_dir, max=max, min=min)
    profiles = [profile_dataset(attribute_module.run, dataset) for dataset in datasets]
    save_collected_data(profiles, output_dir)

    return train_and_validate_session(session_id, attribute_module.run, small_validation=small_validation)

# %% [markdown]
# ## Validating if it works

# %%
from seismic.attributes import envelope

envelope_model = create_model(envelope)
# Out:
# 2024-06-14 16:18:39.144 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (50, 50, 50)
# 2024-06-14 16:18:39.406 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (50, 50, 250)
# 2024-06-14 16:18:39.776 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (50, 250, 50)
# 2024-06-14 16:18:40.821 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (250, 50, 50)
# 2024-06-14 16:18:42.085 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (250, 250, 50)
# 2024-06-14 16:18:47.295 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (250, 50, 250)
# 2024-06-14 16:18:48.953 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (50, 250, 250)
# 2024-06-14 16:18:49.618 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (250, 250, 250)
# 2024-06-14 16:18:53.098 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:18:53.100 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:18:53.101 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:18:53.119 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:18:53.134 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:18:53.136 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:18:53.137 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:18:53.139 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:18:53.140 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:18:53.141 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:18:53.147 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:18:53.150 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:18:54.431 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:18:54.476 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:18:54.477 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:18:54.498 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:18:54.502 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:18:54.508 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:18:54.512 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:18:54.512 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:18:54.514 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:18:54.534 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:18:54.552 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:18:54.555 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:18:54.556 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:18:54.557 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:18:54.558 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:18:54.559 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:18:54.566 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:18:54.569 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:18:55.864 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:18:55.898 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:18:55.900 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:18:55.919 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:18:55.922 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:18:55.927 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:18:55.930 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:18:55.932 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:18:55.932 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:18:55.955 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:18:55.982 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:18:55.986 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:18:55.987 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:18:55.989 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:18:55.990 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:18:55.991 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:18:56.000 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:18:56.004 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:18:57.424 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:18:57.440 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:18:57.442 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:18:57.463 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:18:57.466 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:18:57.471 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:18:57.473 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:18:57.474 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:18:57.475 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:18:57.507 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:18:57.561 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:18:57.564 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:18:57.565 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:18:57.566 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:18:57.567 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:18:57.568 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:18:57.575 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:18:57.578 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:18:58.923 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:18:59.002 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:18:59.003 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:18:59.024 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:18:59.028 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:18:59.033 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:18:59.036 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:18:59.038 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:18:59.039 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:18:59.066 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:18:59.083 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:18:59.086 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:18:59.087 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:18:59.088 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:18:59.089 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:18:59.090 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:18:59.096 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:18:59.099 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:19:00.445 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:19:00.525 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:19:00.526 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:19:00.545 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:19:00.548 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:19:00.552 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:19:00.555 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:19:00.556 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:19:00.557 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:19:00.585 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:19:00.612 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:19:00.617 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:19:00.618 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:19:00.621 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:19:00.623 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:19:00.624 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:19:00.637 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:19:00.641 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:19:02.079 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:19:02.174 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:19:02.176 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:19:02.199 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:19:02.202 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:19:02.207 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:19:02.209 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:19:02.210 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:19:02.211 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:19:02.233 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:19:02.252 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:19:02.256 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:19:02.257 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:19:02.258 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:19:02.259 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:19:02.260 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:19:02.265 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:19:02.268 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:19:03.677 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:19:03.700 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:19:03.701 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:19:03.720 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:19:03.724 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:19:03.731 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# 2024-06-14 16:19:03.734 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:19:03.735 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:19:03.736 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:19:03.763 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:19:03.786 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:19:03.789 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:19:03.790 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:19:03.792 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:19:03.793 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:19:03.794 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:19:03.800 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:19:03.803 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:19:05.353 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:19:05.442 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:19:05.443 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:19:05.463 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:19:05.466 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:19:05.471 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/profiles
# RMSE: 30529.408558327967
# Accuracy: 100.00%
# The expected memory usage is 9567241.91 KB for the target shape (651, 951, 462)
# 2024-06-14 16:19:05.563 | INFO     | dowser.profiler.main:run_profiler:15 - Starting profiler
# 2024-06-14 16:19:05.564 | INFO     | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-06-14 16:19:05.565 | WARNING  | dowser.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-06-14 16:19:05.582 | INFO     | dowser.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-06-14 16:19:05.594 | INFO     | dowser.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-06-14 16:19:05.598 | INFO     | dowser.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-06-14 16:19:05.599 | INFO     | dowser.profiler.handlers:execute_file:42 - Compiling code
# 2024-06-14 16:19:05.600 | INFO     | dowser.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-06-14 16:19:05.602 | INFO     | dowser.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-06-14 16:19:05.602 | INFO     | dowser.profiler.tracer:start_sampler:152 - Using precision of 0.1s and process strategy
# 2024-06-14 16:19:05.609 | INFO     | dowser.profiler.handlers:execute_file:48 - Executing code file
# 2024-06-14 16:19:05.612 | INFO     | dowser.profiler.handlers:execute_file:52 - Running function: run
# 2024-06-14 16:19:11.726 | INFO     | dowser.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-06-14 16:19:11.790 | INFO     | dowser.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-06-14 16:19:11.792 | INFO     | dowser.profiler.handlers:execute_file:59 - File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-06-14 16:19:11.817 | INFO     | dowser.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-06-14 16:19:11.821 | INFO     | dowser.profiler.main:run_profiler:52 - Saving profile data
# 2024-06-14 16:19:11.837 | INFO     | dowser.profiler.main:run_profiler:66 - Profiler output saved to: ../output/envelope-20240614-161839/validation
# The actual peak memory usage of the validation dataset is 8446620.0 KB
# The difference between the expected and actual peak memory usage is 1094.36 MB
# This is a 11.71% difference

# %% [markdown]
# ## Testing for all attributes

# %%
import importlib
from pathlib import Path

dowser.load_config(
    {
        "logger": {
            "level": "ERROR"
        },
    }
)

attributes_path = Path('../../../tools/seismic/seismic/attributes')
attribute_names = sorted([f.name.split('.')[0] for f in attributes_path.iterdir() if f.is_file()])[1:]
custom_kwargs = {
    "gst_3d_dip": {
        "small_validation": True
    },
}

attributes_hashmap = [
    {"attribute_name": attribute_name, "kwargs": custom_kwargs.get(attribute_name, {})} for attribute_name in
    attribute_names
]

for data in attributes_hashmap:
    module = importlib.import_module(f"seismic.attributes.{data['attribute_name']}")
    kwargs = data["kwargs"]

    print(f"Modeling for attribute {module.__name__}")
    create_model(module, **kwargs)
    print("---")
# Out:
# Modeling for attribute seismic.attributes.apparent_polarity
# RMSE: 9515.437453395853
# Accuracy: 100.00%
# The expected memory usage is 6773667.93 KB for the target shape (651, 951, 462)
# The actual peak memory usage of the validation dataset is 8403088.0 KB
# The difference between the expected and actual peak memory usage is 1591.23 MB
# This is a 24.06% difference
# ---
# Modeling for attribute seismic.attributes.chaos
# RMSE: 18490.283497960107
# Accuracy: 100.00%
# The expected memory usage is 45077765.73 KB for the target shape (651, 951, 462)
# 2024-06-14 16:36:02.190 | ERROR    | dowser.common.synchronization:do_many:67 - Error executing function: list index out of range
# 2024-06-14 16:36:02.428 | ERROR    | dowser.common.synchronization:do_many:67 - Error executing function: list index out of range
# 2024-06-14 16:36:02.533 | ERROR    | dowser.common.synchronization:do_many:67 - Error executing function: [Errno 3] No such process
# 2024-06-14 16:36:02.637 | ERROR    | dowser.common.synchronization:do_many:67 - Error executing function: [Errno 3] No such process
# 2024-06-14 16:36:02.745 | ERROR    | dowser.common.synchronization:do_many:67 - Error executing function: [Errno 3] No such process
# Process Process-324:1:
# Traceback (most recent call last):
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/managers.py", line 1104, in is_set
#     return self._callmethod('is_set')
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/delucca/src/msc/seismic-attributes-memory-profile/tools/dowser/dowser/profiler/tracer.py", line 172, in sampler
#     while not self.__sampler_finished.is_set():
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/managers.py", line 834, in _callmethod
#     conn.send((self._id, methodname, args, kwds))
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/connection.py", line 206, in send
#     self._send_bytes(_ForkingPickler.dumps(obj))
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
#     self._send(header + buf)
#   File "/home/delucca/.pyenv/versions/3.8.10/lib/python3.8/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# The actual peak memory usage of the validation dataset is 15220100.0 KB
# The difference between the expected and actual peak memory usage is 29157.88 MB
# This is a 66.24% difference
# ---
# Modeling for attribute seismic.attributes.convolution
# RMSE: 10986.734335842153
# Accuracy: 100.00%
# The expected memory usage is 3133879.05 KB for the target shape (651, 951, 462)
# The actual peak memory usage of the validation dataset is 3080800.0 KB
# The difference between the expected and actual peak memory usage is 51.84 MB
# This is a 1.69% difference
# ---
# Modeling for attribute seismic.attributes.cosine_instantaneous_phase
# RMSE: 42252.899042516394
# Accuracy: 33.33%
# The expected memory usage is 9832613.67 KB for the target shape (651, 951, 462)
# The actual peak memory usage of the validation dataset is 8297668.0 KB
# The difference between the expected and actual peak memory usage is 1498.97 MB
# This is a 15.61% difference
# ---
# Modeling for attribute seismic.attributes.dominant_frequency
# RMSE: 10814.996284306693
# Accuracy: 100.00%
# The expected memory usage is 9124714.49 KB for the target shape (651, 951, 462)
# /home/delucca/.pyenv/versions/3.8.10/envs/seismic-attributes-memory-profile/lib/python3.8/site-packages/dasf_seismic/attributes/complex_trace.py:182: RuntimeWarning: divide by zero encountered in divide
#   result = env_prime / env
# /home/delucca/.pyenv/versions/3.8.10/envs/seismic-attributes-memory-profile/lib/python3.8/site-packages/dasf_seismic/attributes/complex_trace.py:182: RuntimeWarning: invalid value encountered in divide
#   result = env_prime / env
# The actual peak memory usage of the validation dataset is 9492164.0 KB
# The difference between the expected and actual peak memory usage is 358.84 MB
# This is a 4.03% difference
# ---
# Modeling for attribute seismic.attributes.eig_complex
