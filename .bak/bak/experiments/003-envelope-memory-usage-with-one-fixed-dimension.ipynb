# %% [markdown]
# # Envelope Memory Usage with a One Fixed Dimension
#
# This experiment aims to evaluate the memory usage of the envelope seismic attribute operator with one fixed dimension.
# On this notebook you will find:
# - The problem statement
# - The data collection for the experiment
# - The evaluation of the experiment results.

# %% [markdown]
# ## Problem Statement
#
# Following [experiment 002](./002-envelope-memory-usage-with-two-fixed-dimensions.ipynb), the goal for this experiment is to evaluate how the Envelope attribute behaves when keeping only a single dimension fixed.
# During the experiment, we plan to:
#
# 1. Generate synthetic seismic data.
# 2. Apply the envelope operator to the synthetic data using the [DASF](https://github.com/discovery-unicamp/dasf-core) framework.
# 3. Assess the memory usage during this process using [TraceQ](https://github.com/discovery-unicamp/traceq).

# %% [markdown]
# ## Data Collection
#
# In this section, we will outline the steps needed to collect the necessary data for our experiment. The process is organized into the following steps:
#
# 1. **Setup Environment:**
#   - Set up the environment with proper env variables and global constants to use during the experiment.
#
# 2. **Setup Dependencies:**
#   - Set up the virtual environment running this notebook with the required dependencies.
#
# 3. **Setup the output directory:**
#   - On this step we will setup the output directory in which we will save the experiment results.
#
# 4. **Generate Synthetic Seismic Data:**
#   - Generate synthetic seismic data within a specified range of dimensions.
#
# 5. **Execute the Envelope Operator:**
#   - Apply the envelope operator to the synthetic data using the prepared environment and tools.
#
# After completing these steps, we will have the data generated by TraceQ to evaluate the memory usage of the envelope operator.

# %% [markdown]
# ### Setup Environment
#
# During the environment setup, we need to:
# - Proper configure `PYTHONPATH`
# - Setup dependencies
#
# Below, we're configuring the `PYTHONPATH` to allow using the tools we've coded for the experiments

# %%
import os
import sys

seismic_path = os.path.abspath('../tools/seismic')
traceq_path = os.path.abspath('../tools/traceq')

if seismic_path not in sys.path:
    sys.path.append(seismic_path)

if traceq_path not in sys.path:
    sys.path.append(traceq_path)

print(sys.path)
# Out:
# ['/home/delucca/.pyenv/versions/3.10.14/lib/python310.zip', '/home/delucca/.pyenv/versions/3.10.14/lib/python3.10', '/home/delucca/.pyenv/versions/3.10.14/lib/python3.10/lib-dynload', '', '/home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages', '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic', '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq']

# %% [markdown]
# Now, lets setup some relevant global variables

# %%
from pprint import pprint

LOG_TRANSPORTS = ['CONSOLE', 'FILE']
LOG_LEVEL = 'DEBUG'

NUM_INLINES = 200
NUM_XLINES = 200
NUM_SAMPLES = 200
STEP_SIZE = 100
RANGE_SIZE = 15

print('Experiment config:')
pprint({
    'LOG_TRANSPORTS': LOG_TRANSPORTS,
    'LOG_LEVEL': LOG_LEVEL,
    'NUM_INLINES': NUM_INLINES,
    'NUM_XLINES': NUM_XLINES,
    'NUM_SAMPLES': NUM_SAMPLES,
    'STEP_SIZE': STEP_SIZE,
    'RANGE_SIZE': RANGE_SIZE
}, indent=2, sort_dicts=True)
# Out:
# Experiment config:
# { 'LOG_LEVEL': 'DEBUG',
#   'LOG_TRANSPORTS': ['CONSOLE', 'FILE'],
#   'NUM_INLINES': 200,
#   'NUM_SAMPLES': 200,
#   'NUM_XLINES': 200,
#   'RANGE_SIZE': 15,
#   'STEP_SIZE': 100}

# %% [markdown]
# ### Setup Dependencies
#
# Before running this step, make sure you are running this notebook in the environment defined by the `.python-version` file.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We need to install DASF tools to execute the experiment

# %%
# %pip install git+https://github.com/discovery-unicamp/dasf-core.git
# Out:
# Collecting git+https://github.com/discovery-unicamp/dasf-core.git
#   Cloning https://github.com/discovery-unicamp/dasf-core.git to /tmp/pip-req-build-ilcdjksp
#   Running command git clone --filter=blob:none --quiet https://github.com/discovery-unicamp/dasf-core.git /tmp/pip-req-build-ilcdjksp
#   Resolved https://github.com/discovery-unicamp/dasf-core.git to commit c4841cdeb92f596b0c011fe0480897731556c2dd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting xpysom-dask@ git+https://github.com/jcfaracco/xpysom-dask#egg=master (from dasf==1.0b6)
#   Cloning https://github.com/jcfaracco/xpysom-dask to /tmp/pip-install-wmcgplnu/xpysom-dask_06244f90655d4ddf8f00eec7e5a36c75
#   Running command git clone --filter=blob:none --quiet https://github.com/jcfaracco/xpysom-dask /tmp/pip-install-wmcgplnu/xpysom-dask_06244f90655d4ddf8f00eec7e5a36c75
#   Resolved https://github.com/jcfaracco/xpysom-dask to commit c21d10b09f68d89663e2e967bdb5781f76a96b13
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: GPUtil==1.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.4.0)
# Requirement already satisfied: bokeh==2.4.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.4.3)
# Requirement already satisfied: charset-normalizer<3.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.1.1)
# Requirement already satisfied: dask==2023.3.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.3.2)
# Requirement already satisfied: dask_cuda==23.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (23.4.0)
# Requirement already satisfied: dask_jobqueue==0.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.8.2)
# Requirement already satisfied: dask_memusage<2.0,>=1.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.1)
# Requirement already satisfied: dask_ml==2023.3.24 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.3.24)
# Requirement already satisfied: gdown<5.0,>=4.6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (4.7.3)
# Requirement already satisfied: graphviz==0.20.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.20.1)
# Requirement already satisfied: h5py==3.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.10.0)
# Requirement already satisfied: hdbscan==0.8.33 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.8.33)
# Requirement already satisfied: ipympl==0.9.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (0.9.3)
# Requirement already satisfied: joblib==1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.2.0)
# Requirement already satisfied: matplotlib==3.7.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.7.1)
# Requirement already satisfied: memray==1.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.10.0)
# Requirement already satisfied: networkx==3.2.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.2.1)
# Requirement already satisfied: numpy==1.23.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.23.5)
# Requirement already satisfied: ormsgpack==1.4.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.4.1)
# Requirement already satisfied: packaging==23.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (23.1)
# Requirement already satisfied: pandas==1.5.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.5.2)
# Requirement already satisfied: portalocker==2.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.8.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (3.20.1)
# Requirement already satisfied: psutil==5.9.4 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (5.9.4)
# Requirement already satisfied: pyarrow<15.0.0,>=14.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (14.0.2)
# Requirement already satisfied: scikit-learn==1.5.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=6.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (6.4.1)
# Requirement already satisfied: xarray==2023.11.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2023.11.0)
# Requirement already satisfied: xgboost==1.7.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (1.7.5)
# Requirement already satisfied: zarr==2.16.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf==1.0b6) (2.16.1)
# Requirement already satisfied: Jinja2>=2.9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (3.1.4)
# Requirement already satisfied: pillow>=7.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf==1.0b6) (4.12.2)
# Requirement already satisfied: click>=7.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (2024.9.0)
# Requirement already satisfied: partd>=1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask==2023.3.2->dasf==1.0b6) (8.4.0)
# Requirement already satisfied: distributed==2023.3.2.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (2023.3.2.1)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (11.4.1)
# Requirement already satisfied: numba>=0.54 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (0.60.0)
# Requirement already satisfied: zict>=0.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: scipy in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (1.10.1)
# Requirement already satisfied: dask-glm>=0.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (0.3.2)
# Requirement already satisfied: multipledispatch>=0.4.9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf==1.0b6) (1.0.0)
# Requirement already satisfied: cython<3,>=0.27 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from hdbscan==0.8.33->dasf==1.0b6) (0.29.37)
# Requirement already satisfied: ipython<9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (8.27.0)
# Requirement already satisfied: ipython-genutils in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (0.2.0)
# Requirement already satisfied: traitlets<6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf==1.0b6) (8.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib==3.7.1->dasf==1.0b6) (2.9.0.post0)
# Requirement already satisfied: rich>=11.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from memray==1.10.0->dasf==1.0b6) (13.8.0)
# Requirement already satisfied: pytz>=2020.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas==1.5.2->dasf==1.0b6) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-learn==1.5.1->dasf==1.0b6) (3.5.0)
# Requirement already satisfied: asciitree in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.3.3)
# Requirement already satisfied: fasteners in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr==2.16.1->dasf==1.0b6) (0.13.0)
# Requirement already satisfied: locket>=1.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (1.0.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed==2023.3.2.1->dask_cuda==23.4.0->dasf==1.0b6) (2.2.2)
# Requirement already satisfied: filelock in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (3.16.0)
# Requirement already satisfied: requests[socks] in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (2.32.3)
# Requirement already satisfied: six in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (1.16.0)
# Requirement already satisfied: tqdm in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (4.66.5)
# Requirement already satisfied: beautifulsoup4 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf==1.0b6) (4.12.3)
# Requirement already satisfied: sparse>=0.7.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask-glm>=0.2.0->dask_ml==2023.3.24->dasf==1.0b6) (0.15.4)
# Requirement already satisfied: zipp>=0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask==2023.3.2->dasf==1.0b6) (3.20.1)
# Requirement already satisfied: decorator in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.18.0)
# Requirement already satisfied: stack-data in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf==1.0b6) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf==1.0b6) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh==2.4.3->dasf==1.0b6) (2.1.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from numba>=0.54->dask_cuda==23.4.0->dasf==1.0b6) (0.43.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from rich>=11.2.0->memray==1.10.0->dasf==1.0b6) (3.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from beautifulsoup4->gdown<5.0,>=4.6->dasf==1.0b6) (2.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf==1.0b6) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray==1.10.0->dasf==1.0b6) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.7.0)
# Requirement already satisfied: wcwidth in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (2.4.1)
# Requirement already satisfied: pure-eval in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf==1.0b6) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, we need to install a package that is private.
# In order to do this, you can either use the HTTPS or SSH protocol.
#
# In the next cell you can install with the protocol you prefer, just uncomment the one you want to use.

# %%
# %pip install git+ssh://git@github.com/discovery-unicamp/dasf-seismic.git ### Using SSH
# %pip install git+https://<token>@github.com/discovery-unicamp/dasf-seismic.git ### Using HTTPS -> Don't forget to replate <token> with your own PAT

# %pip install torch
# Out:
# Collecting git+ssh://****@github.com/discovery-unicamp/dasf-seismic.git
#   Cloning ssh://****@github.com/discovery-unicamp/dasf-seismic.git to /tmp/pip-req-build-t20e2hoj
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/discovery-unicamp/dasf-seismic.git' /tmp/pip-req-build-t20e2hoj
#   Resolved ssh://****@github.com/discovery-unicamp/dasf-seismic.git to commit 8037f403f79dd2a628a6d0d14543ead670eb01d4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main (from dasf-seismic==1.0b5)
#   Cloning https://github.com/discovery-unicamp/dasf-core.git (to revision main) to /tmp/pip-install-j93_2dp5/dasf_c98e6bbd88714f92aa10bb113e5fff1a
#   Running command git clone --filter=blob:none --quiet https://github.com/discovery-unicamp/dasf-core.git /tmp/pip-install-j93_2dp5/dasf_c98e6bbd88714f92aa10bb113e5fff1a
#   Resolved https://github.com/discovery-unicamp/dasf-core.git to commit c4841cdeb92f596b0c011fe0480897731556c2dd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting glcm-cupy@ git+https://github.com/SerodioJ/glcm-cupy.git@stable (from dasf-seismic==1.0b5)
#   Cloning https://github.com/SerodioJ/glcm-cupy.git (to revision stable) to /tmp/pip-install-j93_2dp5/glcm-cupy_91c22f8ac9b44897bcc869ea9468ae36
#   Running command git clone --filter=blob:none --quiet https://github.com/SerodioJ/glcm-cupy.git /tmp/pip-install-j93_2dp5/glcm-cupy_91c22f8ac9b44897bcc869ea9468ae36
#   Running command git checkout -b stable --track origin/stable
#   Switched to a new branch 'stable'
#   branch 'stable' set up to track 'origin/stable'.
#   Resolved https://github.com/SerodioJ/glcm-cupy.git to commit 0c42b921002612712c3f830644bfc0fd9725484c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: multidimio==0.4.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf-seismic==1.0b5) (0.4.2)
# Requirement already satisfied: scikit-image==0.22.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf-seismic==1.0b5) (0.22.0)
# Requirement already satisfied: segyio==1.9.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf-seismic==1.0b5) (1.9.12)
# Requirement already satisfied: segysak==0.4 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf-seismic==1.0b5) (0.4)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (8.1.7)
# Requirement already satisfied: click-params<0.5.0,>=0.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (0.4.1)
# Requirement already satisfied: dask>=2022.11.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (2023.3.2)
# Requirement already satisfied: numba<1.0.0,>=0.55.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (0.60.0)
# Requirement already satisfied: psutil<6.0.0,>=5.9.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (5.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (4.66.5)
# Requirement already satisfied: zarr<3.0.0,>=2.12.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from multidimio==0.4.2->dasf-seismic==1.0b5) (2.16.1)
# Requirement already satisfied: numpy>=1.22 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (1.23.5)
# Requirement already satisfied: scipy>=1.8 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (10.4.0)
# Requirement already satisfied: imageio>=2.27 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-image==0.22.0->dasf-seismic==1.0b5) (0.4)
# Requirement already satisfied: pandas in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (1.5.2)
# Requirement already satisfied: matplotlib in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (3.7.1)
# Requirement already satisfied: xarray in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (2023.11.0)
# Requirement already satisfied: distributed in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (2023.3.2.1)
# Requirement already satisfied: pyzgy in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (0.0.9)
# Requirement already satisfied: h5netcdf in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (1.3.0)
# Requirement already satisfied: addict in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (2.4.0)
# Requirement already satisfied: more-itertools>=8.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (10.5.0)
# Requirement already satisfied: setuptools-scm in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segysak==0.4->dasf-seismic==1.0b5) (8.1.0)
# Collecting xpysom-dask@ git+https://github.com/jcfaracco/xpysom-dask#egg=master (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5)
#   Cloning https://github.com/jcfaracco/xpysom-dask to /tmp/pip-install-j93_2dp5/xpysom-dask_f69d3cbe7fea41e4960d2773b6499fc6
#   Running command git clone --filter=blob:none --quiet https://github.com/jcfaracco/xpysom-dask /tmp/pip-install-j93_2dp5/xpysom-dask_f69d3cbe7fea41e4960d2773b6499fc6
#   Resolved https://github.com/jcfaracco/xpysom-dask to commit c21d10b09f68d89663e2e967bdb5781f76a96b13
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: GPUtil==1.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.4.0)
# Requirement already satisfied: bokeh==2.4.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.4.3)
# Requirement already satisfied: charset-normalizer<3.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.1.1)
# Requirement already satisfied: dask_cuda==23.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (23.4.0)
# Requirement already satisfied: dask_jobqueue==0.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.2)
# Requirement already satisfied: dask_memusage<2.0,>=1.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.1)
# Requirement already satisfied: dask_ml==2023.3.24 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2023.3.24)
# Requirement already satisfied: gdown<5.0,>=4.6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.7.3)
# Requirement already satisfied: graphviz==0.20.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.20.1)
# Requirement already satisfied: h5py==3.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.10.0)
# Requirement already satisfied: hdbscan==0.8.33 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.33)
# Requirement already satisfied: ipympl==0.9.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.9.3)
# Requirement already satisfied: joblib==1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.2.0)
# Requirement already satisfied: memray==1.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.10.0)
# Requirement already satisfied: ormsgpack==1.4.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.4.1)
# Requirement already satisfied: portalocker==2.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.8.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.20.1)
# Requirement already satisfied: pyarrow<15.0.0,>=14.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (14.0.2)
# Requirement already satisfied: scikit-learn==1.5.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=6.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (6.4.1)
# Requirement already satisfied: xgboost==1.7.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.7.5)
# Requirement already satisfied: Jinja2>=2.9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.12.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (2024.9.0)
# Requirement already satisfied: partd>=1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (1.4.2)
# Requirement already satisfied: toolz>=0.8.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (8.4.0)
# Requirement already satisfied: pynvml<11.5,>=11.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (11.4.1)
# Requirement already satisfied: zict>=0.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_cuda==23.4.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: dask-glm>=0.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.3.2)
# Requirement already satisfied: multipledispatch>=0.4.9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.0.0)
# Requirement already satisfied: locket>=1.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (1.0.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: urllib3>=1.24.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from distributed->segysak==0.4->dasf-seismic==1.0b5) (2.2.2)
# Requirement already satisfied: cython<3,>=0.27 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from hdbscan==0.8.33->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.29.37)
# Requirement already satisfied: ipython<9 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (8.27.0)
# Requirement already satisfied: ipython-genutils in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.0)
# Requirement already satisfied: traitlets<6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (5.14.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (8.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from matplotlib->segysak==0.4->dasf-seismic==1.0b5) (2.9.0.post0)
# Requirement already satisfied: rich>=11.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (13.8.0)
# Requirement already satisfied: pytz>=2020.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas->segysak==0.4->dasf-seismic==1.0b5) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from scikit-learn==1.5.1->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.5.0)
# Requirement already satisfied: asciitree in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.3.3)
# Requirement already satisfied: fasteners in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.19)
# Requirement already satisfied: numcodecs>=0.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from zarr<3.0.0,>=2.12.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.13.0)
# Requirement already satisfied: validators<0.21,>=0.20 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from click-params<0.5.0,>=0.4.0->multidimio==0.4.2->dasf-seismic==1.0b5) (0.20.0)
# Requirement already satisfied: filelock in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.16.0)
# Requirement already satisfied: requests[socks] in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.32.3)
# Requirement already satisfied: six in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.12.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from numba<1.0.0,>=0.55.2->multidimio==0.4.2->dasf-seismic==1.0b5) (0.43.0)
# Requirement already satisfied: setuptools in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from setuptools-scm->segysak==0.4->dasf-seismic==1.0b5) (65.5.0)
# Requirement already satisfied: tomli>=1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from setuptools-scm->segysak==0.4->dasf-seismic==1.0b5) (2.0.1)
# Requirement already satisfied: sparse>=0.7.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dask-glm>=0.2.0->dask_ml==2023.3.24->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.15.4)
# Requirement already satisfied: zipp>=0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask>=2022.11.0->multidimio==0.4.2->dasf-seismic==1.0b5) (3.20.1)
# Requirement already satisfied: decorator in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.18.0)
# Requirement already satisfied: stack-data in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh==2.4.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from rich>=11.2.0->memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.0.0)
# Requirement already satisfied: soupsieve>1.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from beautifulsoup4->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests[socks]->gdown<5.0,>=4.6->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray==1.10.0->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (2.4.1)
# Requirement already satisfied: pure-eval in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl==0.9.3->dasf@ git+https://github.com/discovery-unicamp/dasf-core.git@main->dasf-seismic==1.0b5) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: filelock in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now, we need to install the dependencies for the tools we use during the experiment.

# %%
# %pip install -r ../tools/seismic/requirements.txt
# %pip install -r ../tools/traceq/requirements.txt
# Out:
# Requirement already satisfied: segyio==1.9.12 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/seismic/requirements.txt (line 1)) (1.9.12)
# Requirement already satisfied: scipy==1.10.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/seismic/requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: numpy>=1.10 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from segyio==1.9.12->-r ../tools/seismic/requirements.txt (line 1)) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: toml==0.10.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: toolz==0.12.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: loguru==0.7.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: pydantic==2.7.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 4)) (2.7.1)
# Requirement already satisfied: pandas==1.5.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: plotly==5.22.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 6)) (5.22.0)
# Requirement already satisfied: plotly-resampler==0.10.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: kaleido==0.2.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: msgpack==1.0.8 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from -r ../tools/traceq/requirements.txt (line 9)) (1.0.8)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pydantic==2.7.1->-r ../tools/traceq/requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pydantic==2.7.1->-r ../tools/traceq/requirements.txt (line 4)) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pydantic==2.7.1->-r ../tools/traceq/requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas==1.5.2->-r ../tools/traceq/requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas==1.5.2->-r ../tools/traceq/requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from pandas==1.5.2->-r ../tools/traceq/requirements.txt (line 5)) (1.23.5)
# Requirement already satisfied: tenacity>=6.2.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from plotly==5.22.0->-r ../tools/traceq/requirements.txt (line 6)) (9.0.0)
# Requirement already satisfied: packaging in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from plotly==5.22.0->-r ../tools/traceq/requirements.txt (line 6)) (23.1)
# Requirement already satisfied: dash>=2.9.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: importlib-metadata in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: requests in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: retrying in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (1.3.4)
# Requirement already satisfied: nest-asyncio in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: setuptools in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (65.5.0)
# Requirement already satisfied: six>=1.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas==1.5.2->-r ../tools/traceq/requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from Werkzeug<3.1->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from importlib-metadata->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/delucca/.pyenv/versions/3.10.14/envs/seismic-attributes-memory-profile/lib/python3.10/site-packages (from requests->dash>=2.9.0->plotly-resampler==0.10.0->-r ../tools/traceq/requirements.txt (line 7)) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Setup output directory

# %%
import uuid
import os

from datetime import datetime

EXPERIMENT_ID = f'003-{datetime.now().strftime("%Y%m%d%H%M%S")}-{uuid.uuid4().hex[:6]}'
OUTPUT_DIR = f'../output/{EXPERIMENT_ID}'

os.makedirs(OUTPUT_DIR)

OUTPUT_DIR
# Out:
# '../output/003-20240910224723-191b1c'

# %% [markdown]
# ### Generate synthetic data

# %%
from seismic.data.synthetic import generate_and_save_for_range

DATA_OUTPUT_DIR = f'{OUTPUT_DIR}/experiment'

synthetic_data_paths = generate_and_save_for_range(
    NUM_INLINES,
    NUM_XLINES,
    NUM_SAMPLES,
    STEP_SIZE,
    RANGE_SIZE,
    output_dir=DATA_OUTPUT_DIR,
)

print(synthetic_data_paths)
# Out:
# 2024-09-10 22:47:23.985 | INFO     | seismic.data.synthetic:generate_and_save_for_range:60 - Generating synthetic data with the following parameters:
# 2024-09-10 22:47:23.986 | INFO     | seismic.data.synthetic:generate_and_save_for_range:61 - Number of inlines: 200
# 2024-09-10 22:47:23.987 | INFO     | seismic.data.synthetic:generate_and_save_for_range:62 - Number of crosslines: 200
# 2024-09-10 22:47:23.987 | INFO     | seismic.data.synthetic:generate_and_save_for_range:63 - Number of samples: 200
# 2024-09-10 22:47:23.988 | INFO     | seismic.data.synthetic:generate_and_save_for_range:64 - Step size: 100
# 2024-09-10 22:47:23.988 | INFO     | seismic.data.synthetic:generate_and_save_for_range:65 - Range size: 15
# 2024-09-10 22:47:23.989 | INFO     | seismic.data.synthetic:generate_and_save_for_range:66 - Output directory: ../output/003-20240910224723-191b1c/data
# 2024-09-10 22:47:23.991 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (100, 200, 200)
# 2024-09-10 22:47:25.756 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 200, 200)
# 2024-09-10 22:47:29.271 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (300, 200, 200)
# 2024-09-10 22:47:34.638 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (400, 200, 200)
# 2024-09-10 22:47:41.753 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (500, 200, 200)
# 2024-09-10 22:47:50.543 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (600, 200, 200)
# 2024-09-10 22:48:01.008 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (700, 200, 200)
# 2024-09-10 22:48:13.666 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (800, 200, 200)
# 2024-09-10 22:48:27.883 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (900, 200, 200)
# 2024-09-10 22:48:43.858 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1000, 200, 200)
# 2024-09-10 22:49:02.194 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1100, 200, 200)
# 2024-09-10 22:49:21.837 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1200, 200, 200)
# 2024-09-10 22:49:43.758 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1300, 200, 200)
# 2024-09-10 22:50:07.532 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1400, 200, 200)
# 2024-09-10 22:50:32.693 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (1500, 200, 200)
# 2024-09-10 22:51:00.181 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 100, 200)
# 2024-09-10 22:51:02.275 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 300, 200)
# 2024-09-10 22:51:07.410 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 400, 200)
# 2024-09-10 22:51:13.908 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 500, 200)
# 2024-09-10 22:51:22.000 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 600, 200)
# 2024-09-10 22:51:31.647 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 700, 200)
# 2024-09-10 22:51:42.893 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 800, 200)
# 2024-09-10 22:51:55.833 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 900, 200)
# 2024-09-10 22:52:10.071 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1000, 200)
# 2024-09-10 22:52:25.747 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1100, 200)
# 2024-09-10 22:52:43.399 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1200, 200)
# 2024-09-10 22:53:02.210 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1300, 200)
# 2024-09-10 22:53:22.668 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1400, 200)
# 2024-09-10 22:53:44.437 | INFO     | seismic.data.synthetic:generate_and_save_synthetic_data:130 - Generating synthetic data for shape (200, 1500, 200)
# ['../output/003-20240910224723-191b1c/data/100-200-200.segy', '../output/003-20240910224723-191b1c/data/200-200-200.segy', '../output/003-20240910224723-191b1c/data/300-200-200.segy', '../output/003-20240910224723-191b1c/data/400-200-200.segy', '../output/003-20240910224723-191b1c/data/500-200-200.segy', '../output/003-20240910224723-191b1c/data/600-200-200.segy', '../output/003-20240910224723-191b1c/data/700-200-200.segy', '../output/003-20240910224723-191b1c/data/800-200-200.segy', '../output/003-20240910224723-191b1c/data/900-200-200.segy', '../output/003-20240910224723-191b1c/data/1000-200-200.segy', '../output/003-20240910224723-191b1c/data/1100-200-200.segy', '../output/003-20240910224723-191b1c/data/1200-200-200.segy', '../output/003-20240910224723-191b1c/data/1300-200-200.segy', '../output/003-20240910224723-191b1c/data/1400-200-200.segy', '../output/003-20240910224723-191b1c/data/1500-200-200.segy', '../output/003-20240910224723-191b1c/data/200-100-200.segy', '../output/003-20240910224723-191b1c/data/200-200-200.segy', '../output/003-20240910224723-191b1c/data/200-300-200.segy', '../output/003-20240910224723-191b1c/data/200-400-200.segy', '../output/003-20240910224723-191b1c/data/200-500-200.segy', '../output/003-20240910224723-191b1c/data/200-600-200.segy', '../output/003-20240910224723-191b1c/data/200-700-200.segy', '../output/003-20240910224723-191b1c/data/200-800-200.segy', '../output/003-20240910224723-191b1c/data/200-900-200.segy', '../output/003-20240910224723-191b1c/data/200-1000-200.segy', '../output/003-20240910224723-191b1c/data/200-1100-200.segy', '../output/003-20240910224723-191b1c/data/200-1200-200.segy', '../output/003-20240910224723-191b1c/data/200-1300-200.segy', '../output/003-20240910224723-191b1c/data/200-1400-200.segy', '../output/003-20240910224723-191b1c/data/200-1500-200.segy']

# %% [markdown]
# ### Execute the envelope attribute
#
# On this step, we will execute the attribute for each generated synthetic data

# %%
import traceq

from seismic.attributes import envelope

for synthetic_data_path in synthetic_data_paths:
    shape = synthetic_data_path.split('/')[-1].split('.')[0]
    traceq.load_config(
        {
            "output_dir": f'{OUTPUT_DIR}/profile-{shape}',
            "logger": {
                "enabled_transports": LOG_TRANSPORTS,
                "level": LOG_LEVEL,
            },
            "profiler": {
                "session_id": shape,
                "memory_usage": {
                    "enabled_backends": ['kernel'],
                },
            },
        }
    )

    traceq.profile(envelope.run, synthetic_data_path)
# Out:
# 2024-09-10 22:54:07.681 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:07.682 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:07.683 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:07.684 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:07.686 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:07.686 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:07.687 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:07.687 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:07.688 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:07.688 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:07.689 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:07.772 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:07.775 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-100-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='100-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/100-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:07.776 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:07.777 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:07.778 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/100-200-200.segy',)
# 2024-09-10 22:54:07.779 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:07.779 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:07.780 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:07.786 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:07.788 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/100-200-200.segy',)
# 2024-09-10 22:54:07.789 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:07.790 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:07.791 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:07.792 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:07.793 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:07.794 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:07.794 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:07.795 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:07.798 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:07.800 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:11.837 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:11.901 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:11.903 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:11.911 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:11.912 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:11.927 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:11.929 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 389
# 2024-09-10 22:54:11.930 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:11.931 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/100-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:11.969 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 260208.0, 'unix_timestamp': 5654317}
# 2024-09-10 22:54:11.969 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:11.973 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-100-200-200
# 2024-09-10 22:54:11.984 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:11.985 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:11.985 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:11.986 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:11.987 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:11.988 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:11.988 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:11.989 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:11.989 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:11.990 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:11.990 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:12.000 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:12.003 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-200-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='200-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/200-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:12.003 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:12.004 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:12.004 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/200-200-200.segy',)
# 2024-09-10 22:54:12.005 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:12.006 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:12.006 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:12.013 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:12.015 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/200-200-200.segy',)
# 2024-09-10 22:54:12.016 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:12.017 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:12.018 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:12.019 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:12.019 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:12.021 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:12.021 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:12.022 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:12.025 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:12.027 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:14.737 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:14.860 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:14.862 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:14.876 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:14.877 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:14.897 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:14.900 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 268
# 2024-09-10 22:54:14.900 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:14.901 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/200-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:14.927 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 254304.0, 'unix_timestamp': 5657987}
# 2024-09-10 22:54:14.928 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:14.931 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-200-200-200
# 2024-09-10 22:54:14.941 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:14.942 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:14.942 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:14.943 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:14.944 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:14.945 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:14.945 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:14.946 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:14.947 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:14.947 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:14.948 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:14.958 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:14.960 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-300-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='300-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/300-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:14.961 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:14.961 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:14.962 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/300-200-200.segy',)
# 2024-09-10 22:54:14.962 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:14.963 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:14.964 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:14.970 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:14.972 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/300-200-200.segy',)
# 2024-09-10 22:54:14.973 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:14.974 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:14.975 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:14.976 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:14.977 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:14.978 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:14.979 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:14.979 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:14.982 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:14.984 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:17.682 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:17.868 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:17.870 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:17.886 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:17.887 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:17.901 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:17.904 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 273
# 2024-09-10 22:54:17.904 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:17.905 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/300-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:17.932 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 216192.0, 'unix_timestamp': 5660693}
# 2024-09-10 22:54:17.932 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:17.934 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-300-200-200
# 2024-09-10 22:54:17.945 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:17.946 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:17.946 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:17.947 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:17.947 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:17.948 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:17.948 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:17.949 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:17.950 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:17.950 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:17.951 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:17.961 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:17.963 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-400-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='400-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/400-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:17.964 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:17.965 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:17.966 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/400-200-200.segy',)
# 2024-09-10 22:54:17.968 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:17.968 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:17.969 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:17.974 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:17.977 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/400-200-200.segy',)
# 2024-09-10 22:54:17.979 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:17.980 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:17.980 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:17.981 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:17.982 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:17.983 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:17.984 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:17.984 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:17.987 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:17.989 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:20.665 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:20.931 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:20.933 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:20.944 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:20.945 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:20.961 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:20.963 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 278
# 2024-09-10 22:54:20.964 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:20.964 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/400-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:20.994 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 623956.0, 'unix_timestamp': 5665363}
# 2024-09-10 22:54:20.995 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:20.997 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-400-200-200
# 2024-09-10 22:54:21.008 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:21.009 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:21.010 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:21.010 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:21.011 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:21.012 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:21.012 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:21.013 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:21.013 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:21.014 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:21.014 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:21.024 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:21.027 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-500-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='500-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/500-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:21.027 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:21.028 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:21.028 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/500-200-200.segy',)
# 2024-09-10 22:54:21.029 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:21.030 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:21.030 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:21.036 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:21.039 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/500-200-200.segy',)
# 2024-09-10 22:54:21.040 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:21.041 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:21.042 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:21.042 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:21.043 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:21.044 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:21.045 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:21.046 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:21.049 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:21.051 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:23.751 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:24.086 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:24.087 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:24.102 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:24.103 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:24.118 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:24.120 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 286
# 2024-09-10 22:54:24.121 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:24.122 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/500-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:24.151 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 199652.0, 'unix_timestamp': 5666713}
# 2024-09-10 22:54:24.152 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:24.155 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-500-200-200
# 2024-09-10 22:54:24.167 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:24.168 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:24.169 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:24.169 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:24.170 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:24.170 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:24.171 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:24.171 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:24.173 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:24.173 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:24.174 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:24.184 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:24.186 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-600-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='600-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/600-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:24.187 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:24.187 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:24.188 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/600-200-200.segy',)
# 2024-09-10 22:54:24.189 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:24.189 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:54:24.190 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:54:24.196 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:54:24.199 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/600-200-200.segy',)
# 2024-09-10 22:54:24.199 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:54:24.200 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:54:24.201 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:54:24.202 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:54:24.203 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:54:24.204 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:54:24.205 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:54:24.205 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:54:24.208 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:54:24.210 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:54:26.927 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:54:27.331 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:54:27.332 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:54:27.342 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:54:27.343 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:54:27.358 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:54:27.361 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 294
# 2024-09-10 22:54:27.362 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:54:27.362 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/600-200-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:54:27.394 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 615860.0, 'unix_timestamp': 5671347}
# 2024-09-10 22:54:27.395 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:54:27.398 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-600-200-200
# 2024-09-10 22:54:27.412 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:54:27.413 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:27.414 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:54:27.414 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:54:27.415 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:54:27.415 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:54:27.416 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:54:27.416 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:54:27.417 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:54:27.417 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:54:27.418 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:54:27.428 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:54:27.430 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-700-200-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='700-200-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/700-200-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:54:27.431 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:54:27.432 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:54:27.432 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/700-200-200.segy',)
# 2024-09-10 22:54:27.433 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:54:27.433 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# ...
# 2024-09-10 22:55:43.153 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:55:43.155 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 337
# 2024-09-10 22:55:43.156 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:55:43.157 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/200-1300-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:55:43.190 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 627096.0, 'unix_timestamp': 5747076}
# 2024-09-10 22:55:43.191 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:55:43.194 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-200-1300-200
# 2024-09-10 22:55:43.206 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:55:43.207 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:55:43.207 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:55:43.209 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:55:43.209 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:55:43.210 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:55:43.210 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:55:43.211 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:55:43.212 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:55:43.212 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:55:43.213 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:55:43.223 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:55:43.226 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-200-1400-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='200-1400-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/200-1400-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:55:43.227 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:55:43.227 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:55:43.228 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/200-1400-200.segy',)
# 2024-09-10 22:55:43.228 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:55:43.229 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:55:43.230 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:55:43.236 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:55:43.239 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/200-1400-200.segy',)
# 2024-09-10 22:55:43.239 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:55:43.240 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:55:43.241 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:55:43.242 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:55:43.243 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:55:43.244 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:55:43.244 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:55:43.245 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:55:43.248 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:55:43.250 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:55:46.046 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:55:46.900 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:55:46.903 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:55:46.911 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:55:46.913 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:55:46.928 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:55:46.930 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 345
# 2024-09-10 22:55:46.931 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:55:46.932 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/200-1400-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:55:46.965 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 310112.0, 'unix_timestamp': 5749806}
# 2024-09-10 22:55:46.965 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:55:46.968 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-200-1400-200
# 2024-09-10 22:55:46.980 | INFO     | traceq.profiler.main:run_profiler:15 - Starting profiler
# 2024-09-10 22:55:46.981 | DEBUG    | traceq.profiler.builders:build_trace_hooks:20 - Building trace hooks for enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:55:46.981 | INFO     | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:12 - Enabled memory usage backends: "[<MemoryUsageBackend.KERNEL: 'KERNEL'>]"
# 2024-09-10 22:55:46.982 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:23 - Loading backend: "kernel"
# 2024-09-10 22:55:46.983 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:31 - Loaded backend: "<module 'traceq.profiler.metrics.memory_usage.backends.kernel' from '/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/traceq/traceq/profiler/metrics/memory_usage/backends/kernel.py'>"
# 2024-09-10 22:55:46.984 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "before" function
# 2024-09-10 22:55:46.984 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "before" from "kernel" to hooks
# 2024-09-10 22:55:46.985 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "on_sample" function
# 2024-09-10 22:55:46.985 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:43 - Added "on_sample" from "kernel" to hooks
# 2024-09-10 22:55:46.986 | DEBUG    | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:34 - Checking if backend has "after" function
# 2024-09-10 22:55:46.987 | WARNING  | traceq.profiler.metrics.memory_usage.builders:build_trace_hooks:37 - Backend "kernel" does not have "after" function
# 2024-09-10 22:55:46.997 | DEBUG    | traceq.profiler.tracer:executor_hooks:65 - Using executor hooks: {'before': [<function before at 0x7efef10c6f80>], 'on_sample': [<function capture_trace at 0x7efef10c76d0>, <function capture_trace at 0x7efef10c64d0>], 'after': []}
# 2024-09-10 22:55:46.999 | DEBUG    | traceq.profiler.main:run_profiler:39 - Using config: output_dir=PosixPath('../output/003-20240910224723-191b1c/profile-200-1500-200') logger=LoggerConfig(enabled_transports=[<Transport.CONSOLE: 'CONSOLE'>, <Transport.FILE: 'FILE'>], level=<Level.DEBUG: 'DEBUG'>) profiler=ProfilerConfig(session_id='200-1500-200', enabled_metrics=[<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>], memory_usage=MemoryUsageConfig(enabled_backends=[<MemoryUsageBackend.KERNEL: 'KERNEL'>]), filepath=PosixPath('/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py'), entrypoint='run', signature=[FunctionParameter(name='segy_filepath', type='str', position=0, default='None'), FunctionParameter(name='n_workers', type='int', position=1, default='1'), FunctionParameter(name='single_threaded', type='bool', position=2, default='True')], args=('../output/003-20240910224723-191b1c/data/200-1500-200.segy',), kwargs={}, depth=3, precision=0.01, sign_traces=False, strategy='process')
# 2024-09-10 22:55:47.000 | DEBUG    | traceq.profiler.main:run_profiler:40 - Enabled trace hooks: dict_keys(['before', 'on_sample', 'after'])
# 2024-09-10 22:55:47.000 | DEBUG    | traceq.profiler.main:run_profiler:41 - Enabled metrics: [<Metric.MEMORY_USAGE: 'MEMORY_USAGE'>, <Metric.TIME: 'TIME'>]
# 2024-09-10 22:55:47.001 | DEBUG    | traceq.profiler.main:run_profiler:42 - Using args: ('../output/003-20240910224723-191b1c/data/200-1500-200.segy',)
# 2024-09-10 22:55:47.001 | DEBUG    | traceq.profiler.main:run_profiler:43 - Using kwargs: {}
# 2024-09-10 22:55:47.002 | DEBUG    | traceq.profiler.main:run_profiler:44 - Using entrypoint: run
# 2024-09-10 22:55:47.002 | INFO     | traceq.profiler.main:run_profiler:46 - Starting profiler execution for "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py"
# 2024-09-10 22:55:47.009 | INFO     | traceq.profiler.handlers:execute_file:19 - Starting new profiler session for file "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" with entrypoint set to: "run"
# 2024-09-10 22:55:47.011 | DEBUG    | traceq.profiler.handlers:execute_file:22 - Using args: ('../output/003-20240910224723-191b1c/data/200-1500-200.segy',)
# 2024-09-10 22:55:47.012 | DEBUG    | traceq.profiler.handlers:execute_file:23 - Using kwargs: {}
# 2024-09-10 22:55:47.013 | INFO     | traceq.profiler.handlers:execute_file:38 - Executing file: /home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py
# 2024-09-10 22:55:47.014 | DEBUG    | traceq.profiler.handlers:execute_file:40 - Using function "run" as entrypoint
# 2024-09-10 22:55:47.015 | INFO     | traceq.profiler.handlers:execute_file:42 - Compiling code
# 2024-09-10 22:55:47.016 | INFO     | traceq.profiler.handlers:execute_file:45 - Running execution before hook
# 2024-09-10 22:55:47.017 | DEBUG    | traceq.profiler.tracer:before_executor:83 - Running before executor hooks
# 2024-09-10 22:55:47.018 | INFO     | traceq.profiler.tracer:start_sampler:151 - Starting profile sampler
# 2024-09-10 22:55:47.018 | INFO     | traceq.profiler.tracer:start_sampler:152 - Using precision of 0.01s and process strategy
# 2024-09-10 22:55:47.021 | INFO     | traceq.profiler.handlers:execute_file:48 - Executing code file
# 2024-09-10 22:55:47.023 | INFO     | traceq.profiler.handlers:execute_file:52 - Running function: run
# 2024-09-10 22:55:49.900 | DEBUG    | seismic.cluster:run_attribute:14 - Running attribute Envelope
# 2024-09-10 22:55:50.806 | INFO     | traceq.profiler.handlers:execute_file:55 - Running execution after hook
# 2024-09-10 22:55:50.808 | DEBUG    | traceq.profiler.tracer:after_executor:93 - Running after executor hooks
# 2024-09-10 22:55:50.829 | INFO     | traceq.profiler.tracer:stop_sampler:169 - Profile sampler stopped
# 2024-09-10 22:55:50.830 | INFO     | traceq.profiler.handlers:execute_file:59 - File "/home/delucca/src/unicamp/msc/seismic-attributes-memory-profile/tools/seismic/seismic/attributes/envelope.py" finished execution
# 2024-09-10 22:55:50.845 | INFO     | traceq.profiler.main:run_profiler:50 - Profiler execution finished
# 2024-09-10 22:55:50.847 | DEBUG    | traceq.profiler.main:run_profiler:51 - Amount of captured traces: 358
# 2024-09-10 22:55:50.848 | INFO     | traceq.profiler.main:run_profiler:52 - Saving profile data
# 2024-09-10 22:55:50.849 | DEBUG    | traceq.profiler.main:run_profiler:59 - Using metadata: {'entrypoint_segy_filepath': '../output/003-20240910224723-191b1c/data/200-1500-200.segy', 'kernel_memory_usage_unit': 'kb', 'psutil_memory_usage_unit': 'b', 'resource_memory_usage_unit': 'kb', 'tracemalloc_memory_usage_unit': 'b', 'unix_timestamp_unit': 'ms'}
# 2024-09-10 22:55:50.883 | DEBUG    | traceq.profiler.main:run_profiler:63 - Sample captured trace: {'signature': 'unknown::unknown:0::unknown', 'kernel_memory_usage': 1304492.0, 'unix_timestamp': 5755388}
# 2024-09-10 22:55:50.884 | DEBUG    | traceq.profiler.builders:build_profile:64 - Building profile
# 2024-09-10 22:55:50.886 | INFO     | traceq.profiler.main:run_profiler:66 - Profiler output saved to: ../output/003-20240910224723-191b1c/profile-200-1500-200

# %% [markdown]
# ## Evaluating Experiment Results

# %%
import os
import gzip
import msgpack


def list_directories(path):
    entries = os.listdir(path)

    directories = [
        os.path.join(path, entry)
        for entry in entries
        if os.path.isdir(os.path.join(path, entry))
    ]
    return directories


def find_profiles(directory):
    parquet_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".prof"):
                full_path = os.path.join(root, file)
                parquet_files.append(full_path)
    return parquet_files


def get_session_paths(directory_path):
    dirs = list_directories(directory_path)
    shapes = [shape for shape in dirs if 'experiment' not in shape and 'checkpoints' not in shape]

    return [find_profiles(shape)[0] for shape in shapes]


def get_session_names(sessions):
    return [
        f"{'-'.join(os.path.basename(session).split('/')[-1].split('.')[0].split('-')[:2])}" for session in sessions
    ]


def normalize_metadata(sessions):
    for session in sessions:
        profile = load_profile(session)

        metadata = profile["metadata"]
        metadata_dict = {k: v for k, v in metadata.items()}

        entrypoint_segy_filepath = metadata_dict.pop("entrypoint_segy_filepath", None)
        if entrypoint_segy_filepath:
            entrypoint_shape = os.path.basename(entrypoint_segy_filepath).split(".")[0]
            entrypoint_shape = f"({entrypoint_shape.replace('-', ',')})"
            metadata_dict["entrypoint_shape"] = entrypoint_shape

        new_metadata = {k: v for k, v in metadata_dict.items()}
        profile["metadata"] = new_metadata

        with gzip.open(session, "wb") as f:
            packed = msgpack.packb(profile)
            f.write(packed)


session_paths = get_session_paths(OUTPUT_DIR)
normalize_metadata(session_paths)

session_names = get_session_names(session_paths)
zipped_sessions = list(zip(session_names, session_paths))

print(zipped_sessions)
# Out:
# [('200-1100', '../output/003-20240910224723-191b1c/profile-200-1100-200/200-1100-200.prof'), ('200-900', '../output/003-20240910224723-191b1c/profile-200-900-200/200-900-200.prof'), ('100-200', '../output/003-20240910224723-191b1c/profile-100-200-200/100-200-200.prof'), ('1400-200', '../output/003-20240910224723-191b1c/profile-1400-200-200/1400-200-200.prof'), ('200-100', '../output/003-20240910224723-191b1c/profile-200-100-200/200-100-200.prof'), ('200-500', '../output/003-20240910224723-191b1c/profile-200-500-200/200-500-200.prof'), ('200-800', '../output/003-20240910224723-191b1c/profile-200-800-200/200-800-200.prof'), ('1000-200', '../output/003-20240910224723-191b1c/profile-1000-200-200/1000-200-200.prof'), ('200-1000', '../output/003-20240910224723-191b1c/profile-200-1000-200/200-1000-200.prof'), ('1500-200', '../output/003-20240910224723-191b1c/profile-1500-200-200/1500-200-200.prof'), ('800-200', '../output/003-20240910224723-191b1c/profile-800-200-200/800-200-200.prof'), ('400-200', '../output/003-20240910224723-191b1c/profile-400-200-200/400-200-200.prof'), ('1100-200', '../output/003-20240910224723-191b1c/profile-1100-200-200/1100-200-200.prof'), ('200-600', '../output/003-20240910224723-191b1c/profile-200-600-200/200-600-200.prof'), ('200-1500', '../output/003-20240910224723-191b1c/profile-200-1500-200/200-1500-200.prof'), ('1200-200', '../output/003-20240910224723-191b1c/profile-1200-200-200/1200-200-200.prof'), ('200-1200', '../output/003-20240910224723-191b1c/profile-200-1200-200/200-1200-200.prof'), ('300-200', '../output/003-20240910224723-191b1c/profile-300-200-200/300-200-200.prof'), ('1300-200', '../output/003-20240910224723-191b1c/profile-1300-200-200/1300-200-200.prof'), ('700-200', '../output/003-20240910224723-191b1c/profile-700-200-200/700-200-200.prof'), ('500-200', '../output/003-20240910224723-191b1c/profile-500-200-200/500-200-200.prof'), ('200-200', '../output/003-20240910224723-191b1c/profile-200-200-200/200-200-200.prof'), ('200-1400', '../output/003-20240910224723-191b1c/profile-200-1400-200/200-1400-200.prof'), ('200-300', '../output/003-20240910224723-191b1c/profile-200-300-200/200-300-200.prof'), ('200-700', '../output/003-20240910224723-191b1c/profile-200-700-200/200-700-200.prof'), ('200-1300', '../output/003-20240910224723-191b1c/profile-200-1300-200/200-1300-200.prof'), ('600-200', '../output/003-20240910224723-191b1c/profile-600-200-200/600-200-200.prof'), ('200-400', '../output/003-20240910224723-191b1c/profile-200-400-200/200-400-200.prof'), ('900-200', '../output/003-20240910224723-191b1c/profile-900-200-200/900-200-200.prof')]

# %% [markdown]
# With the metadata normalized, and the organized data, we need now to get the peaks for each profile

# %%
from traceq.profiler.loaders import load_profile


def get_peak(profile_path):
    profile = load_profile(profile_path)
    data = profile['experiment']

    return max(item['kernel_memory_usage'] for item in data)


def get_unit(profile_path):
    profile = load_profile(profile_path)
    return profile['metadata']['kernel_memory_usage_unit']


peaks = [(shape, get_peak(profile_path), get_unit(profile_path)) for shape, profile_path in zipped_sessions]
print(peaks)
# Out:
# [('200-1100', 1872856.0, 'kb'), ('200-900', 1643200.0, 'kb'), ('100-200', 780704.0, 'kb'), ('1400-200', 2193256.0, 'kb'), ('200-100', 776788.0, 'kb'), ('200-500', 1218564.0, 'kb'), ('200-800', 1541740.0, 'kb'), ('1000-200', 1758756.0, 'kb'), ('200-1000', 1763140.0, 'kb'), ('1500-200', 2311224.0, 'kb'), ('800-200', 1549876.0, 'kb'), ('400-200', 1102592.0, 'kb'), ('1100-200', 1872508.0, 'kb'), ('200-600', 1322116.0, 'kb'), ('200-1500', 2311252.0, 'kb'), ('1200-200', 1986288.0, 'kb'), ('200-1200', 1988528.0, 'kb'), ('300-200', 990908.0, 'kb'), ('1300-200', 2095864.0, 'kb'), ('700-200', 1440016.0, 'kb'), ('500-200', 1222540.0, 'kb'), ('200-200', 882772.0, 'kb'), ('200-1400', 2191332.0, 'kb'), ('200-300', 990976.0, 'kb'), ('200-700', 1425888.0, 'kb'), ('200-1300', 2098040.0, 'kb'), ('600-200', 1328236.0, 'kb'), ('200-400', 1098636.0, 'kb'), ('900-200', 1653184.0, 'kb')]

# %% [markdown]
# Now, we can create the graph

# %%
import plotly.graph_objects as go

# Prepare experiment for 3D plot
inlines = [int(item[0].split('-')[0]) for item in peaks]
xlines = [int(item[0].split('-')[1]) for item in peaks]
memory_gb = [item[1] / 1048576 for item in peaks]  # Convert memory usage to GB

fig = go.Figure(data=[go.Scatter3d(
    x=inlines,
    y=xlines,
    z=memory_gb,
    mode='markers',
    marker=dict(
        size=5,
        color=memory_gb,
        colorscale='Viridis',
    ),
    line=dict(color='blue'),
)])

fig.update_layout(
    scene=dict(
        xaxis_title='Inline',
        yaxis_title='Xline',
        zaxis_title='Memory Usage (GB)',
        aspectmode='cube',
        camera=dict(
            eye=dict(x=-2.5, y=-1.5, z=2),
            center=dict(x=0, y=0, z=-1)
        ),
    ),
    font=dict(family="Courier New, monospace", size=12, color="Black"),
    template="plotly_white"
)

fig.write_image(f'{OUTPUT_DIR}/memory-usage-3d.pdf', format="pdf", engine="kaleido", width=900, height=700)
fig.show()
# Out:
# <div>                            <div id="3eb0b343-8dc1-4c53-8e0d-0e2caae21cd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3eb0b343-8dc1-4c53-8e0d-0e2caae21cd8")) {                    Plotly.newPlot(                        "3eb0b343-8dc1-4c53-8e0d-0e2caae21cd8",                        [{"line":{"color":"blue"},"marker":{"color":[1.7860946655273438,1.56707763671875,0.744537353515625,2.0916519165039062,0.7408027648925781,1.1621131896972656,1.4703178405761719,1.6772804260253906,1.6814613342285156,2.2041549682617188,1.4780769348144531,1.051513671875,1.7857627868652344,1.2608680725097656,2.204181671142578,1.8942718505859375,1.8964080810546875,0.9450035095214844,1.9987716674804688,1.3733062744140625,1.1659049987792969,0.8418769836425781,2.0898170471191406,0.945068359375,1.359832763671875,2.0008468627929688,1.2667045593261719,1.0477409362792969,1.57659912109375],"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"size":5},"mode":"markers","x":[200,200,100,1400,200,200,200,1000,200,1500,800,400,1100,200,200,1200,200,300,1300,700,500,200,200,200,200,200,600,200,900],"y":[1100,900,200,200,100,500,800,200,1000,200,200,200,200,600,1500,200,1200,200,200,200,200,200,1400,300,700,1300,200,400,200],"z":[1.7860946655273438,1.56707763671875,0.744537353515625,2.0916519165039062,0.7408027648925781,1.1621131896972656,1.4703178405761719,1.6772804260253906,1.6814613342285156,2.2041549682617188,1.4780769348144531,1.051513671875,1.7857627868652344,1.2608680725097656,2.204181671142578,1.8942718505859375,1.8964080810546875,0.9450035095214844,1.9987716674804688,1.3733062744140625,1.1659049987792969,0.8418769836425781,2.0898170471191406,0.945068359375,1.359832763671875,2.0008468627929688,1.2667045593261719,1.0477409362792969,1.57659912109375],"type":"scatter3d"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0. ...
