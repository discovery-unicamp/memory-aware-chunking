# %% [markdown]
# # Execution Environment Notebook

# %% [markdown]
# ## Introduction
#
# This notebook aims to demonstrate and validate the execution environment isolation for the memory consumption experiment.
# The goals of this notebooks are:
#
# - Check if the experiment runs in an isolated process or container.
# - Confirm that no memory contamination occurs between runs.

# %% [markdown]
# ### How to Use this Notebook
#
# - Run the individual cells to inspect and verify the behavior of specific parts of the component.
# - Review the expected behavior before running the full experiment via the shell script.
# - Use this notebook as a debugging and documentation tool to support future iterations of the experiment.
#
# By structuring the experiment this way, we ensure a clear separation between explanation, validation, and execution, making it easier to reason about the results while keeping the experiment reproducible and well-documented.

# %% [markdown]
# ## Components Overview

# %% [markdown]
# Before running the component, we need to setup a few variables and utils.

# %%
import os
import re
import sys
from datetime import datetime

from loguru import logger

dirs_to_add = [
    os.path.abspath('../'),
]

for dir_to_add in dirs_to_add:
    if dir_to_add not in sys.path:
        sys.path.insert(0, dir_to_add)

TIMESTAMP = datetime.now().strftime("%Y%m%d%H%M%S")

EXPERIMENT_IMAGE = "mac/02-execution-environment"
RELATIVE_OUT_DIR = f"out/notebooks/02-execution-environment-{TIMESTAMP}"
CONTAINER_OUT_DIR = f"/app/{RELATIVE_OUT_DIR}"
MEMORY_USAGE_DATA_GENERATION_LOG_FILE = f"{CONTAINER_OUT_DIR}/docker-monitor/memory-usage--data-generation.log"
MEMORY_USAGE_EXPERIMENT_LOG_FILE = f"{CONTAINER_OUT_DIR}/docker-monitor/memory-usage--experiment.log"
PAGE_FAULTS_DATA_GENERATION_LOG_FILE = f"{CONTAINER_OUT_DIR}/docker-monitor/page-faults--data-generation.log"
PAGE_FAULTS_EXPERIMENT_LOG_FILE = f"{CONTAINER_OUT_DIR}/docker-monitor/page-faults--experiment.log"

INLINES = "700"
XLINES = "700"
SAMPLES = "400"

logger.debug("Generated global variables")
logger.debug(f"TIMESTAMP: {TIMESTAMP}")
logger.debug(f"EXPERIMENT_IMAGE: {EXPERIMENT_IMAGE}")
logger.debug(f"RELATIVE_OUT_DIR: {RELATIVE_OUT_DIR}")
logger.debug(f"CONTAINER_OUT_DIR: {CONTAINER_OUT_DIR}")

logger.debug(f"MEMORY_USAGE_DATA_GENERATION_LOG_FILE: {MEMORY_USAGE_DATA_GENERATION_LOG_FILE}")
logger.debug(f"MEMORY_USAGE_EXPERIMENT_LOG_FILE: {MEMORY_USAGE_EXPERIMENT_LOG_FILE}")

logger.debug(f"PAGE_FAULTS_DATA_GENERATION_LOG_FILE: {PAGE_FAULTS_DATA_GENERATION_LOG_FILE}")
logger.debug(f"PAGE_FAULTS_EXPERIMENT_LOG_FILE: {PAGE_FAULTS_EXPERIMENT_LOG_FILE}")

logger.debug(f"INLINES: {INLINES}")
logger.debug(f"XLINES: {XLINES}")
logger.debug(f"SAMPLES: {SAMPLES}")

os.makedirs(f"../{RELATIVE_OUT_DIR}/docker-monitor", exist_ok=True)
# Out:
# 2025-05-09 00:05:17.538 | DEBUG    | __main__:<module>:30 - Generated global variables
# 2025-05-09 00:05:17.538 | DEBUG    | __main__:<module>:31 - TIMESTAMP: 20250509000517
# 2025-05-09 00:05:17.538 | DEBUG    | __main__:<module>:32 - EXPERIMENT_IMAGE: mac/02-execution-environment
# 2025-05-09 00:05:17.538 | DEBUG    | __main__:<module>:33 - RELATIVE_OUT_DIR: out/notebooks/02-execution-environment-20250509000517
# 2025-05-09 00:05:17.538 | DEBUG    | __main__:<module>:34 - CONTAINER_OUT_DIR: /app/out/notebooks/02-execution-environment-20250509000517
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:36 - MEMORY_USAGE_DATA_GENERATION_LOG_FILE: /app/out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--data-generation.log
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:37 - MEMORY_USAGE_EXPERIMENT_LOG_FILE: /app/out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment.log
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:39 - PAGE_FAULTS_DATA_GENERATION_LOG_FILE: /app/out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--data-generation.log
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:40 - PAGE_FAULTS_EXPERIMENT_LOG_FILE: /app/out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment.log
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:42 - INLINES: 700
# 2025-05-09 00:05:17.539 | DEBUG    | __main__:<module>:43 - XLINES: 700
# 2025-05-09 00:05:17.540 | DEBUG    | __main__:<module>:44 - SAMPLES: 400

# %% [markdown]
# Now, let's build the Docker images

# %%
import importlib
import docker
import tools.docker

from loguru import logger

importlib.reload(tools.docker)

client = docker.from_env()

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, client)
logger.info("Experiment image built successfully.")
# Out:
# 2025-05-09 00:05:17.674 | INFO     | __main__:<module>:11 - Building experiment image...
# 2025-05-09 00:05:17.674 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# 2025-05-09 00:05:18.272 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 00:05:18.273 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 00:05:30.290 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 00:05:30.292 | INFO     | __main__:<module>:13 - Experiment image built successfully.

# %% [markdown]
# With the image built, we're going to generate the test data.

# %%
logger.info("Generating test data...")
data_generator_container = client.containers.run(
    image=EXPERIMENT_IMAGE,
    command=[
        "generate-data",
        "--inlines", INLINES,
        "--xlines", XLINES,
        "--samples", SAMPLES,
        "--output-dir", f"{CONTAINER_OUT_DIR}/data"
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": MEMORY_USAGE_DATA_GENERATION_LOG_FILE,
        "PAGE_FAULTS_LOG_FILE": PAGE_FAULTS_DATA_GENERATION_LOG_FILE,
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py generate-data",
    },
    volumes={
        os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished generating test data")
# Out:
# 2025-05-09 00:05:30.307 | INFO     | __main__:<module>:1 - Generating test data...
# 2025-05-09 00:07:08.516 | INFO     | __main__:<module>:23 - Finished generating test data

# %% [markdown]
# With the test data generated, we're going to execute the experiment, and launch the Docker monitor to check the memory usage.

# %%
logger.info("Launching experiment...")
experiment_container = client.containers.run(
    image=EXPERIMENT_IMAGE,
    mem_limit="15g",
    command=[
        "operate",
        "envelope",
        "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": MEMORY_USAGE_EXPERIMENT_LOG_FILE,
        "PAGE_FAULTS_LOG_FILE": PAGE_FAULTS_EXPERIMENT_LOG_FILE,
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
    },
    volumes={
        os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished executing experiment")
# Out:
# 2025-05-09 00:07:08.535 | INFO     | __main__:<module>:1 - Launching experiment...
# 2025-05-09 00:07:12.538 | INFO     | __main__:<module>:22 - Finished executing experiment

# %% [markdown]
# After executing the experiment, now we need to parse the memory usage data.

# %%
import importlib
import tools.monitor

importlib.reload(tools.monitor)

memory_usage_df = tools.monitor.memory_usage_log_to_df(
    f"../{RELATIVE_OUT_DIR}/docker-monitor/memory-usage--experiment.log",
)

memory_usage_df.head()
# Out:
# 2025-05-09 00:07:12.563 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment.log
#                  timestamp  memory_usage_kb
# 0  2025-05-09 03:07:09.704            27056
# 1  2025-05-09 03:07:09.716            33832
# 2  2025-05-09 03:07:09.730            37544
# 3  2025-05-09 03:07:09.742            39316
# 4  2025-05-09 03:07:09.754            39692

# %%
import tools.conversions

importlib.reload(tools.conversions)

peak_memory_usage = tools.conversions.kb_to_gb(
    memory_usage_df["memory_usage_kb"].max()
)

logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
# Out:
# 2025-05-09 00:07:12.606 | INFO     | __main__:<module>:9 - Peak memory usage: 6.013034820556641 GB

# %% [markdown]
# Given that we know that the memory usage data is correct, we will now execute multiple iterations to confirm that the memory usage is consistent.

# %%
iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}.log"

    logger.info(f"Iteration {i + 1}/{iterations}")
    experiment_container = client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))
# Out:
# 2025-05-09 00:07:12.672 | INFO     | __main__:<module>:14 - Iteration 1/30
# 2025-05-09 00:07:16.618 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0.log
# 2025-05-09 00:07:16.620 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0.log
# 2025-05-09 00:07:16.622 | INFO     | __main__:<module>:57 - Peak memory usage: 6.020084381103516 GB
# 2025-05-09 00:07:16.623 | INFO     | __main__:<module>:58 - Peak minor page faults: 32426
# 2025-05-09 00:07:16.623 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:16.624 | INFO     | __main__:<module>:14 - Iteration 2/30
# 2025-05-09 00:07:20.502 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1.log
# 2025-05-09 00:07:20.504 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1.log
# 2025-05-09 00:07:20.506 | INFO     | __main__:<module>:57 - Peak memory usage: 5.991630554199219 GB
# 2025-05-09 00:07:20.506 | INFO     | __main__:<module>:58 - Peak minor page faults: 32428
# 2025-05-09 00:07:20.507 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:20.507 | INFO     | __main__:<module>:14 - Iteration 3/30
# 2025-05-09 00:07:24.635 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2.log
# 2025-05-09 00:07:24.636 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2.log
# 2025-05-09 00:07:24.637 | INFO     | __main__:<module>:57 - Peak memory usage: 5.987079620361328 GB
# 2025-05-09 00:07:24.638 | INFO     | __main__:<module>:58 - Peak minor page faults: 32428
# 2025-05-09 00:07:24.638 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:24.638 | INFO     | __main__:<module>:14 - Iteration 4/30
# 2025-05-09 00:07:28.578 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3.log
# 2025-05-09 00:07:28.581 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3.log
# 2025-05-09 00:07:28.583 | INFO     | __main__:<module>:57 - Peak memory usage: 6.007652282714844 GB
# 2025-05-09 00:07:28.583 | INFO     | __main__:<module>:58 - Peak minor page faults: 32444
# 2025-05-09 00:07:28.584 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:28.584 | INFO     | __main__:<module>:14 - Iteration 5/30
# 2025-05-09 00:07:32.556 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4.log
# 2025-05-09 00:07:32.558 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4.log
# 2025-05-09 00:07:32.560 | INFO     | __main__:<module>:57 - Peak memory usage: 5.999507904052734 GB
# 2025-05-09 00:07:32.561 | INFO     | __main__:<module>:58 - Peak minor page faults: 32424
# 2025-05-09 00:07:32.562 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:32.562 | INFO     | __main__:<module>:14 - Iteration 6/30
# 2025-05-09 00:07:36.509 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5.log
# 2025-05-09 00:07:36.512 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5.log
# 2025-05-09 00:07:36.515 | INFO     | __main__:<module>:57 - Peak memory usage: 5.9882354736328125 GB
# 2025-05-09 00:07:36.515 | INFO     | __main__:<module>:58 - Peak minor page faults: 32432
# 2025-05-09 00:07:36.516 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:36.516 | INFO     | __main__:<module>:14 - Iteration 7/30
# 2025-05-09 00:07:40.527 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6.log
# 2025-05-09 00:07:40.529 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6.log
# 2025-05-09 00:07:40.531 | INFO     | __main__:<module>:57 - Peak memory usage: 6.031093597412109 GB
# 2025-05-09 00:07:40.532 | INFO     | __main__:<module>:58 - Peak minor page faults: 32439
# 2025-05-09 00:07:40.532 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:40.533 | INFO     | __main__:<module>:14 - Iteration 8/30
# 2025-05-09 00:07:44.427 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7.log
# 2025-05-09 00:07:44.429 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7.log
# 2025-05-09 00:07:44.431 | INFO     | __main__:<module>:57 - Peak memory usage: 6.019351959228516 GB
# 2025-05-09 00:07:44.432 | INFO     | __main__:<module>:58 - Peak minor page faults: 32426
# 2025-05-09 00:07:44.432 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:44.433 | INFO     | __main__:<module>:14 - Iteration 9/30
# 2025-05-09 00:07:48.336 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8.log
# 2025-05-09 00:07:48.339 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8.log
# 2025-05-09 00:07:48.341 | INFO     | __main__:<module>:57 - Peak memory usage: 6.010753631591797 GB
# 2025-05-09 00:07:48.341 | INFO     | __main__:<module>:58 - Peak minor page faults: 32446
# 2025-05-09 00:07:48.342 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:48.342 | INFO     | __main__:<module>:14 - Iteration 10/30
# 2025-05-09 00:07:52.224 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9.log
# 2025-05-09 00:07:52.226 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9.log
# 2025-05-09 00:07:52.228 | INFO     | __main__:<module>:57 - Peak memory usage: 5.985401153564453 GB
# 2025-05-09 00:07:52.229 | INFO     | __main__:<module>:58 - Peak minor page faults: 32420
# 2025-05-09 00:07:52.229 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:52.229 | INFO     | __main__:<module>:14 - Iteration 11/30
# 2025-05-09 00:07:56.111 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10.log
# 2025-05-09 00:07:56.113 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10.log
# 2025-05-09 00:07:56.115 | INFO     | __main__:<module>:57 - Peak memory usage: 6.009777069091797 GB
# 2025-05-09 00:07:56.116 | INFO     | __main__:<module>:58 - Peak minor page faults: 32434
# 2025-05-09 00:07:56.116 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:56.117 | INFO     | __main__:<module>:14 - Iteration 12/30
# 2025-05-09 00:07:59.962 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11.log
# 2025-05-09 00:07:59.964 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11.log
# 2025-05-09 00:07:59.967 | INFO     | __main__:<module>:57 - Peak memory usage: 6.011260986328125 GB
# 2025-05-09 00:07:59.968 | INFO     | __main__:<module>:58 - Peak minor page faults: 32423
# 2025-05-09 00:07:59.968 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:07:59.969 | INFO     | __main__:<module>:14 - Iteration 13/30
# 2025-05-09 00:08:03.829 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12.log
# 2025-05-09 00:08:03.831 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12.log
# 2025-05-09 00:08:03.833 | INFO     | __main__:<module>:57 - Peak memory usage: 5.988063812255859 GB
# 2025-05-09 00:08:03.834 | INFO     | __main__:<module>:58 - Peak minor page faults: 32445
# 2025-05-09 00:08:03.834 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:03.835 | INFO     | __main__:<module>:14 - Iteration 14/30
# 2025-05-09 00:08:07.771 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13.log
# 2025-05-09 00:08:07.773 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13.log
# 2025-05-09 00:08:07.775 | INFO     | __main__:<module>:57 - Peak memory usage: 6.002388000488281 GB
# 2025-05-09 00:08:07.789 | INFO     | __main__:<module>:58 - Peak minor page faults: 32432
# 2025-05-09 00:08:07.789 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:07.790 | INFO     | __main__:<module>:14 - Iteration 15/30
# 2025-05-09 00:08:11.669 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14.log
# 2025-05-09 00:08:11.671 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14.log
# 2025-05-09 00:08:11.672 | INFO     | __main__:<module>:57 - Peak memory usage: 5.997230529785156 GB
# 2025-05-09 00:08:11.673 | INFO     | __main__:<module>:58 - Peak minor page faults: 32421
# 2025-05-09 00:08:11.673 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:11.674 | INFO     | __main__:<module>:14 - Iteration 16/30
# 2025-05-09 00:08:15.554 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15.log
# 2025-05-09 00:08:15.555 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15.log
# 2025-05-09 00:08:15.557 | INFO     | __main__:<module>:57 - Peak memory usage: 6.020206451416016 GB
# 2025-05-09 00:08:15.557 | INFO     | __main__:<module>:58 - Peak minor page faults: 32436
# 2025-05-09 00:08:15.558 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:15.558 | INFO     | __main__:<module>:14 - Iteration 17/30
# 2025-05-09 00:08:19.455 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16.log
# 2025-05-09 00:08:19.458 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16.log
# 2025-05-09 00:08:19.460 | INFO     | __main__:<module>:57 - Peak memory usage: 5.992012023925781 GB
# 2025-05-09 00:08:19.460 | INFO     | __main__:<module>:58 - Peak minor page faults: 32435
# 2025-05-09 00:08:19.461 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:19.462 | INFO     | __main__:<module>:14 - Iteration 18/30
# 2025-05-09 00:08:23.681 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17.log
# 2025-05-09 00:08:23.684 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17.log
# 2025-05-09 00:08:23.686 | INFO     | __main__:<module>:57 - Peak memory usage: 6.0252838134765625 GB
# 2025-05-09 00:08:23.687 | INFO     | __main__:<module>:58 - Peak minor page faults: 32427
# 2025-05-09 00:08:23.687 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:23.688 | INFO     | __main__:<module>:14 - Iteration 19/30
# 2025-05-09 00:08:27.585 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18.log
# 2025-05-09 00:08:27.586 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18.log
# 2025-05-09 00:08:27.588 | INFO     | __main__:<module>:57 - Peak memory usage: 5.998165130615234 GB
# 2025-05-09 00:08:27.589 | INFO     | __main__:<module>:58 - Peak minor page faults: 32430
# 2025-05-09 00:08:27.589 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:27.589 | INFO     | __main__:<module>:14 - Iteration 20/30
# 2025-05-09 00:08:31.522 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19.log
# 2025-05-09 00:08:31.524 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19.log
# 2025-05-09 00:08:31.526 | INFO     | __main__:<module>:57 - Peak memory usage: 5.981525421142578 GB
# 2025-05-09 00:08:31.526 | INFO     | __main__:<module>:58 - Peak minor page faults: 32422
# 2025-05-09 00:08:31.527 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:31.527 | INFO     | __main__:<module>:14 - Iteration 21/30
# 2025-05-09 00:08:35.460 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20.log
# 2025-05-09 00:08:35.462 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20.log
# 2025-05-09 00:08:35.463 | INFO     | __main__:<module>:57 - Peak memory usage: 6.008674621582031 GB
# 2025-05-09 00:08:35.463 | INFO     | __main__:<module>:58 - Peak minor page faults: 32431
# 2025-05-09 00:08:35.463 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:35.464 | INFO     | __main__:<module>:14 - Iteration 22/30
# 2025-05-09 00:08:39.367 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21.log
# 2025-05-09 00:08:39.369 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21.log
# 2025-05-09 00:08:39.371 | INFO     | __main__:<module>:57 - Peak memory usage: 6.033908843994141 GB
# 2025-05-09 00:08:39.372 | INFO     | __main__:<module>:58 - Peak minor page faults: 32424
# 2025-05-09 00:08:39.372 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:39.373 | INFO     | __main__:<module>:14 - Iteration 23/30
# 2025-05-09 00:08:43.239 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22.log
# 2025-05-09 00:08:43.242 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22.log
# 2025-05-09 00:08:43.244 | INFO     | __main__:<module>:57 - Peak memory usage: 6.0297393798828125 GB
# 2025-05-09 00:08:43.244 | INFO     | __main__:<module>:58 - Peak minor page faults: 32446
# 2025-05-09 00:08:43.245 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:43.247 | INFO     | __main__:<module>:14 - Iteration 24/30
# 2025-05-09 00:08:47.190 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23.log
# 2025-05-09 00:08:47.193 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23.log
# 2025-05-09 00:08:47.195 | INFO     | __main__:<module>:57 - Peak memory usage: 5.980838775634766 GB
# 2025-05-09 00:08:47.195 | INFO     | __main__:<module>:58 - Peak minor page faults: 32425
# 2025-05-09 00:08:47.196 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:47.196 | INFO     | __main__:<module>:14 - Iteration 25/30
# 2025-05-09 00:08:51.165 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24.log
# 2025-05-09 00:08:51.170 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24.log
# 2025-05-09 00:08:51.175 | INFO     | __main__:<module>:57 - Peak memory usage: 5.994251251220703 GB
# 2025-05-09 00:08:51.175 | INFO     | __main__:<module>:58 - Peak minor page faults: 32425
# 2025-05-09 00:08:51.175 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:51.176 | INFO     | __main__:<module>:14 - Iteration 26/30
# 2025-05-09 00:08:55.093 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25.log
# 2025-05-09 00:08:55.096 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25.log
# 2025-05-09 00:08:55.098 | INFO     | __main__:<module>:57 - Peak memory usage: 6.007625579833984 GB
# 2025-05-09 00:08:55.098 | INFO     | __main__:<module>:58 - Peak minor page faults: 32429
# 2025-05-09 00:08:55.099 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:55.100 | INFO     | __main__:<module>:14 - Iteration 27/30
# 2025-05-09 00:08:59.038 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26.log
# 2025-05-09 00:08:59.040 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26.log
# 2025-05-09 00:08:59.042 | INFO     | __main__:<module>:57 - Peak memory usage: 6.022914886474609 GB
# 2025-05-09 00:08:59.043 | INFO     | __main__:<module>:58 - Peak minor page faults: 32440
# 2025-05-09 00:08:59.043 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:08:59.043 | INFO     | __main__:<module>:14 - Iteration 28/30
# 2025-05-09 00:09:03.067 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27.log
# 2025-05-09 00:09:03.070 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27.log
# 2025-05-09 00:09:03.073 | INFO     | __main__:<module>:57 - Peak memory usage: 6.0161285400390625 GB
# 2025-05-09 00:09:03.073 | INFO     | __main__:<module>:58 - Peak minor page faults: 32428
# 2025-05-09 00:09:03.074 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:09:03.074 | INFO     | __main__:<module>:14 - Iteration 29/30
# 2025-05-09 00:09:07.009 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28.log
# 2025-05-09 00:09:07.012 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28.log
# 2025-05-09 00:09:07.014 | INFO     | __main__:<module>:57 - Peak memory usage: 5.987087249755859 GB
# 2025-05-09 00:09:07.015 | INFO     | __main__:<module>:58 - Peak minor page faults: 32431
# 2025-05-09 00:09:07.015 | INFO     | __main__:<module>:59 - Peak major page faults: 0
# 2025-05-09 00:09:07.015 | INFO     | __main__:<module>:14 - Iteration 30/30
# 2025-05-09 00:09:10.929 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29.log
# 2025-05-09 00:09:10.932 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29.log
# 2025-05-09 00:09:10.934 | INFO     | __main__:<module>:57 - Peak memory usage: 5.997287750244141 GB
# 2025-05-09 00:09:10.934 | INFO     | __main__:<module>:58 - Peak minor page faults: 32425
# 2025-05-09 00:09:10.934 | INFO     | __main__:<module>:59 - Peak major page faults: 0

# %%
import matplotlib.pyplot as plt

# Plot memory usage over time for all DataFrames
plt.figure(figsize=(10, 5))
for i, df in enumerate(memory_usage_history):
    memory_usages = tools.conversions.kb_to_gb(df["memory_usage_kb"]).to_numpy()
    plt.plot(memory_usages, marker='o', linestyle='-', label=f'Run {i + 1}')

plt.ylabel("Memory Usage (GB)")
plt.title("Memory Usage Over Time Across Runs")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig(f"../{RELATIVE_OUT_DIR}/memory_usage_over_time.pdf")
plt.show()

# Plot minor page faults over time for all DataFrames
plt.figure(figsize=(10, 5))
for i, df in enumerate(page_faults_history):
    minor_page_faults = df["minor_page_faults"].to_numpy()
    plt.plot(minor_page_faults, marker='o', linestyle='-', label=f'Run {i + 1}')

plt.ylabel("Minor Page Faults")
plt.title("Minor Page Faults Over Time Across Runs")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig(f"../{RELATIVE_OUT_DIR}/minor_page_faults_over_time.pdf")
plt.show()

# Plot major page faults over time for all DataFrames
plt.figure(figsize=(10, 5))
for i, df in enumerate(page_faults_history):
    major_page_faults = df["major_page_faults"].to_numpy()
    plt.plot(major_page_faults, marker='o', linestyle='-', label=f'Run {i + 1}')

plt.ylabel("Major Page Faults")
plt.title("Major Page Faults Over Time Across Runs")
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig(f"../{RELATIVE_OUT_DIR}/major_page_faults_over_time.pdf")
plt.show()

# Plot peak memory usage across runs
plt.figure(figsize=(8, 4))
plt.plot(peak_memory_usage_history, marker='s', linestyle='-', color='r', label='Peak Memory Usage (GB)')
plt.xlabel("Run Number")
plt.ylabel("Peak Memory Usage (GB)")
plt.title("Peak Memory Usage Across Runs")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.savefig(f"../{RELATIVE_OUT_DIR}/peak_memory_usage.pdf")
plt.show()

# Plot peak minor page faults across runs
plt.figure(figsize=(8, 4))
plt.plot(peak_minor_page_faults_history, marker='s', linestyle='-', color='r', label='Peak Minor Page Faults')
plt.xlabel("Run Number")
plt.ylabel("Peak Minor Page Faults")
plt.title("Peak Minor Page Faults Across Runs")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.savefig(f"../{RELATIVE_OUT_DIR}/peak_minor_page_faults.pdf")
plt.show()

# Plot peak major page faults across runs
plt.figure(figsize=(8, 4))
plt.plot(peak_major_page_faults_history, marker='s', linestyle='-', color='r', label='Peak Minor Page Faults')
plt.xlabel("Run Number")
plt.ylabel("Peak Major Page Faults")
plt.title("Peak Major Page Faults Across Runs")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.savefig(f"../{RELATIVE_OUT_DIR}/peak_major_page_faults.pdf")
plt.show()

# %%
import numpy as np

# Plot moving average of peak memory usage
window_size = 5
moving_avg = np.convolve(peak_memory_usage_history, np.ones(window_size) / window_size, mode='valid')

plt.figure(figsize=(8, 4))
plt.plot(peak_memory_usage_history, marker='s', linestyle='-', color='r', alpha=0.5, label='Raw Peak Memory Usage')
plt.plot(range(len(moving_avg)), moving_avg, marker='o', linestyle='-', color='b', label='Moving Average')
plt.xlabel("Run Number")
plt.ylabel("Peak Memory Usage (GB)")
plt.title("Peak Memory Usage Across Runs (Smoothed)")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.savefig(f"../{RELATIVE_OUT_DIR}/peak_memory_usage_smoothed.pdf")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot distribution of peak memory usage
sns.histplot(peak_memory_usage_history, bins=10, kde=True)
plt.xlabel("Peak Memory Usage (GB)")
plt.ylabel("Frequency")
plt.title("Distribution of Peak Memory Usage")
plt.savefig(f"../{RELATIVE_OUT_DIR}/distribution_of_peak_memory_usage.pdf")
plt.show()

# %%
def plot_variability(peaks: list[float], metric: str, unit: str = "", suffix: str = ""):
    unit = unit.strip() if unit else ""
    metric_with_unit = f"{metric}{f' ({unit})' if unit != '' else ''}"
    snake_cased_metric = f"{re.sub(r'([_])', '_', str(metric_with_unit)).lower()}".replace(" ", "_")

    mean_peak = np.mean(peaks)
    std_dev_peak = np.std(peaks)
    median_peak = np.median(peaks)
    min_peak = np.min(peaks)
    max_peak = np.max(peaks)
    coefficient_of_variation = (std_dev_peak / mean_peak) * 100

    # Create a figure to visualize peak memory usage and its variability
    fig, ax = plt.subplots(figsize=(10, 5))

    # Plot peak memory usage
    ax.plot(peaks, marker='s', linestyle='-', color='r', alpha=0.7, label=f"Peak {metric_with_unit}")

    # Plot mean and standard deviation bands
    ax.axhline(mean_peak, color='b', linestyle='--', label=f'Mean: {mean_peak:.2f} {unit}')
    ax.fill_between(range(len(peaks)), mean_peak - std_dev_peak, mean_peak + std_dev_peak,
                    color='blue', alpha=0.2, label=f'Standard Deviation: ±{std_dev_peak:.2f} {unit}')

    # Annotate min and max values
    ax.scatter(np.argmin(peaks), min_peak, color='green', label=f'Min: {min_peak:.2f} {unit}', zorder=3)
    ax.scatter(np.argmax(peaks), max_peak, color='purple', label=f'Max: {max_peak:.2f} {unit}', zorder=3)

    # Labels and title
    ax.set_xlabel("Run Number")
    ax.set_ylabel(metric_with_unit)
    ax.set_title(f"Peak {metric} Across Runs with Variability")
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.plot([], [], ' ', label=f'Coefficient of Variation (CV): {coefficient_of_variation:.2f}%')
    ax.legend()
    plt.savefig(f"../{RELATIVE_OUT_DIR}/peak_{snake_cased_metric}_across_runs_{suffix}.pdf")
    plt.show()

    # Histogram to visualize distribution
    plt.figure(figsize=(8, 4))
    sns.histplot(peaks, bins=10, kde=True, color='r', alpha=0.7)
    plt.axvline(mean_peak, color='b', linestyle='--', label=f'Mean: {mean_peak:.2f} {unit}')
    plt.axvline(median_peak, color='g', linestyle='--', label=f'Median: {median_peak:.2f} {unit}')
    plt.xlabel(f"Peak {metric_with_unit}")
    plt.ylabel("Frequency")
    plt.title(f"Distribution of Peak {metric}")
    plt.legend()
    plt.savefig(f"../{RELATIVE_OUT_DIR}/distribution_of_peak_{snake_cased_metric}_{suffix}.pdf")
    plt.show()


plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="first_run_bias")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="first_run_bias")
plot_variability(peak_major_page_faults_history, "Major Page Faults", suffix="first_run_bias")
# Out:
# /var/folders/sl/3td2vnj56c38q77xf6_s8qrr0000gn/T/ipykernel_50379/763330323.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   coefficient_of_variation = (std_dev_peak / mean_peak) * 100

# %% [markdown]
# As we can see, for some reason even that we're running on Docker containers, we see a different memory usage pattern on the first runs, increasing after each iteration.
# Also, we see that the amount of page faults decreases after each iteration.
#
# This can be happening due to numerous reasons:
#
# ### JIT (Just-In-Time) Compilation
# Since the code relies on libraries like NumPy or Pandas, these libraries may compile optimized code during the first run, leading to increased memory usage in subsequent runs.
# The first run may be loading only necessary components, while subsequent runs may use cached compiled versions, leading to increased memory.
#
# References:
# - [Python 3.13 gets a JIT](https://tonybaloney.github.io/posts/python-gets-a-jit.html)
#
# ### Memory Fragmentation in Docker
# Even though each run happens in an isolated Docker container, the underlying host OS manages memory allocation.
# If the first container execution does not request a lot of memory, it may get a fresh, contiguous memory block.
# Later executions might be assigned more fragmented memory, leading to slightly higher peak memory usage due to additional memory allocation overhead.
#
# References:
# - [Container memory usage keeps on increasing until it gets OOM killed](https://www.reddit.com/r/docker/comments/10rpdn3/container_memory_usage_keeps_on_increasing_until/)
# - [Docker memory usage and how processes running inside containers see it](https://forums.docker.com/t/docker-memory-usage-and-how-processes-running-inside-containers-see-it/90660)
# - [Memory not being cleared within Docker container after job is finished](https://github.com/agronholm/apscheduler/issues/600)
#
# ### Kernel Page Caching and OS-Level Effects
# The Linux kernel aggressively caches frequently accessed data in RAM.
# On the first run, the container might load libraries from disk (low memory usage).
# On subsequent runs, those libraries and data might be cached in RAM, causing the OS to report a higher peak memory usage.
#
# References:
# - [Percent memory usage of containers after reboot](https://forums.docker.com/t/percent-memory-usage-of-containers-after-reboot/140668)
# - [Docker memory usage hitting 100% and Unraid slow to respond](https://forums.unraid.net/topic/157432-docker-memory-usage-hitting-100-and-unraid-slow-to-respond/)

# %% [markdown]
# We have a few possible startegies to try to mitigate this issue:
#
# 1. Bypass page caching
# 2. Explicitly dropping page caching
# 3. Forcing GC to be used
# 4. Forcing the container to always use the same CPU
#
# We will try those in sequence, until we find one that works.

# %% [markdown]
# We will start by trying to bypass page cache.
# Docker provides the option to use the `vfs` storage driver, which does the following:
#
# - Bypass page caching
# - Prevents copy-on-write (COW) issues
# - Is cross-platform
# - Allows filesystem isolation
#
# [Reference](https://docs.docker.com/engine/storage/drivers/vfs-driver/)
#
# So, we're going to use `vfs` and test using it

# %%
import subprocess
import time
import os

DIND_CONTAINER_NAME = "vfs-dind"
HOST_OUT_DIR = os.path.abspath(f"../{RELATIVE_OUT_DIR}")

logger.info("Starting VFS Docker daemon...")
vfs_container = client.containers.run(
    image="docker:dind",
    name=DIND_CONTAINER_NAME,
    auto_remove=True,
    privileged=True,
    detach=True,
    ports={
        "2375/tcp": 2375
    },
    command=[
        "--storage-driver=vfs"
    ],
    environment={
        "DOCKER_TLS_CERTDIR": "",
    },
    volumes={
        os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
            "bind": "/mnt/out",
            "mode": "rw",
        }
    },
)

logger.info("Waiting for dockerd to start...")
time.sleep(5)

for _ in range(10):
    try:
        subprocess.run(["docker", "-H", "tcp://localhost:2375", "info"], check=True)
        logger.info("dockerd inside dind is fully operational.")
        break
    except subprocess.CalledProcessError:
        logger.info("Waiting for dockerd to start...")
        time.sleep(5)

vfs_client = docker.DockerClient(base_url="tcp://localhost:2375")

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)
logger.info("Experiment image built successfully.")

iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}-with-vfs.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}-with-vfs.log"

    logger.info(f"Iteration {i + 1}/{iterations}")

    experiment_container = vfs_client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            "/mnt/out": {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))

vfs_container.stop()

plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="using_vfs")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="using_vfs")
# Out:
# 2025-05-09 00:28:53.118 | INFO     | __main__:<module>:8 - Starting VFS Docker daemon...
# 2025-05-09 00:28:53.354 | INFO     | __main__:<module>:32 - Waiting for dockerd to start...
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60194->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:28:58.709 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60203->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:29:03.802 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60217->[::1]:2375: read: connection reset by peer
# 2025-05-09 00:29:08.880 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# [DEPRECATION NOTICE]: API is accessible on http://0.0.0.0:2375 without encryption.
#          Access to the remote API is equivalent to root access on the host. Refer
#          to the 'Docker daemon attack surface' section in the documentation for
#          more information: https://docs.docker.com/go/attack-surface/
# In future versions this will be a hard failure preventing the daemon from starting! Learn more at: https://docs.docker.com/go/api-security/
# 2025-05-09 00:29:13.995 | INFO     | __main__:<module>:38 - dockerd inside dind is fully operational.
# 2025-05-09 00:29:14.004 | INFO     | __main__:<module>:46 - Building experiment image...
# 2025-05-09 00:29:14.004 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 0
#  Server Version: 28.1.1
#  Storage Driver: vfs
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.6-0-ge89a299
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Alpine Linux v3.21 (containerized)
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 16
#  Total Memory: 30.91GiB
#  Name: ee59abf54f34
#  ID: 67ab4a37-ae35-4a90-b154-c06b7b60fa4a
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false
#  Product License: Community Engine
# 2025-05-09 00:29:37.538 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 00:29:37.539 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 00:31:10.356 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 00:31:10.359 | INFO     | __main__:<module>:48 - Experiment image built successfully.
# 2025-05-09 00:31:10.363 | INFO     | __main__:<module>:63 - Iteration 1/30
# 2025-05-09 00:31:20.208 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0-with-vfs.log
# 2025-05-09 00:31:20.211 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0-with-vfs.log
# 2025-05-09 00:31:20.214 | INFO     | __main__:<module>:107 - Peak memory usage: 5.9720458984375 GB
# 2025-05-09 00:31:20.214 | INFO     | __main__:<module>:108 - Peak minor page faults: 77218
# 2025-05-09 00:31:20.214 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:20.214 | INFO     | __main__:<module>:63 - Iteration 2/30
# 2025-05-09 00:31:27.212 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1-with-vfs.log
# 2025-05-09 00:31:27.215 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1-with-vfs.log
# 2025-05-09 00:31:27.217 | INFO     | __main__:<module>:107 - Peak memory usage: 5.953365325927734 GB
# 2025-05-09 00:31:27.218 | INFO     | __main__:<module>:108 - Peak minor page faults: 64956
# 2025-05-09 00:31:27.218 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:27.218 | INFO     | __main__:<module>:63 - Iteration 3/30
# 2025-05-09 00:31:33.270 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2-with-vfs.log
# 2025-05-09 00:31:33.272 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2-with-vfs.log
# 2025-05-09 00:31:33.274 | INFO     | __main__:<module>:107 - Peak memory usage: 5.9943695068359375 GB
# 2025-05-09 00:31:33.275 | INFO     | __main__:<module>:108 - Peak minor page faults: 39921
# 2025-05-09 00:31:33.276 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:33.276 | INFO     | __main__:<module>:63 - Iteration 4/30
# 2025-05-09 00:31:38.541 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3-with-vfs.log
# 2025-05-09 00:31:38.545 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3-with-vfs.log
# 2025-05-09 00:31:38.547 | INFO     | __main__:<module>:107 - Peak memory usage: 6.0049896240234375 GB
# 2025-05-09 00:31:38.548 | INFO     | __main__:<module>:108 - Peak minor page faults: 39923
# 2025-05-09 00:31:38.549 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:38.549 | INFO     | __main__:<module>:63 - Iteration 5/30
# 2025-05-09 00:31:44.589 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4-with-vfs.log
# 2025-05-09 00:31:44.592 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4-with-vfs.log
# 2025-05-09 00:31:44.594 | INFO     | __main__:<module>:107 - Peak memory usage: 5.998889923095703 GB
# 2025-05-09 00:31:44.594 | INFO     | __main__:<module>:108 - Peak minor page faults: 44530
# 2025-05-09 00:31:44.595 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:44.595 | INFO     | __main__:<module>:63 - Iteration 6/30
# 2025-05-09 00:31:50.215 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5-with-vfs.log
# 2025-05-09 00:31:50.218 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5-with-vfs.log
# 2025-05-09 00:31:50.221 | INFO     | __main__:<module>:107 - Peak memory usage: 6.0159149169921875 GB
# 2025-05-09 00:31:50.222 | INFO     | __main__:<module>:108 - Peak minor page faults: 30740
# 2025-05-09 00:31:50.222 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:50.223 | INFO     | __main__:<module>:63 - Iteration 7/30
# 2025-05-09 00:31:56.086 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6-with-vfs.log
# 2025-05-09 00:31:56.089 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6-with-vfs.log
# 2025-05-09 00:31:56.090 | INFO     | __main__:<module>:107 - Peak memory usage: 6.001949310302734 GB
# 2025-05-09 00:31:56.091 | INFO     | __main__:<module>:108 - Peak minor page faults: 48116
# 2025-05-09 00:31:56.092 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:31:56.092 | INFO     | __main__:<module>:63 - Iteration 8/30
# 2025-05-09 00:32:01.597 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7-with-vfs.log
# 2025-05-09 00:32:01.600 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7-with-vfs.log
# 2025-05-09 00:32:01.603 | INFO     | __main__:<module>:107 - Peak memory usage: 6.027454376220703 GB
# 2025-05-09 00:32:01.604 | INFO     | __main__:<module>:108 - Peak minor page faults: 30737
# 2025-05-09 00:32:01.606 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:01.607 | INFO     | __main__:<module>:63 - Iteration 9/30
# 2025-05-09 00:32:07.035 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8-with-vfs.log
# 2025-05-09 00:32:07.038 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8-with-vfs.log
# 2025-05-09 00:32:07.041 | INFO     | __main__:<module>:107 - Peak memory usage: 6.004650115966797 GB
# 2025-05-09 00:32:07.042 | INFO     | __main__:<module>:108 - Peak minor page faults: 30734
# 2025-05-09 00:32:07.042 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:07.043 | INFO     | __main__:<module>:63 - Iteration 10/30
# 2025-05-09 00:32:17.411 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9-with-vfs.log
# 2025-05-09 00:32:17.417 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9-with-vfs.log
# 2025-05-09 00:32:17.425 | INFO     | __main__:<module>:107 - Peak memory usage: 6.0028533935546875 GB
# 2025-05-09 00:32:17.426 | INFO     | __main__:<module>:108 - Peak minor page faults: 40957
# 2025-05-09 00:32:17.426 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:17.427 | INFO     | __main__:<module>:63 - Iteration 11/30
# 2025-05-09 00:32:29.014 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10-with-vfs.log
# 2025-05-09 00:32:29.020 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10-with-vfs.log
# 2025-05-09 00:32:29.024 | INFO     | __main__:<module>:107 - Peak memory usage: 6.022426605224609 GB
# 2025-05-09 00:32:29.025 | INFO     | __main__:<module>:108 - Peak minor page faults: 30736
# 2025-05-09 00:32:29.025 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:29.026 | INFO     | __main__:<module>:63 - Iteration 12/30
# 2025-05-09 00:32:39.866 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11-with-vfs.log
# 2025-05-09 00:32:39.879 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11-with-vfs.log
# 2025-05-09 00:32:39.881 | INFO     | __main__:<module>:107 - Peak memory usage: 6.027561187744141 GB
# 2025-05-09 00:32:39.882 | INFO     | __main__:<module>:108 - Peak minor page faults: 30738
# 2025-05-09 00:32:39.882 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:39.882 | INFO     | __main__:<module>:63 - Iteration 13/30
# 2025-05-09 00:32:51.758 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12-with-vfs.log
# 2025-05-09 00:32:51.765 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12-with-vfs.log
# 2025-05-09 00:32:51.767 | INFO     | __main__:<module>:107 - Peak memory usage: 6.02313232421875 GB
# 2025-05-09 00:32:51.768 | INFO     | __main__:<module>:108 - Peak minor page faults: 30736
# 2025-05-09 00:32:51.768 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:32:51.769 | INFO     | __main__:<module>:63 - Iteration 14/30
# 2025-05-09 00:33:02.334 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13-with-vfs.log
# 2025-05-09 00:33:02.349 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13-with-vfs.log
# 2025-05-09 00:33:02.351 | INFO     | __main__:<module>:107 - Peak memory usage: 6.026451110839844 GB
# 2025-05-09 00:33:02.352 | INFO     | __main__:<module>:108 - Peak minor page faults: 30724
# 2025-05-09 00:33:02.352 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:02.352 | INFO     | __main__:<module>:63 - Iteration 15/30
# 2025-05-09 00:33:12.959 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14-with-vfs.log
# 2025-05-09 00:33:12.980 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14-with-vfs.log
# 2025-05-09 00:33:12.987 | INFO     | __main__:<module>:107 - Peak memory usage: 6.020503997802734 GB
# 2025-05-09 00:33:12.987 | INFO     | __main__:<module>:108 - Peak minor page faults: 30738
# 2025-05-09 00:33:12.991 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:12.991 | INFO     | __main__:<module>:63 - Iteration 16/30
# 2025-05-09 00:33:25.197 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15-with-vfs.log
# 2025-05-09 00:33:25.202 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15-with-vfs.log
# 2025-05-09 00:33:25.205 | INFO     | __main__:<module>:107 - Peak memory usage: 6.017902374267578 GB
# 2025-05-09 00:33:25.205 | INFO     | __main__:<module>:108 - Peak minor page faults: 30736
# 2025-05-09 00:33:25.205 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:25.206 | INFO     | __main__:<module>:63 - Iteration 17/30
# 2025-05-09 00:33:35.603 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16-with-vfs.log
# 2025-05-09 00:33:35.615 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16-with-vfs.log
# 2025-05-09 00:33:35.618 | INFO     | __main__:<module>:107 - Peak memory usage: 6.023349761962891 GB
# 2025-05-09 00:33:35.619 | INFO     | __main__:<module>:108 - Peak minor page faults: 30732
# 2025-05-09 00:33:35.619 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:35.620 | INFO     | __main__:<module>:63 - Iteration 18/30
# 2025-05-09 00:33:46.335 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17-with-vfs.log
# 2025-05-09 00:33:46.345 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17-with-vfs.log
# 2025-05-09 00:33:46.348 | INFO     | __main__:<module>:107 - Peak memory usage: 6.02313232421875 GB
# 2025-05-09 00:33:46.348 | INFO     | __main__:<module>:108 - Peak minor page faults: 32268
# 2025-05-09 00:33:46.348 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:46.349 | INFO     | __main__:<module>:63 - Iteration 19/30
# 2025-05-09 00:33:56.780 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18-with-vfs.log
# 2025-05-09 00:33:56.788 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18-with-vfs.log
# 2025-05-09 00:33:56.795 | INFO     | __main__:<module>:107 - Peak memory usage: 6.024955749511719 GB
# 2025-05-09 00:33:56.796 | INFO     | __main__:<module>:108 - Peak minor page faults: 30732
# 2025-05-09 00:33:56.796 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:33:56.797 | INFO     | __main__:<module>:63 - Iteration 20/30
# 2025-05-09 00:34:07.035 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19-with-vfs.log
# 2025-05-09 00:34:07.042 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19-with-vfs.log
# 2025-05-09 00:34:07.045 | INFO     | __main__:<module>:107 - Peak memory usage: 6.0213165283203125 GB
# 2025-05-09 00:34:07.046 | INFO     | __main__:<module>:108 - Peak minor page faults: 30740
# 2025-05-09 00:34:07.046 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:07.046 | INFO     | __main__:<module>:63 - Iteration 21/30
# 2025-05-09 00:34:17.400 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20-with-vfs.log
# 2025-05-09 00:34:17.411 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20-with-vfs.log
# 2025-05-09 00:34:17.425 | INFO     | __main__:<module>:107 - Peak memory usage: 6.025798797607422 GB
# 2025-05-09 00:34:17.425 | INFO     | __main__:<module>:108 - Peak minor page faults: 30740
# 2025-05-09 00:34:17.426 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:17.426 | INFO     | __main__:<module>:63 - Iteration 22/30
# 2025-05-09 00:34:27.219 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21-with-vfs.log
# 2025-05-09 00:34:27.232 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21-with-vfs.log
# 2025-05-09 00:34:27.236 | INFO     | __main__:<module>:107 - Peak memory usage: 6.022666931152344 GB
# 2025-05-09 00:34:27.236 | INFO     | __main__:<module>:108 - Peak minor page faults: 30740
# 2025-05-09 00:34:27.237 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:27.237 | INFO     | __main__:<module>:63 - Iteration 23/30
# 2025-05-09 00:34:37.441 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22-with-vfs.log
# 2025-05-09 00:34:37.460 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22-with-vfs.log
# 2025-05-09 00:34:37.465 | INFO     | __main__:<module>:107 - Peak memory usage: 6.0240020751953125 GB
# 2025-05-09 00:34:37.466 | INFO     | __main__:<module>:108 - Peak minor page faults: 30739
# 2025-05-09 00:34:37.466 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:37.466 | INFO     | __main__:<module>:63 - Iteration 24/30
# 2025-05-09 00:34:47.148 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23-with-vfs.log
# 2025-05-09 00:34:47.152 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23-with-vfs.log
# 2025-05-09 00:34:47.154 | INFO     | __main__:<module>:107 - Peak memory usage: 6.006137847900391 GB
# 2025-05-09 00:34:47.155 | INFO     | __main__:<module>:108 - Peak minor page faults: 30735
# 2025-05-09 00:34:47.155 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:47.156 | INFO     | __main__:<module>:63 - Iteration 25/30
# 2025-05-09 00:34:53.518 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24-with-vfs.log
# 2025-05-09 00:34:53.520 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24-with-vfs.log
# 2025-05-09 00:34:53.522 | INFO     | __main__:<module>:107 - Peak memory usage: 6.025657653808594 GB
# 2025-05-09 00:34:53.523 | INFO     | __main__:<module>:108 - Peak minor page faults: 30732
# 2025-05-09 00:34:53.523 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:34:53.524 | INFO     | __main__:<module>:63 - Iteration 26/30
# 2025-05-09 00:35:02.219 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25-with-vfs.log
# 2025-05-09 00:35:02.230 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25-with-vfs.log
# 2025-05-09 00:35:02.236 | INFO     | __main__:<module>:107 - Peak memory usage: 6.011272430419922 GB
# 2025-05-09 00:35:02.236 | INFO     | __main__:<module>:108 - Peak minor page faults: 30728
# 2025-05-09 00:35:02.236 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:35:02.236 | INFO     | __main__:<module>:63 - Iteration 27/30
# 2025-05-09 00:35:12.957 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26-with-vfs.log
# 2025-05-09 00:35:12.966 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26-with-vfs.log
# 2025-05-09 00:35:12.968 | INFO     | __main__:<module>:107 - Peak memory usage: 6.029502868652344 GB
# 2025-05-09 00:35:12.969 | INFO     | __main__:<module>:108 - Peak minor page faults: 30738
# 2025-05-09 00:35:12.969 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:35:12.969 | INFO     | __main__:<module>:63 - Iteration 28/30
# 2025-05-09 00:35:24.667 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27-with-vfs.log
# 2025-05-09 00:35:24.722 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27-with-vfs.log
# 2025-05-09 00:35:24.726 | INFO     | __main__:<module>:107 - Peak memory usage: 6.023200988769531 GB
# 2025-05-09 00:35:24.727 | INFO     | __main__:<module>:108 - Peak minor page faults: 30735
# 2025-05-09 00:35:24.727 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:35:24.728 | INFO     | __main__:<module>:63 - Iteration 29/30
# 2025-05-09 00:35:35.383 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28-with-vfs.log
# 2025-05-09 00:35:35.396 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28-with-vfs.log
# 2025-05-09 00:35:35.402 | INFO     | __main__:<module>:107 - Peak memory usage: 6.015270233154297 GB
# 2025-05-09 00:35:35.402 | INFO     | __main__:<module>:108 - Peak minor page faults: 30733
# 2025-05-09 00:35:35.403 | INFO     | __main__:<module>:109 - Peak major page faults: 0
# 2025-05-09 00:35:35.403 | INFO     | __main__:<module>:63 - Iteration 30/30
# 2025-05-09 00:35:44.991 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29-with-vfs.log
# 2025-05-09 00:35:45.013 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29-with-vfs.log
# 2025-05-09 00:35:45.016 | INFO     | __main__:<module>:107 - Peak memory usage: 6.025669097900391 GB
# 2025-05-09 00:35:45.016 | INFO     | __main__:<module>:108 - Peak minor page faults: 30734
# 2025-05-09 00:35:45.016 | INFO     | __main__:<module>:109 - Peak major page faults: 0

# %% [markdown]
# Based on the results, we can see that it wasn't effective.
# We can still see the same pattern, of the page faults decreasing after the first few iterations.
# We can now try explicitly dropping the page cache.

# %%
import subprocess
import time
import os


def drop_caches_in_dind():
    dind_container_id = subprocess.run(
        ["docker", "ps", "-q", "--filter", "ancestor=docker:dind"],
        capture_output=True, text=True
    ).stdout.strip()

    if not dind_container_id:
        logger.error("DinD container not found")
        return

    drop_cmd = f"docker exec {dind_container_id} sh -c 'sync && echo 3 > /proc/sys/vm/drop_caches'"
    subprocess.run(drop_cmd, shell=True, check=True)
    logger.info("Dropped caches inside DinD container")


DIND_CONTAINER_NAME = "vfs-dind"
HOST_OUT_DIR = os.path.abspath(f"../{RELATIVE_OUT_DIR}")

logger.info("Starting VFS Docker daemon...")
vfs_container = client.containers.run(
    image="docker:dind",
    name=DIND_CONTAINER_NAME,
    auto_remove=True,
    privileged=True,
    detach=True,
    ports={
        "2375/tcp": 2375
    },
    command=[
        "--storage-driver=vfs"
    ],
    environment={
        "DOCKER_TLS_CERTDIR": "",
    },
    volumes={
        os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
            "bind": "/mnt/out",
            "mode": "rw",
        }
    },
)

logger.info("Waiting for dockerd to start...")
time.sleep(5)

for _ in range(10):
    try:
        subprocess.run(["docker", "-H", "tcp://localhost:2375", "info"], check=True)
        logger.info("dockerd inside dind is fully operational.")
        break
    except subprocess.CalledProcessError:
        logger.info("Waiting for dockerd to start...")
        time.sleep(5)

vfs_client = docker.DockerClient(base_url="tcp://localhost:2375")

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)
logger.info("Experiment image built successfully.")

iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}-without-page-caching.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}-without-page-caching.log"

    drop_caches_in_dind()

    logger.info(f"Iteration {i + 1}/{iterations}")

    experiment_container = vfs_client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            "/mnt/out": {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))

vfs_container.stop()

plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="dropping_page_cache")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="dropping_page_cache")
# Out:
# 2025-05-09 00:36:36.266 | INFO     | __main__:<module>:24 - Starting VFS Docker daemon...
# 2025-05-09 00:36:36.596 | INFO     | __main__:<module>:48 - Waiting for dockerd to start...
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:61333->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:36:42.013 | INFO     | __main__:<module>:57 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:61342->[::1]:2375: read: connection reset by peer
# 2025-05-09 00:36:47.093 | INFO     | __main__:<module>:57 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:61357->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:36:52.179 | INFO     | __main__:<module>:57 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# [DEPRECATION NOTICE]: API is accessible on http://0.0.0.0:2375 without encryption.
#          Access to the remote API is equivalent to root access on the host. Refer
#          to the 'Docker daemon attack surface' section in the documentation for
#          more information: https://docs.docker.com/go/attack-surface/
# In future versions this will be a hard failure preventing the daemon from starting! Learn more at: https://docs.docker.com/go/api-security/
# 2025-05-09 00:36:57.301 | INFO     | __main__:<module>:54 - dockerd inside dind is fully operational.
# 2025-05-09 00:36:57.315 | INFO     | __main__:<module>:62 - Building experiment image...
# 2025-05-09 00:36:57.315 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 0
#  Server Version: 28.1.1
#  Storage Driver: vfs
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: runc io.containerd.runc.v2
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.6-0-ge89a299
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Alpine Linux v3.21 (containerized)
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 16
#  Total Memory: 30.91GiB
#  Name: e173d9e339f4
#  ID: 8d7dcf95-ade5-45e4-b1f0-506e3dd1febe
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false
#  Product License: Community Engine
# 2025-05-09 00:37:21.811 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 00:37:21.813 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 00:38:58.643 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 00:38:58.646 | INFO     | __main__:<module>:64 - Experiment image built successfully.
# 2025-05-09 00:39:08.832 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:08.835 | INFO     | __main__:<module>:81 - Iteration 1/30
# 2025-05-09 00:39:18.809 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0-without-page-caching.log
# 2025-05-09 00:39:18.815 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0-without-page-caching.log
# 2025-05-09 00:39:18.818 | INFO     | __main__:<module>:125 - Peak memory usage: 6.026332855224609 GB
# 2025-05-09 00:39:18.819 | INFO     | __main__:<module>:126 - Peak minor page faults: 30732
# 2025-05-09 00:39:18.820 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:19.376 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:19.378 | INFO     | __main__:<module>:81 - Iteration 2/30
# 2025-05-09 00:39:25.848 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1-without-page-caching.log
# 2025-05-09 00:39:25.852 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1-without-page-caching.log
# 2025-05-09 00:39:25.854 | INFO     | __main__:<module>:125 - Peak memory usage: 6.004444122314453 GB
# 2025-05-09 00:39:25.855 | INFO     | __main__:<module>:126 - Peak minor page faults: 30717
# 2025-05-09 00:39:25.855 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:26.346 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:26.347 | INFO     | __main__:<module>:81 - Iteration 3/30
# 2025-05-09 00:39:35.895 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2-without-page-caching.log
# 2025-05-09 00:39:35.900 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2-without-page-caching.log
# 2025-05-09 00:39:35.909 | INFO     | __main__:<module>:125 - Peak memory usage: 6.022907257080078 GB
# 2025-05-09 00:39:35.913 | INFO     | __main__:<module>:126 - Peak minor page faults: 30719
# 2025-05-09 00:39:35.916 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:36.476 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:36.478 | INFO     | __main__:<module>:81 - Iteration 4/30
# 2025-05-09 00:39:42.848 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3-without-page-caching.log
# 2025-05-09 00:39:42.852 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3-without-page-caching.log
# 2025-05-09 00:39:42.856 | INFO     | __main__:<module>:125 - Peak memory usage: 6.017921447753906 GB
# 2025-05-09 00:39:42.857 | INFO     | __main__:<module>:126 - Peak minor page faults: 30721
# 2025-05-09 00:39:42.858 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:43.649 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:43.650 | INFO     | __main__:<module>:81 - Iteration 5/30
# 2025-05-09 00:39:50.258 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4-without-page-caching.log
# 2025-05-09 00:39:50.265 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4-without-page-caching.log
# 2025-05-09 00:39:50.268 | INFO     | __main__:<module>:125 - Peak memory usage: 6.022991180419922 GB
# 2025-05-09 00:39:50.269 | INFO     | __main__:<module>:126 - Peak minor page faults: 30718
# 2025-05-09 00:39:50.269 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:50.788 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:50.790 | INFO     | __main__:<module>:81 - Iteration 6/30
# 2025-05-09 00:39:56.773 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5-without-page-caching.log
# 2025-05-09 00:39:56.775 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5-without-page-caching.log
# 2025-05-09 00:39:56.775 | INFO     | __main__:<module>:125 - Peak memory usage: 6.024497985839844 GB
# 2025-05-09 00:39:56.776 | INFO     | __main__:<module>:126 - Peak minor page faults: 30724
# 2025-05-09 00:39:56.776 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:39:57.363 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:39:57.365 | INFO     | __main__:<module>:81 - Iteration 7/30
# 2025-05-09 00:40:03.612 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6-without-page-caching.log
# 2025-05-09 00:40:03.617 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6-without-page-caching.log
# 2025-05-09 00:40:03.622 | INFO     | __main__:<module>:125 - Peak memory usage: 6.022556304931641 GB
# 2025-05-09 00:40:03.623 | INFO     | __main__:<module>:126 - Peak minor page faults: 30718
# 2025-05-09 00:40:03.624 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:04.065 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:04.067 | INFO     | __main__:<module>:81 - Iteration 8/30
# 2025-05-09 00:40:17.777 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7-without-page-caching.log
# 2025-05-09 00:40:17.786 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7-without-page-caching.log
# 2025-05-09 00:40:17.790 | INFO     | __main__:<module>:125 - Peak memory usage: 6.028018951416016 GB
# 2025-05-09 00:40:17.791 | INFO     | __main__:<module>:126 - Peak minor page faults: 30740
# 2025-05-09 00:40:17.792 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:18.559 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:18.561 | INFO     | __main__:<module>:81 - Iteration 9/30
# 2025-05-09 00:40:25.837 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8-without-page-caching.log
# 2025-05-09 00:40:25.840 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8-without-page-caching.log
# 2025-05-09 00:40:25.842 | INFO     | __main__:<module>:125 - Peak memory usage: 6.0272979736328125 GB
# 2025-05-09 00:40:25.842 | INFO     | __main__:<module>:126 - Peak minor page faults: 30733
# 2025-05-09 00:40:25.843 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:26.310 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:26.312 | INFO     | __main__:<module>:81 - Iteration 10/30
# 2025-05-09 00:40:32.775 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9-without-page-caching.log
# 2025-05-09 00:40:32.779 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9-without-page-caching.log
# 2025-05-09 00:40:32.781 | INFO     | __main__:<module>:125 - Peak memory usage: 5.9981842041015625 GB
# 2025-05-09 00:40:32.782 | INFO     | __main__:<module>:126 - Peak minor page faults: 30719
# 2025-05-09 00:40:32.783 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:33.386 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:33.388 | INFO     | __main__:<module>:81 - Iteration 11/30
# 2025-05-09 00:40:42.102 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10-without-page-caching.log
# 2025-05-09 00:40:42.105 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10-without-page-caching.log
# 2025-05-09 00:40:42.107 | INFO     | __main__:<module>:125 - Peak memory usage: 6.017299652099609 GB
# 2025-05-09 00:40:42.107 | INFO     | __main__:<module>:126 - Peak minor page faults: 30723
# 2025-05-09 00:40:42.107 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:42.684 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:42.686 | INFO     | __main__:<module>:81 - Iteration 12/30
# 2025-05-09 00:40:49.762 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11-without-page-caching.log
# 2025-05-09 00:40:49.766 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11-without-page-caching.log
# 2025-05-09 00:40:49.768 | INFO     | __main__:<module>:125 - Peak memory usage: 6.0054931640625 GB
# 2025-05-09 00:40:49.769 | INFO     | __main__:<module>:126 - Peak minor page faults: 30716
# 2025-05-09 00:40:49.769 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:50.257 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:50.258 | INFO     | __main__:<module>:81 - Iteration 13/30
# 2025-05-09 00:40:56.248 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12-without-page-caching.log
# 2025-05-09 00:40:56.251 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12-without-page-caching.log
# 2025-05-09 00:40:56.253 | INFO     | __main__:<module>:125 - Peak memory usage: 5.985984802246094 GB
# 2025-05-09 00:40:56.254 | INFO     | __main__:<module>:126 - Peak minor page faults: 30716
# 2025-05-09 00:40:56.254 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:40:56.710 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:40:56.712 | INFO     | __main__:<module>:81 - Iteration 14/30
# 2025-05-09 00:41:02.730 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13-without-page-caching.log
# 2025-05-09 00:41:02.734 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13-without-page-caching.log
# 2025-05-09 00:41:02.736 | INFO     | __main__:<module>:125 - Peak memory usage: 5.998210906982422 GB
# 2025-05-09 00:41:02.737 | INFO     | __main__:<module>:126 - Peak minor page faults: 30720
# 2025-05-09 00:41:02.737 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:03.216 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:03.218 | INFO     | __main__:<module>:81 - Iteration 15/30
# 2025-05-09 00:41:09.259 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14-without-page-caching.log
# 2025-05-09 00:41:09.262 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14-without-page-caching.log
# 2025-05-09 00:41:09.265 | INFO     | __main__:<module>:125 - Peak memory usage: 5.996818542480469 GB
# 2025-05-09 00:41:09.265 | INFO     | __main__:<module>:126 - Peak minor page faults: 30718
# 2025-05-09 00:41:09.266 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:09.853 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:09.855 | INFO     | __main__:<module>:81 - Iteration 16/30
# 2025-05-09 00:41:16.319 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15-without-page-caching.log
# 2025-05-09 00:41:16.322 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15-without-page-caching.log
# 2025-05-09 00:41:16.324 | INFO     | __main__:<module>:125 - Peak memory usage: 6.008934020996094 GB
# 2025-05-09 00:41:16.325 | INFO     | __main__:<module>:126 - Peak minor page faults: 30725
# 2025-05-09 00:41:16.325 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:16.795 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:16.797 | INFO     | __main__:<module>:81 - Iteration 17/30
# 2025-05-09 00:41:22.804 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16-without-page-caching.log
# 2025-05-09 00:41:22.807 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16-without-page-caching.log
# 2025-05-09 00:41:22.810 | INFO     | __main__:<module>:125 - Peak memory usage: 5.980411529541016 GB
# 2025-05-09 00:41:22.810 | INFO     | __main__:<module>:126 - Peak minor page faults: 30718
# 2025-05-09 00:41:22.810 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:23.395 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:23.397 | INFO     | __main__:<module>:81 - Iteration 18/30
# 2025-05-09 00:41:29.741 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17-without-page-caching.log
# 2025-05-09 00:41:29.744 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17-without-page-caching.log
# 2025-05-09 00:41:29.746 | INFO     | __main__:<module>:125 - Peak memory usage: 5.99127197265625 GB
# 2025-05-09 00:41:29.747 | INFO     | __main__:<module>:126 - Peak minor page faults: 30715
# 2025-05-09 00:41:29.748 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:30.225 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:30.226 | INFO     | __main__:<module>:81 - Iteration 19/30
# 2025-05-09 00:41:36.125 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18-without-page-caching.log
# 2025-05-09 00:41:36.128 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18-without-page-caching.log
# 2025-05-09 00:41:36.130 | INFO     | __main__:<module>:125 - Peak memory usage: 6.022487640380859 GB
# 2025-05-09 00:41:36.131 | INFO     | __main__:<module>:126 - Peak minor page faults: 30731
# 2025-05-09 00:41:36.131 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:36.633 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:36.635 | INFO     | __main__:<module>:81 - Iteration 20/30
# 2025-05-09 00:41:42.425 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19-without-page-caching.log
# 2025-05-09 00:41:42.428 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19-without-page-caching.log
# 2025-05-09 00:41:42.433 | INFO     | __main__:<module>:125 - Peak memory usage: 6.023151397705078 GB
# 2025-05-09 00:41:42.435 | INFO     | __main__:<module>:126 - Peak minor page faults: 30717
# 2025-05-09 00:41:42.436 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:42.867 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:42.869 | INFO     | __main__:<module>:81 - Iteration 21/30
# 2025-05-09 00:41:49.067 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20-without-page-caching.log
# 2025-05-09 00:41:49.070 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20-without-page-caching.log
# 2025-05-09 00:41:49.073 | INFO     | __main__:<module>:125 - Peak memory usage: 6.028827667236328 GB
# 2025-05-09 00:41:49.074 | INFO     | __main__:<module>:126 - Peak minor page faults: 30741
# 2025-05-09 00:41:49.075 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:49.586 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:49.588 | INFO     | __main__:<module>:81 - Iteration 22/30
# 2025-05-09 00:41:55.650 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21-without-page-caching.log
# 2025-05-09 00:41:55.654 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21-without-page-caching.log
# 2025-05-09 00:41:55.656 | INFO     | __main__:<module>:125 - Peak memory usage: 6.021518707275391 GB
# 2025-05-09 00:41:55.657 | INFO     | __main__:<module>:126 - Peak minor page faults: 30720
# 2025-05-09 00:41:55.657 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:41:56.103 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:41:56.105 | INFO     | __main__:<module>:81 - Iteration 23/30
# 2025-05-09 00:42:02.009 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22-without-page-caching.log
# 2025-05-09 00:42:02.012 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22-without-page-caching.log
# 2025-05-09 00:42:02.014 | INFO     | __main__:<module>:125 - Peak memory usage: 6.002983093261719 GB
# 2025-05-09 00:42:02.014 | INFO     | __main__:<module>:126 - Peak minor page faults: 30732
# 2025-05-09 00:42:02.015 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:02.526 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:02.527 | INFO     | __main__:<module>:81 - Iteration 24/30
# 2025-05-09 00:42:08.663 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23-without-page-caching.log
# 2025-05-09 00:42:08.666 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23-without-page-caching.log
# 2025-05-09 00:42:08.670 | INFO     | __main__:<module>:125 - Peak memory usage: 6.010948181152344 GB
# 2025-05-09 00:42:08.670 | INFO     | __main__:<module>:126 - Peak minor page faults: 30716
# 2025-05-09 00:42:08.671 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:09.259 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:09.260 | INFO     | __main__:<module>:81 - Iteration 25/30
# 2025-05-09 00:42:15.793 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24-without-page-caching.log
# 2025-05-09 00:42:15.796 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24-without-page-caching.log
# 2025-05-09 00:42:15.798 | INFO     | __main__:<module>:125 - Peak memory usage: 5.989997863769531 GB
# 2025-05-09 00:42:15.799 | INFO     | __main__:<module>:126 - Peak minor page faults: 30717
# 2025-05-09 00:42:15.799 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:16.287 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:16.289 | INFO     | __main__:<module>:81 - Iteration 26/30
# 2025-05-09 00:42:22.413 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25-without-page-caching.log
# 2025-05-09 00:42:22.417 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25-without-page-caching.log
# 2025-05-09 00:42:22.420 | INFO     | __main__:<module>:125 - Peak memory usage: 6.0050048828125 GB
# 2025-05-09 00:42:22.420 | INFO     | __main__:<module>:126 - Peak minor page faults: 30724
# 2025-05-09 00:42:22.420 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:22.781 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:22.783 | INFO     | __main__:<module>:81 - Iteration 27/30
# 2025-05-09 00:42:28.983 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26-without-page-caching.log
# 2025-05-09 00:42:28.987 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26-without-page-caching.log
# 2025-05-09 00:42:28.989 | INFO     | __main__:<module>:125 - Peak memory usage: 6.002906799316406 GB
# 2025-05-09 00:42:28.990 | INFO     | __main__:<module>:126 - Peak minor page faults: 30721
# 2025-05-09 00:42:28.990 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:29.448 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:29.449 | INFO     | __main__:<module>:81 - Iteration 28/30
# 2025-05-09 00:42:36.204 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27-without-page-caching.log
# 2025-05-09 00:42:36.207 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27-without-page-caching.log
# 2025-05-09 00:42:36.210 | INFO     | __main__:<module>:125 - Peak memory usage: 6.003246307373047 GB
# 2025-05-09 00:42:36.210 | INFO     | __main__:<module>:126 - Peak minor page faults: 30718
# 2025-05-09 00:42:36.211 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:36.646 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:36.648 | INFO     | __main__:<module>:81 - Iteration 29/30
# 2025-05-09 00:42:42.728 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28-without-page-caching.log
# 2025-05-09 00:42:42.731 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28-without-page-caching.log
# 2025-05-09 00:42:42.733 | INFO     | __main__:<module>:125 - Peak memory usage: 6.013774871826172 GB
# 2025-05-09 00:42:42.733 | INFO     | __main__:<module>:126 - Peak minor page faults: 30725
# 2025-05-09 00:42:42.734 | INFO     | __main__:<module>:127 - Peak major page faults: 0
# 2025-05-09 00:42:43.183 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:42:43.185 | INFO     | __main__:<module>:81 - Iteration 30/30
# 2025-05-09 00:42:49.807 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29-without-page-caching.log
# 2025-05-09 00:42:49.810 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29-without-page-caching.log
# 2025-05-09 00:42:49.812 | INFO     | __main__:<module>:125 - Peak memory usage: 5.994579315185547 GB
# 2025-05-09 00:42:49.813 | INFO     | __main__:<module>:126 - Peak minor page faults: 30716
# 2025-05-09 00:42:49.813 | INFO     | __main__:<module>:127 - Peak major page faults: 0

# %% [markdown]
# As we can see, dropping the page cache changed the pattern.
# We don't see any specific pattern of the page faults dropping after the first few runs.
# Now, we will try to force the garbage collector to run.

# %%
import gc

iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}-garbage-collected.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}-garbage-collected.log"

    logger.info(f"Iteration {i + 1}/{iterations}")

    gc.collect()

    experiment_container = client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))

plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="forcing_gc")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="forcing_gc")
# Out:
# 2025-05-09 00:42:51.480 | INFO     | __main__:<module>:16 - Iteration 1/30
# 2025-05-09 00:42:56.919 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0-garbage-collected.log
# 2025-05-09 00:42:56.921 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0-garbage-collected.log
# 2025-05-09 00:42:56.923 | INFO     | __main__:<module>:62 - Peak memory usage: 6.161571502685547 GB
# 2025-05-09 00:42:56.924 | INFO     | __main__:<module>:63 - Peak minor page faults: 32379
# 2025-05-09 00:42:56.925 | INFO     | __main__:<module>:64 - Peak major page faults: 472
# 2025-05-09 00:42:56.925 | INFO     | __main__:<module>:16 - Iteration 2/30
# 2025-05-09 00:43:01.619 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1-garbage-collected.log
# 2025-05-09 00:43:01.622 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1-garbage-collected.log
# 2025-05-09 00:43:01.624 | INFO     | __main__:<module>:62 - Peak memory usage: 6.017223358154297 GB
# 2025-05-09 00:43:01.624 | INFO     | __main__:<module>:63 - Peak minor page faults: 32427
# 2025-05-09 00:43:01.625 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:01.625 | INFO     | __main__:<module>:16 - Iteration 3/30
# 2025-05-09 00:43:05.936 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2-garbage-collected.log
# 2025-05-09 00:43:05.938 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2-garbage-collected.log
# 2025-05-09 00:43:05.940 | INFO     | __main__:<module>:62 - Peak memory usage: 5.998493194580078 GB
# 2025-05-09 00:43:05.940 | INFO     | __main__:<module>:63 - Peak minor page faults: 32431
# 2025-05-09 00:43:05.941 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:05.941 | INFO     | __main__:<module>:16 - Iteration 4/30
# 2025-05-09 00:43:10.329 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3-garbage-collected.log
# 2025-05-09 00:43:10.331 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3-garbage-collected.log
# 2025-05-09 00:43:10.333 | INFO     | __main__:<module>:62 - Peak memory usage: 5.996089935302734 GB
# 2025-05-09 00:43:10.334 | INFO     | __main__:<module>:63 - Peak minor page faults: 32424
# 2025-05-09 00:43:10.334 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:10.335 | INFO     | __main__:<module>:16 - Iteration 5/30
# 2025-05-09 00:43:14.775 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4-garbage-collected.log
# 2025-05-09 00:43:14.776 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4-garbage-collected.log
# 2025-05-09 00:43:14.777 | INFO     | __main__:<module>:62 - Peak memory usage: 5.992069244384766 GB
# 2025-05-09 00:43:14.778 | INFO     | __main__:<module>:63 - Peak minor page faults: 32443
# 2025-05-09 00:43:14.778 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:14.778 | INFO     | __main__:<module>:16 - Iteration 6/30
# 2025-05-09 00:43:19.344 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5-garbage-collected.log
# 2025-05-09 00:43:19.347 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5-garbage-collected.log
# 2025-05-09 00:43:19.348 | INFO     | __main__:<module>:62 - Peak memory usage: 6.026329040527344 GB
# 2025-05-09 00:43:19.349 | INFO     | __main__:<module>:63 - Peak minor page faults: 32428
# 2025-05-09 00:43:19.349 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:19.350 | INFO     | __main__:<module>:16 - Iteration 7/30
# 2025-05-09 00:43:23.945 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6-garbage-collected.log
# 2025-05-09 00:43:23.947 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6-garbage-collected.log
# 2025-05-09 00:43:23.949 | INFO     | __main__:<module>:62 - Peak memory usage: 6.019237518310547 GB
# 2025-05-09 00:43:23.949 | INFO     | __main__:<module>:63 - Peak minor page faults: 32438
# 2025-05-09 00:43:23.950 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:23.950 | INFO     | __main__:<module>:16 - Iteration 8/30
# 2025-05-09 00:43:28.654 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7-garbage-collected.log
# 2025-05-09 00:43:28.656 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7-garbage-collected.log
# 2025-05-09 00:43:28.658 | INFO     | __main__:<module>:62 - Peak memory usage: 5.973957061767578 GB
# 2025-05-09 00:43:28.659 | INFO     | __main__:<module>:63 - Peak minor page faults: 32426
# 2025-05-09 00:43:28.660 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:28.661 | INFO     | __main__:<module>:16 - Iteration 9/30
# 2025-05-09 00:43:34.157 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8-garbage-collected.log
# 2025-05-09 00:43:34.159 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8-garbage-collected.log
# 2025-05-09 00:43:34.160 | INFO     | __main__:<module>:62 - Peak memory usage: 5.9911956787109375 GB
# 2025-05-09 00:43:34.161 | INFO     | __main__:<module>:63 - Peak minor page faults: 32447
# 2025-05-09 00:43:34.161 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:34.162 | INFO     | __main__:<module>:16 - Iteration 10/30
# 2025-05-09 00:43:38.954 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9-garbage-collected.log
# 2025-05-09 00:43:38.955 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9-garbage-collected.log
# 2025-05-09 00:43:38.958 | INFO     | __main__:<module>:62 - Peak memory usage: 5.996971130371094 GB
# 2025-05-09 00:43:38.959 | INFO     | __main__:<module>:63 - Peak minor page faults: 32432
# 2025-05-09 00:43:38.959 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:38.960 | INFO     | __main__:<module>:16 - Iteration 11/30
# 2025-05-09 00:43:43.707 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10-garbage-collected.log
# 2025-05-09 00:43:43.709 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10-garbage-collected.log
# 2025-05-09 00:43:43.712 | INFO     | __main__:<module>:62 - Peak memory usage: 6.015323638916016 GB
# 2025-05-09 00:43:43.712 | INFO     | __main__:<module>:63 - Peak minor page faults: 32442
# 2025-05-09 00:43:43.713 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:43.713 | INFO     | __main__:<module>:16 - Iteration 12/30
# 2025-05-09 00:43:48.949 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11-garbage-collected.log
# 2025-05-09 00:43:48.951 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11-garbage-collected.log
# 2025-05-09 00:43:48.953 | INFO     | __main__:<module>:62 - Peak memory usage: 6.024261474609375 GB
# 2025-05-09 00:43:48.953 | INFO     | __main__:<module>:63 - Peak minor page faults: 32444
# 2025-05-09 00:43:48.953 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:48.954 | INFO     | __main__:<module>:16 - Iteration 13/30
# 2025-05-09 00:43:53.722 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12-garbage-collected.log
# 2025-05-09 00:43:53.723 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12-garbage-collected.log
# 2025-05-09 00:43:53.725 | INFO     | __main__:<module>:62 - Peak memory usage: 6.027530670166016 GB
# 2025-05-09 00:43:53.727 | INFO     | __main__:<module>:63 - Peak minor page faults: 32428
# 2025-05-09 00:43:53.728 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:53.728 | INFO     | __main__:<module>:16 - Iteration 14/30
# 2025-05-09 00:43:59.735 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13-garbage-collected.log
# 2025-05-09 00:43:59.740 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13-garbage-collected.log
# 2025-05-09 00:43:59.746 | INFO     | __main__:<module>:62 - Peak memory usage: 6.017387390136719 GB
# 2025-05-09 00:43:59.747 | INFO     | __main__:<module>:63 - Peak minor page faults: 32430
# 2025-05-09 00:43:59.748 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:43:59.749 | INFO     | __main__:<module>:16 - Iteration 15/30
# 2025-05-09 00:44:06.268 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14-garbage-collected.log
# 2025-05-09 00:44:06.272 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14-garbage-collected.log
# 2025-05-09 00:44:06.274 | INFO     | __main__:<module>:62 - Peak memory usage: 6.014854431152344 GB
# 2025-05-09 00:44:06.275 | INFO     | __main__:<module>:63 - Peak minor page faults: 32441
# 2025-05-09 00:44:06.275 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:06.276 | INFO     | __main__:<module>:16 - Iteration 16/30
# 2025-05-09 00:44:12.047 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15-garbage-collected.log
# 2025-05-09 00:44:12.050 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15-garbage-collected.log
# 2025-05-09 00:44:12.052 | INFO     | __main__:<module>:62 - Peak memory usage: 6.016834259033203 GB
# 2025-05-09 00:44:12.052 | INFO     | __main__:<module>:63 - Peak minor page faults: 32442
# 2025-05-09 00:44:12.053 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:12.053 | INFO     | __main__:<module>:16 - Iteration 17/30
# 2025-05-09 00:44:18.422 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16-garbage-collected.log
# 2025-05-09 00:44:18.424 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16-garbage-collected.log
# 2025-05-09 00:44:18.426 | INFO     | __main__:<module>:62 - Peak memory usage: 6.022373199462891 GB
# 2025-05-09 00:44:18.427 | INFO     | __main__:<module>:63 - Peak minor page faults: 32426
# 2025-05-09 00:44:18.427 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:18.427 | INFO     | __main__:<module>:16 - Iteration 18/30
# 2025-05-09 00:44:23.988 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17-garbage-collected.log
# 2025-05-09 00:44:23.992 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17-garbage-collected.log
# 2025-05-09 00:44:23.995 | INFO     | __main__:<module>:62 - Peak memory usage: 6.021289825439453 GB
# 2025-05-09 00:44:23.996 | INFO     | __main__:<module>:63 - Peak minor page faults: 32432
# 2025-05-09 00:44:23.997 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:23.997 | INFO     | __main__:<module>:16 - Iteration 19/30
# 2025-05-09 00:44:32.177 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18-garbage-collected.log
# 2025-05-09 00:44:32.185 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18-garbage-collected.log
# 2025-05-09 00:44:32.189 | INFO     | __main__:<module>:62 - Peak memory usage: 6.019744873046875 GB
# 2025-05-09 00:44:32.189 | INFO     | __main__:<module>:63 - Peak minor page faults: 32427
# 2025-05-09 00:44:32.190 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:32.190 | INFO     | __main__:<module>:16 - Iteration 20/30
# 2025-05-09 00:44:42.078 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19-garbage-collected.log
# 2025-05-09 00:44:42.083 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19-garbage-collected.log
# 2025-05-09 00:44:42.085 | INFO     | __main__:<module>:62 - Peak memory usage: 6.016407012939453 GB
# 2025-05-09 00:44:42.085 | INFO     | __main__:<module>:63 - Peak minor page faults: 32431
# 2025-05-09 00:44:42.086 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:42.086 | INFO     | __main__:<module>:16 - Iteration 21/30
# 2025-05-09 00:44:49.759 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20-garbage-collected.log
# 2025-05-09 00:44:49.762 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20-garbage-collected.log
# 2025-05-09 00:44:49.765 | INFO     | __main__:<module>:62 - Peak memory usage: 6.019996643066406 GB
# 2025-05-09 00:44:49.765 | INFO     | __main__:<module>:63 - Peak minor page faults: 32441
# 2025-05-09 00:44:49.766 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:49.767 | INFO     | __main__:<module>:16 - Iteration 22/30
# 2025-05-09 00:44:59.958 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21-garbage-collected.log
# 2025-05-09 00:44:59.966 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21-garbage-collected.log
# 2025-05-09 00:44:59.969 | INFO     | __main__:<module>:62 - Peak memory usage: 6.025783538818359 GB
# 2025-05-09 00:44:59.969 | INFO     | __main__:<module>:63 - Peak minor page faults: 32442
# 2025-05-09 00:44:59.969 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:44:59.970 | INFO     | __main__:<module>:16 - Iteration 23/30
# 2025-05-09 00:45:07.750 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22-garbage-collected.log
# 2025-05-09 00:45:07.753 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22-garbage-collected.log
# 2025-05-09 00:45:07.755 | INFO     | __main__:<module>:62 - Peak memory usage: 6.027015686035156 GB
# 2025-05-09 00:45:07.756 | INFO     | __main__:<module>:63 - Peak minor page faults: 32431
# 2025-05-09 00:45:07.756 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:45:07.757 | INFO     | __main__:<module>:16 - Iteration 24/30
# 2025-05-09 00:45:18.198 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23-garbage-collected.log
# 2025-05-09 00:45:18.207 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23-garbage-collected.log
# 2025-05-09 00:45:18.211 | INFO     | __main__:<module>:62 - Peak memory usage: 6.0246124267578125 GB
# 2025-05-09 00:45:18.212 | INFO     | __main__:<module>:63 - Peak minor page faults: 32442
# 2025-05-09 00:45:18.213 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:45:18.213 | INFO     | __main__:<module>:16 - Iteration 25/30
# 2025-05-09 00:45:29.026 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24-garbage-collected.log
# 2025-05-09 00:45:29.033 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24-garbage-collected.log
# 2025-05-09 00:45:29.038 | INFO     | __main__:<module>:62 - Peak memory usage: 6.026981353759766 GB
# 2025-05-09 00:45:29.039 | INFO     | __main__:<module>:63 - Peak minor page faults: 32447
# 2025-05-09 00:45:29.040 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:45:29.040 | INFO     | __main__:<module>:16 - Iteration 26/30
# 2025-05-09 00:45:38.885 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25-garbage-collected.log
# 2025-05-09 00:45:38.924 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25-garbage-collected.log
# 2025-05-09 00:45:38.927 | INFO     | __main__:<module>:62 - Peak memory usage: 6.020912170410156 GB
# 2025-05-09 00:45:38.928 | INFO     | __main__:<module>:63 - Peak minor page faults: 32444
# 2025-05-09 00:45:38.930 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:45:38.931 | INFO     | __main__:<module>:16 - Iteration 27/30
# 2025-05-09 00:45:49.219 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26-garbage-collected.log
# 2025-05-09 00:45:49.242 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26-garbage-collected.log
# 2025-05-09 00:45:49.244 | INFO     | __main__:<module>:62 - Peak memory usage: 6.019023895263672 GB
# 2025-05-09 00:45:49.245 | INFO     | __main__:<module>:63 - Peak minor page faults: 32443
# 2025-05-09 00:45:49.245 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:45:49.245 | INFO     | __main__:<module>:16 - Iteration 28/30
# 2025-05-09 00:46:00.284 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27-garbage-collected.log
# 2025-05-09 00:46:00.297 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27-garbage-collected.log
# 2025-05-09 00:46:00.304 | INFO     | __main__:<module>:62 - Peak memory usage: 6.0242156982421875 GB
# 2025-05-09 00:46:00.304 | INFO     | __main__:<module>:63 - Peak minor page faults: 32449
# 2025-05-09 00:46:00.304 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:46:00.305 | INFO     | __main__:<module>:16 - Iteration 29/30
# 2025-05-09 00:46:11.564 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28-garbage-collected.log
# 2025-05-09 00:46:11.574 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28-garbage-collected.log
# 2025-05-09 00:46:11.580 | INFO     | __main__:<module>:62 - Peak memory usage: 6.022575378417969 GB
# 2025-05-09 00:46:11.581 | INFO     | __main__:<module>:63 - Peak minor page faults: 32443
# 2025-05-09 00:46:11.581 | INFO     | __main__:<module>:64 - Peak major page faults: 0
# 2025-05-09 00:46:11.582 | INFO     | __main__:<module>:16 - Iteration 30/30
# 2025-05-09 00:46:26.168 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29-garbage-collected.log
# 2025-05-09 00:46:26.184 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29-garbage-collected.log
# 2025-05-09 00:46:26.189 | INFO     | __main__:<module>:62 - Peak memory usage: 6.025279998779297 GB
# 2025-05-09 00:46:26.191 | INFO     | __main__:<module>:63 - Peak minor page faults: 32441
# 2025-05-09 00:46:26.192 | INFO     | __main__:<module>:64 - Peak major page faults: 0

# %% [markdown]
# Manually calling the GC still doesn't change the page fault pattern.
# Let's try making the CPU usage more strict to see if we can make the memory usage pattern more stable.

# %%
iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}-cpu-affinity.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}-cpu-affinity.log"

    logger.info(f"Iteration {i + 1}/{iterations}")
    experiment_container = client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        nano_cpus=int(1 * 1e9),  # Strictly allocate 1 CPU (1 * 1,000,000,000 nanoCPUs)
        cpu_shares=1024,  # Relative CPU priority
        cpuset_cpus="0",  # Pin to CPUs 0 for strict consistency
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))

plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="with_cpu_affinity")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="with_cpu_affinity")
# Out:
# 2025-05-09 00:46:26.980 | INFO     | __main__:<module>:14 - Iteration 1/30
# 2025-05-09 00:46:48.369 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0-cpu-affinity.log
# 2025-05-09 00:46:48.381 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0-cpu-affinity.log
# 2025-05-09 00:46:48.386 | INFO     | __main__:<module>:60 - Peak memory usage: 6.026088714599609 GB
# 2025-05-09 00:46:48.386 | INFO     | __main__:<module>:61 - Peak minor page faults: 32343
# 2025-05-09 00:46:48.387 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:46:48.387 | INFO     | __main__:<module>:14 - Iteration 2/30
# 2025-05-09 00:47:01.800 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1-cpu-affinity.log
# 2025-05-09 00:47:01.813 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1-cpu-affinity.log
# 2025-05-09 00:47:01.816 | INFO     | __main__:<module>:60 - Peak memory usage: 6.022075653076172 GB
# 2025-05-09 00:47:01.817 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:47:01.818 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:47:01.818 | INFO     | __main__:<module>:14 - Iteration 3/30
# 2025-05-09 00:47:15.757 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2-cpu-affinity.log
# 2025-05-09 00:47:15.767 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2-cpu-affinity.log
# 2025-05-09 00:47:15.770 | INFO     | __main__:<module>:60 - Peak memory usage: 6.022380828857422 GB
# 2025-05-09 00:47:15.770 | INFO     | __main__:<module>:61 - Peak minor page faults: 32337
# 2025-05-09 00:47:15.771 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:47:15.771 | INFO     | __main__:<module>:14 - Iteration 4/30
# 2025-05-09 00:47:31.335 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3-cpu-affinity.log
# 2025-05-09 00:47:31.351 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3-cpu-affinity.log
# 2025-05-09 00:47:31.358 | INFO     | __main__:<module>:60 - Peak memory usage: 6.024204254150391 GB
# 2025-05-09 00:47:31.358 | INFO     | __main__:<module>:61 - Peak minor page faults: 32345
# 2025-05-09 00:47:31.359 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:47:31.359 | INFO     | __main__:<module>:14 - Iteration 5/30
# 2025-05-09 00:47:44.850 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4-cpu-affinity.log
# 2025-05-09 00:47:44.864 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4-cpu-affinity.log
# 2025-05-09 00:47:44.869 | INFO     | __main__:<module>:60 - Peak memory usage: 6.023307800292969 GB
# 2025-05-09 00:47:44.870 | INFO     | __main__:<module>:61 - Peak minor page faults: 32336
# 2025-05-09 00:47:44.870 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:47:44.871 | INFO     | __main__:<module>:14 - Iteration 6/30
# 2025-05-09 00:47:58.358 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5-cpu-affinity.log
# 2025-05-09 00:47:58.375 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5-cpu-affinity.log
# 2025-05-09 00:47:58.379 | INFO     | __main__:<module>:60 - Peak memory usage: 6.0274505615234375 GB
# 2025-05-09 00:47:58.380 | INFO     | __main__:<module>:61 - Peak minor page faults: 32340
# 2025-05-09 00:47:58.380 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:47:58.381 | INFO     | __main__:<module>:14 - Iteration 7/30
# 2025-05-09 00:48:12.124 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6-cpu-affinity.log
# 2025-05-09 00:48:12.137 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6-cpu-affinity.log
# 2025-05-09 00:48:12.143 | INFO     | __main__:<module>:60 - Peak memory usage: 6.023288726806641 GB
# 2025-05-09 00:48:12.143 | INFO     | __main__:<module>:61 - Peak minor page faults: 32339
# 2025-05-09 00:48:12.143 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:48:12.144 | INFO     | __main__:<module>:14 - Iteration 8/30
# 2025-05-09 00:48:25.784 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7-cpu-affinity.log
# 2025-05-09 00:48:25.791 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7-cpu-affinity.log
# 2025-05-09 00:48:25.794 | INFO     | __main__:<module>:60 - Peak memory usage: 6.024017333984375 GB
# 2025-05-09 00:48:25.795 | INFO     | __main__:<module>:61 - Peak minor page faults: 32340
# 2025-05-09 00:48:25.795 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:48:25.795 | INFO     | __main__:<module>:14 - Iteration 9/30
# 2025-05-09 00:48:40.233 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8-cpu-affinity.log
# 2025-05-09 00:48:40.241 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8-cpu-affinity.log
# 2025-05-09 00:48:40.244 | INFO     | __main__:<module>:60 - Peak memory usage: 6.027667999267578 GB
# 2025-05-09 00:48:40.244 | INFO     | __main__:<module>:61 - Peak minor page faults: 32343
# 2025-05-09 00:48:40.244 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:48:40.245 | INFO     | __main__:<module>:14 - Iteration 10/30
# 2025-05-09 00:48:55.012 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9-cpu-affinity.log
# 2025-05-09 00:48:55.020 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9-cpu-affinity.log
# 2025-05-09 00:48:55.022 | INFO     | __main__:<module>:60 - Peak memory usage: 6.026729583740234 GB
# 2025-05-09 00:48:55.023 | INFO     | __main__:<module>:61 - Peak minor page faults: 32341
# 2025-05-09 00:48:55.023 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:48:55.024 | INFO     | __main__:<module>:14 - Iteration 11/30
# 2025-05-09 00:49:09.399 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10-cpu-affinity.log
# 2025-05-09 00:49:09.407 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10-cpu-affinity.log
# 2025-05-09 00:49:09.411 | INFO     | __main__:<module>:60 - Peak memory usage: 6.022789001464844 GB
# 2025-05-09 00:49:09.412 | INFO     | __main__:<module>:61 - Peak minor page faults: 32338
# 2025-05-09 00:49:09.413 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:49:09.413 | INFO     | __main__:<module>:14 - Iteration 12/30
# 2025-05-09 00:49:23.750 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11-cpu-affinity.log
# 2025-05-09 00:49:23.764 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11-cpu-affinity.log
# 2025-05-09 00:49:23.771 | INFO     | __main__:<module>:60 - Peak memory usage: 6.02667236328125 GB
# 2025-05-09 00:49:23.771 | INFO     | __main__:<module>:61 - Peak minor page faults: 32338
# 2025-05-09 00:49:23.772 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:49:23.774 | INFO     | __main__:<module>:14 - Iteration 13/30
# 2025-05-09 00:49:37.753 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12-cpu-affinity.log
# 2025-05-09 00:49:37.758 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12-cpu-affinity.log
# 2025-05-09 00:49:37.761 | INFO     | __main__:<module>:60 - Peak memory usage: 6.026905059814453 GB
# 2025-05-09 00:49:37.762 | INFO     | __main__:<module>:61 - Peak minor page faults: 32340
# 2025-05-09 00:49:37.762 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:49:37.763 | INFO     | __main__:<module>:14 - Iteration 14/30
# 2025-05-09 00:49:52.195 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13-cpu-affinity.log
# 2025-05-09 00:49:52.210 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13-cpu-affinity.log
# 2025-05-09 00:49:52.218 | INFO     | __main__:<module>:60 - Peak memory usage: 6.024868011474609 GB
# 2025-05-09 00:49:52.219 | INFO     | __main__:<module>:61 - Peak minor page faults: 32339
# 2025-05-09 00:49:52.219 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:49:52.219 | INFO     | __main__:<module>:14 - Iteration 15/30
# 2025-05-09 00:50:07.081 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14-cpu-affinity.log
# 2025-05-09 00:50:07.103 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14-cpu-affinity.log
# 2025-05-09 00:50:07.110 | INFO     | __main__:<module>:60 - Peak memory usage: 6.024883270263672 GB
# 2025-05-09 00:50:07.110 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:50:07.110 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:50:07.111 | INFO     | __main__:<module>:14 - Iteration 16/30
# 2025-05-09 00:50:21.216 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15-cpu-affinity.log
# 2025-05-09 00:50:21.225 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15-cpu-affinity.log
# 2025-05-09 00:50:21.236 | INFO     | __main__:<module>:60 - Peak memory usage: 6.022541046142578 GB
# 2025-05-09 00:50:21.237 | INFO     | __main__:<module>:61 - Peak minor page faults: 32333
# 2025-05-09 00:50:21.237 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:50:21.237 | INFO     | __main__:<module>:14 - Iteration 17/30
# 2025-05-09 00:50:35.413 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16-cpu-affinity.log
# 2025-05-09 00:50:35.423 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16-cpu-affinity.log
# 2025-05-09 00:50:35.431 | INFO     | __main__:<module>:60 - Peak memory usage: 6.02703857421875 GB
# 2025-05-09 00:50:35.432 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:50:35.432 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:50:35.433 | INFO     | __main__:<module>:14 - Iteration 18/30
# 2025-05-09 00:50:49.788 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17-cpu-affinity.log
# 2025-05-09 00:50:49.803 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17-cpu-affinity.log
# 2025-05-09 00:50:49.808 | INFO     | __main__:<module>:60 - Peak memory usage: 6.02471923828125 GB
# 2025-05-09 00:50:49.808 | INFO     | __main__:<module>:61 - Peak minor page faults: 32335
# 2025-05-09 00:50:49.809 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:50:49.809 | INFO     | __main__:<module>:14 - Iteration 19/30
# 2025-05-09 00:51:04.869 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18-cpu-affinity.log
# 2025-05-09 00:51:04.877 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18-cpu-affinity.log
# 2025-05-09 00:51:04.880 | INFO     | __main__:<module>:60 - Peak memory usage: 6.026130676269531 GB
# 2025-05-09 00:51:04.881 | INFO     | __main__:<module>:61 - Peak minor page faults: 32335
# 2025-05-09 00:51:04.882 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:51:04.883 | INFO     | __main__:<module>:14 - Iteration 20/30
# 2025-05-09 00:51:19.175 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19-cpu-affinity.log
# 2025-05-09 00:51:19.186 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19-cpu-affinity.log
# 2025-05-09 00:51:19.191 | INFO     | __main__:<module>:60 - Peak memory usage: 6.019893646240234 GB
# 2025-05-09 00:51:19.192 | INFO     | __main__:<module>:61 - Peak minor page faults: 32338
# 2025-05-09 00:51:19.193 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:51:19.194 | INFO     | __main__:<module>:14 - Iteration 21/30
# 2025-05-09 00:51:33.955 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20-cpu-affinity.log
# 2025-05-09 00:51:33.964 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20-cpu-affinity.log
# 2025-05-09 00:51:33.966 | INFO     | __main__:<module>:60 - Peak memory usage: 6.018730163574219 GB
# 2025-05-09 00:51:33.967 | INFO     | __main__:<module>:61 - Peak minor page faults: 32337
# 2025-05-09 00:51:33.967 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:51:33.968 | INFO     | __main__:<module>:14 - Iteration 22/30
# 2025-05-09 00:51:48.316 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21-cpu-affinity.log
# 2025-05-09 00:51:48.328 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21-cpu-affinity.log
# 2025-05-09 00:51:48.335 | INFO     | __main__:<module>:60 - Peak memory usage: 6.018520355224609 GB
# 2025-05-09 00:51:48.335 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:51:48.336 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:51:48.336 | INFO     | __main__:<module>:14 - Iteration 23/30
# 2025-05-09 00:52:02.701 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22-cpu-affinity.log
# 2025-05-09 00:52:02.712 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22-cpu-affinity.log
# 2025-05-09 00:52:02.720 | INFO     | __main__:<module>:60 - Peak memory usage: 6.027656555175781 GB
# 2025-05-09 00:52:02.720 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:52:02.720 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:52:02.721 | INFO     | __main__:<module>:14 - Iteration 24/30
# 2025-05-09 00:52:16.833 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23-cpu-affinity.log
# 2025-05-09 00:52:16.842 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23-cpu-affinity.log
# 2025-05-09 00:52:16.844 | INFO     | __main__:<module>:60 - Peak memory usage: 6.012725830078125 GB
# 2025-05-09 00:52:16.845 | INFO     | __main__:<module>:61 - Peak minor page faults: 32339
# 2025-05-09 00:52:16.847 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:52:16.848 | INFO     | __main__:<module>:14 - Iteration 25/30
# 2025-05-09 00:52:31.663 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24-cpu-affinity.log
# 2025-05-09 00:52:31.671 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24-cpu-affinity.log
# 2025-05-09 00:52:31.674 | INFO     | __main__:<module>:60 - Peak memory usage: 6.021636962890625 GB
# 2025-05-09 00:52:31.675 | INFO     | __main__:<module>:61 - Peak minor page faults: 32340
# 2025-05-09 00:52:31.676 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:52:31.677 | INFO     | __main__:<module>:14 - Iteration 26/30
# 2025-05-09 00:52:45.582 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25-cpu-affinity.log
# 2025-05-09 00:52:45.593 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25-cpu-affinity.log
# 2025-05-09 00:52:45.596 | INFO     | __main__:<module>:60 - Peak memory usage: 6.022544860839844 GB
# 2025-05-09 00:52:45.597 | INFO     | __main__:<module>:61 - Peak minor page faults: 32334
# 2025-05-09 00:52:45.597 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:52:45.598 | INFO     | __main__:<module>:14 - Iteration 27/30
# 2025-05-09 00:52:59.784 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26-cpu-affinity.log
# 2025-05-09 00:52:59.797 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26-cpu-affinity.log
# 2025-05-09 00:52:59.800 | INFO     | __main__:<module>:60 - Peak memory usage: 6.02117919921875 GB
# 2025-05-09 00:52:59.800 | INFO     | __main__:<module>:61 - Peak minor page faults: 32338
# 2025-05-09 00:52:59.801 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:52:59.801 | INFO     | __main__:<module>:14 - Iteration 28/30
# 2025-05-09 00:53:13.997 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27-cpu-affinity.log
# 2025-05-09 00:53:14.012 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27-cpu-affinity.log
# 2025-05-09 00:53:14.020 | INFO     | __main__:<module>:60 - Peak memory usage: 6.028266906738281 GB
# 2025-05-09 00:53:14.021 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:53:14.024 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:53:14.024 | INFO     | __main__:<module>:14 - Iteration 29/30
# 2025-05-09 00:53:28.807 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28-cpu-affinity.log
# 2025-05-09 00:53:28.816 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28-cpu-affinity.log
# 2025-05-09 00:53:28.819 | INFO     | __main__:<module>:60 - Peak memory usage: 6.0187530517578125 GB
# 2025-05-09 00:53:28.820 | INFO     | __main__:<module>:61 - Peak minor page faults: 32342
# 2025-05-09 00:53:28.820 | INFO     | __main__:<module>:62 - Peak major page faults: 0
# 2025-05-09 00:53:28.820 | INFO     | __main__:<module>:14 - Iteration 30/30
# 2025-05-09 00:53:42.995 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29-cpu-affinity.log
# 2025-05-09 00:53:43.013 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29-cpu-affinity.log
# 2025-05-09 00:53:43.018 | INFO     | __main__:<module>:60 - Peak memory usage: 6.015693664550781 GB
# 2025-05-09 00:53:43.018 | INFO     | __main__:<module>:61 - Peak minor page faults: 32338
# 2025-05-09 00:53:43.020 | INFO     | __main__:<module>:62 - Peak major page faults: 0

# %% [markdown]
# As we can see, having CPU affinity drastically changed the page fault pattern.
# Let's try merging the CPU affinity with the explicit drop of page caches.

# %%
import subprocess
import time
import os

DIND_CONTAINER_NAME = "vfs-dind"
HOST_OUT_DIR = os.path.abspath(f"../{RELATIVE_OUT_DIR}")

logger.info("Starting VFS Docker daemon...")
vfs_container = client.containers.run(
    image="docker:dind",
    name=DIND_CONTAINER_NAME,
    auto_remove=True,
    privileged=True,
    detach=True,
    ports={
        "2375/tcp": 2375
    },
    command=[
        "--storage-driver=vfs"
    ],
    environment={
        "DOCKER_TLS_CERTDIR": "",
    },
    volumes={
        os.path.abspath(f"../{RELATIVE_OUT_DIR}"): {
            "bind": "/mnt/out",
            "mode": "rw",
        }
    },
)

logger.info("Waiting for dockerd to start...")
time.sleep(5)

for _ in range(10):
    try:
        subprocess.run(["docker", "-H", "tcp://localhost:2375", "info"], check=True)
        logger.info("dockerd inside dind is fully operational.")
        break
    except subprocess.CalledProcessError:
        logger.info("Waiting for dockerd to start...")
        time.sleep(5)

vfs_client = docker.DockerClient(base_url="tcp://localhost:2375")

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)
logger.info("Experiment image built successfully.")

iterations = 30

memory_usage_history = []
page_faults_history = []

peak_memory_usage_history = []
peak_minor_page_faults_history = []
peak_major_page_faults_history = []

for i in range(iterations):
    memory_usage_log_file = f"docker-monitor/memory-usage--experiment-{i}-without-page-caching+with-cpu-affinity.log"
    page_faults_log_file = f"docker-monitor/page-faults--experiment-{i}-without-page-caching+with-cpu-affinity.log"

    drop_caches_in_dind()

    logger.info(f"Iteration {i + 1}/{iterations}")

    experiment_container = vfs_client.containers.run(
        image=EXPERIMENT_IMAGE,
        mem_limit="15g",
        auto_remove=True,
        nano_cpus=int(1 * 1e9),  # Strictly allocate 1 CPU (1 * 1,000,000,000 nanoCPUs)
        cpu_shares=1024,  # Relative CPU priority
        cpuset_cpus="0",  # Pin to CPUs 0 for strict consistency
        command=[
            "operate",
            "envelope",
            "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy"
        ],
        environment={
            "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
            "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
            "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        },
        volumes={
            "/mnt/out": {
                "bind": CONTAINER_OUT_DIR,
                "mode": "rw",
            }
        },
    )

    memory_usage_df = tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
    )
    page_faults_df = tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/{page_faults_log_file}",
    )

    peak_memory_usage = tools.conversions.kb_to_gb(
        memory_usage_df["memory_usage_kb"].max()
    )
    peak_minor_page_faults = page_faults_df["minor_page_faults"].max()
    peak_major_page_faults = page_faults_df["major_page_faults"].max()

    memory_usage_history.append(memory_usage_df)
    page_faults_history.append(page_faults_df)

    peak_memory_usage_history.append(peak_memory_usage)
    peak_minor_page_faults_history.append(peak_minor_page_faults)
    peak_major_page_faults_history.append(peak_major_page_faults)

    logger.info("Peak memory usage: {} GB".format(peak_memory_usage))
    logger.info("Peak minor page faults: {}".format(peak_minor_page_faults))
    logger.info("Peak major page faults: {}".format(peak_major_page_faults))

vfs_container.stop()

plot_variability(peak_memory_usage_history, "Memory Usage", "GB", suffix="cpu_affinity_and_dropping_caches")
plot_variability(peak_minor_page_faults_history, "Minor Page Faults", suffix="cpu_affinity_and_dropping_caches")
# Out:
# 2025-05-09 00:53:43.717 | INFO     | __main__:<module>:8 - Starting VFS Docker daemon...
# 2025-05-09 00:53:43.908 | INFO     | __main__:<module>:32 - Waiting for dockerd to start...
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:63626->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:53:49.360 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:63644->[::1]:2375: read: connection reset by peer
# 2025-05-09 00:53:54.461 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:63661->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 00:53:59.665 | INFO     | __main__:<module>:41 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# [DEPRECATION NOTICE]: API is accessible on http://0.0.0.0:2375 without encryption.
#          Access to the remote API is equivalent to root access on the host. Refer
#          to the 'Docker daemon attack surface' section in the documentation for
#          more information: https://docs.docker.com/go/attack-surface/
# In future versions this will be a hard failure preventing the daemon from starting! Learn more at: https://docs.docker.com/go/api-security/
# 2025-05-09 00:54:04.764 | INFO     | __main__:<module>:38 - dockerd inside dind is fully operational.
# 2025-05-09 00:54:04.773 | INFO     | __main__:<module>:46 - Building experiment image...
# 2025-05-09 00:54:04.774 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.3
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.22.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  0.2.20
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.34.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Beta) (Docker Inc.)
#     Version:  v0.1.6
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.4
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 0
#  Server Version: 28.1.1
#  Storage Driver: vfs
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.6-0-ge89a299
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Alpine Linux v3.21 (containerized)
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 16
#  Total Memory: 30.91GiB
#  Name: 900bf7c92b15
#  ID: 1bca8926-b9df-4867-9e0f-6bb35bd06046
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false
#  Product License: Community Engine
# 2025-05-09 00:54:28.717 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 00:54:28.720 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 00:56:02.375 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 00:56:02.379 | INFO     | __main__:<module>:48 - Experiment image built successfully.
# 2025-05-09 00:56:12.765 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:56:12.767 | INFO     | __main__:<module>:65 - Iteration 1/30
# 2025-05-09 00:56:26.030 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-0-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:26.039 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-0-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:26.043 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0225067138671875 GB
# 2025-05-09 00:56:26.044 | INFO     | __main__:<module>:113 - Peak minor page faults: 30666
# 2025-05-09 00:56:26.045 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:56:26.606 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:56:26.608 | INFO     | __main__:<module>:65 - Iteration 2/30
# 2025-05-09 00:56:35.439 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-1-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:35.442 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-1-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:35.445 | INFO     | __main__:<module>:112 - Peak memory usage: 6.024688720703125 GB
# 2025-05-09 00:56:35.446 | INFO     | __main__:<module>:113 - Peak minor page faults: 30651
# 2025-05-09 00:56:35.447 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:56:35.916 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:56:35.918 | INFO     | __main__:<module>:65 - Iteration 3/30
# 2025-05-09 00:56:44.007 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-2-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:44.010 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-2-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:44.013 | INFO     | __main__:<module>:112 - Peak memory usage: 5.999385833740234 GB
# 2025-05-09 00:56:44.013 | INFO     | __main__:<module>:113 - Peak minor page faults: 30672
# 2025-05-09 00:56:44.014 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:56:44.481 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:56:44.483 | INFO     | __main__:<module>:65 - Iteration 4/30
# 2025-05-09 00:56:51.736 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-3-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:51.740 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-3-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:51.743 | INFO     | __main__:<module>:112 - Peak memory usage: 5.9947357177734375 GB
# 2025-05-09 00:56:51.743 | INFO     | __main__:<module>:113 - Peak minor page faults: 30673
# 2025-05-09 00:56:51.745 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:56:52.215 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:56:52.217 | INFO     | __main__:<module>:65 - Iteration 5/30
# 2025-05-09 00:56:59.865 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-4-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:59.868 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-4-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:56:59.872 | INFO     | __main__:<module>:112 - Peak memory usage: 6.000587463378906 GB
# 2025-05-09 00:56:59.874 | INFO     | __main__:<module>:113 - Peak minor page faults: 30652
# 2025-05-09 00:56:59.875 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:00.341 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:00.342 | INFO     | __main__:<module>:65 - Iteration 6/30
# 2025-05-09 00:57:07.631 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-5-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:07.633 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-5-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:07.634 | INFO     | __main__:<module>:112 - Peak memory usage: 6.022121429443359 GB
# 2025-05-09 00:57:07.634 | INFO     | __main__:<module>:113 - Peak minor page faults: 30667
# 2025-05-09 00:57:07.635 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:08.096 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:08.097 | INFO     | __main__:<module>:65 - Iteration 7/30
# 2025-05-09 00:57:15.633 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-6-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:15.638 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-6-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:15.640 | INFO     | __main__:<module>:112 - Peak memory usage: 5.987751007080078 GB
# 2025-05-09 00:57:15.641 | INFO     | __main__:<module>:113 - Peak minor page faults: 30655
# 2025-05-09 00:57:15.642 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:16.152 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:16.154 | INFO     | __main__:<module>:65 - Iteration 8/30
# 2025-05-09 00:57:23.400 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-7-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:23.402 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-7-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:23.403 | INFO     | __main__:<module>:112 - Peak memory usage: 6.025260925292969 GB
# 2025-05-09 00:57:23.403 | INFO     | __main__:<module>:113 - Peak minor page faults: 30669
# 2025-05-09 00:57:23.403 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:23.976 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:23.977 | INFO     | __main__:<module>:65 - Iteration 9/30
# 2025-05-09 00:57:31.555 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-8-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:31.558 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-8-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:31.560 | INFO     | __main__:<module>:112 - Peak memory usage: 6.003120422363281 GB
# 2025-05-09 00:57:31.561 | INFO     | __main__:<module>:113 - Peak minor page faults: 30666
# 2025-05-09 00:57:31.561 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:31.935 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:31.937 | INFO     | __main__:<module>:65 - Iteration 10/30
# 2025-05-09 00:57:38.994 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-9-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:38.997 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-9-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:38.999 | INFO     | __main__:<module>:112 - Peak memory usage: 6.022850036621094 GB
# 2025-05-09 00:57:39.000 | INFO     | __main__:<module>:113 - Peak minor page faults: 30659
# 2025-05-09 00:57:39.000 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:39.432 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:39.433 | INFO     | __main__:<module>:65 - Iteration 11/30
# 2025-05-09 00:57:46.759 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-10-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:46.763 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-10-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:46.766 | INFO     | __main__:<module>:112 - Peak memory usage: 6.023120880126953 GB
# 2025-05-09 00:57:46.767 | INFO     | __main__:<module>:113 - Peak minor page faults: 30656
# 2025-05-09 00:57:46.767 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:47.201 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:47.202 | INFO     | __main__:<module>:65 - Iteration 12/30
# 2025-05-09 00:57:54.293 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-11-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:54.296 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-11-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:57:54.298 | INFO     | __main__:<module>:112 - Peak memory usage: 6.005519866943359 GB
# 2025-05-09 00:57:54.299 | INFO     | __main__:<module>:113 - Peak minor page faults: 30655
# 2025-05-09 00:57:54.300 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:57:54.790 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:57:54.791 | INFO     | __main__:<module>:65 - Iteration 13/30
# 2025-05-09 00:58:01.990 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-12-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:01.993 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-12-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:01.995 | INFO     | __main__:<module>:112 - Peak memory usage: 5.994789123535156 GB
# 2025-05-09 00:58:01.996 | INFO     | __main__:<module>:113 - Peak minor page faults: 30666
# 2025-05-09 00:58:01.996 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:02.461 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:02.462 | INFO     | __main__:<module>:65 - Iteration 14/30
# 2025-05-09 00:58:10.162 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-13-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:10.165 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-13-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:10.167 | INFO     | __main__:<module>:112 - Peak memory usage: 6.018970489501953 GB
# 2025-05-09 00:58:10.168 | INFO     | __main__:<module>:113 - Peak minor page faults: 30673
# 2025-05-09 00:58:10.168 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:10.633 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:10.636 | INFO     | __main__:<module>:65 - Iteration 15/30
# 2025-05-09 00:58:17.668 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-14-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:17.671 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-14-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:17.674 | INFO     | __main__:<module>:112 - Peak memory usage: 6.004432678222656 GB
# 2025-05-09 00:58:17.674 | INFO     | __main__:<module>:113 - Peak minor page faults: 30658
# 2025-05-09 00:58:17.675 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:18.128 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:18.129 | INFO     | __main__:<module>:65 - Iteration 16/30
# 2025-05-09 00:58:25.398 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-15-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:25.402 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-15-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:25.407 | INFO     | __main__:<module>:112 - Peak memory usage: 6.006519317626953 GB
# 2025-05-09 00:58:25.408 | INFO     | __main__:<module>:113 - Peak minor page faults: 30657
# 2025-05-09 00:58:25.409 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:25.840 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:25.841 | INFO     | __main__:<module>:65 - Iteration 17/30
# 2025-05-09 00:58:32.864 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-16-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:32.868 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-16-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:32.871 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0014495849609375 GB
# 2025-05-09 00:58:32.872 | INFO     | __main__:<module>:113 - Peak minor page faults: 30675
# 2025-05-09 00:58:32.872 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:33.314 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:33.316 | INFO     | __main__:<module>:65 - Iteration 18/30
# 2025-05-09 00:58:40.737 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-17-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:40.740 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-17-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:40.742 | INFO     | __main__:<module>:112 - Peak memory usage: 5.979267120361328 GB
# 2025-05-09 00:58:40.742 | INFO     | __main__:<module>:113 - Peak minor page faults: 30657
# 2025-05-09 00:58:40.743 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:41.161 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:41.163 | INFO     | __main__:<module>:65 - Iteration 19/30
# 2025-05-09 00:58:48.280 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-18-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:48.283 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-18-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:48.285 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0074310302734375 GB
# 2025-05-09 00:58:48.285 | INFO     | __main__:<module>:113 - Peak minor page faults: 30667
# 2025-05-09 00:58:48.286 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:48.723 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:48.728 | INFO     | __main__:<module>:65 - Iteration 20/30
# 2025-05-09 00:58:56.152 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-19-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:56.157 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-19-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:58:56.160 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0049285888671875 GB
# 2025-05-09 00:58:56.160 | INFO     | __main__:<module>:113 - Peak minor page faults: 30659
# 2025-05-09 00:58:56.160 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:58:56.589 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:58:56.591 | INFO     | __main__:<module>:65 - Iteration 21/30
# 2025-05-09 00:59:03.766 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-20-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:03.769 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-20-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:03.771 | INFO     | __main__:<module>:112 - Peak memory usage: 5.999412536621094 GB
# 2025-05-09 00:59:03.771 | INFO     | __main__:<module>:113 - Peak minor page faults: 30653
# 2025-05-09 00:59:03.772 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:04.399 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:04.400 | INFO     | __main__:<module>:65 - Iteration 22/30
# 2025-05-09 00:59:12.349 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-21-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:12.352 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-21-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:12.354 | INFO     | __main__:<module>:112 - Peak memory usage: 6.022769927978516 GB
# 2025-05-09 00:59:12.355 | INFO     | __main__:<module>:113 - Peak minor page faults: 30661
# 2025-05-09 00:59:12.355 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:12.805 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:12.806 | INFO     | __main__:<module>:65 - Iteration 23/30
# 2025-05-09 00:59:20.066 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-22-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:20.070 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-22-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:20.073 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0052947998046875 GB
# 2025-05-09 00:59:20.074 | INFO     | __main__:<module>:113 - Peak minor page faults: 30649
# 2025-05-09 00:59:20.075 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:20.536 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:20.538 | INFO     | __main__:<module>:65 - Iteration 24/30
# 2025-05-09 00:59:27.782 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-23-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:27.785 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-23-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:27.788 | INFO     | __main__:<module>:112 - Peak memory usage: 6.006427764892578 GB
# 2025-05-09 00:59:27.789 | INFO     | __main__:<module>:113 - Peak minor page faults: 30652
# 2025-05-09 00:59:27.789 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:28.254 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:28.256 | INFO     | __main__:<module>:65 - Iteration 25/30
# 2025-05-09 00:59:36.736 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-24-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:36.739 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-24-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:36.741 | INFO     | __main__:<module>:112 - Peak memory usage: 6.016239166259766 GB
# 2025-05-09 00:59:36.742 | INFO     | __main__:<module>:113 - Peak minor page faults: 30672
# 2025-05-09 00:59:36.742 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:37.167 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:37.168 | INFO     | __main__:<module>:65 - Iteration 26/30
# 2025-05-09 00:59:44.604 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-25-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:44.608 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-25-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:44.611 | INFO     | __main__:<module>:112 - Peak memory usage: 6.0240020751953125 GB
# 2025-05-09 00:59:44.611 | INFO     | __main__:<module>:113 - Peak minor page faults: 30668
# 2025-05-09 00:59:44.612 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:45.120 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:45.122 | INFO     | __main__:<module>:65 - Iteration 27/30
# 2025-05-09 00:59:52.416 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-26-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:52.420 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-26-without-page-caching+with-cpu-affinity.log
# 2025-05-09 00:59:52.422 | INFO     | __main__:<module>:112 - Peak memory usage: 6.009723663330078 GB
# 2025-05-09 00:59:52.423 | INFO     | __main__:<module>:113 - Peak minor page faults: 30652
# 2025-05-09 00:59:52.423 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 00:59:52.856 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 00:59:52.858 | INFO     | __main__:<module>:65 - Iteration 28/30
# 2025-05-09 01:00:00.229 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-27-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:00.232 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-27-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:00.234 | INFO     | __main__:<module>:112 - Peak memory usage: 6.017078399658203 GB
# 2025-05-09 01:00:00.235 | INFO     | __main__:<module>:113 - Peak minor page faults: 30657
# 2025-05-09 01:00:00.235 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 01:00:00.661 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 01:00:00.662 | INFO     | __main__:<module>:65 - Iteration 29/30
# 2025-05-09 01:00:08.196 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-28-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:08.198 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-28-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:08.201 | INFO     | __main__:<module>:112 - Peak memory usage: 6.02056884765625 GB
# 2025-05-09 01:00:08.201 | INFO     | __main__:<module>:113 - Peak minor page faults: 30672
# 2025-05-09 01:00:08.202 | INFO     | __main__:<module>:114 - Peak major page faults: 0
# 2025-05-09 01:00:08.689 | INFO     | __main__:drop_caches_in_dind:18 - Dropped caches inside DinD container
# 2025-05-09 01:00:08.691 | INFO     | __main__:<module>:65 - Iteration 30/30
# 2025-05-09 01:00:15.911 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/memory-usage--experiment-29-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:15.915 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/02-execution-environment-20250509000517/docker-monitor/page-faults--experiment-29-without-page-caching+with-cpu-affinity.log
# 2025-05-09 01:00:15.917 | INFO     | __main__:<module>:112 - Peak memory usage: 6.018562316894531 GB
# 2025-05-09 01:00:15.918 | INFO     | __main__:<module>:113 - Peak minor page faults: 30658
# 2025-05-09 01:00:15.918 | INFO     | __main__:<module>:114 - Peak major page faults: 0

# %% [markdown]
# ## Summary of Findings
#
# In this experiment, we aimed to evaluate the consistency of memory usage across multiple identical runs of a computational workload inside Docker containers.
# Despite efforts to minimize variability, our findings indicate that even with strict resource constraints, Docker containers still exhibit memory fragmentation and other unpredictable memory behaviors.
#
# ### Key Findings
#
# - Memory usage across runs showed non-trivial variability.
# - Even running on containers, we still saw a decreasing amount of page faults between runs.
# - Running with VFS storage-driver and dropping page cache helped reducing the contamination between runs.
# - Running with CPU affinity helped reducing the contamination between runs.
# - Memory fragmentation and page caching contamination persists, even with strict CPU affinity, VFS storage driver, and garbage collection optimizations.
# - Docker’s memory allocation is not fully deterministic, likely due to:
#   - Memory fragmentation inside the container.
#   - Kernel-level caching effects that persist across container runs.
#   - Variability in process startup behavior.
#
# ### Conclusions
#
# Even under controlled conditions, Docker workloads experience small but persistent variations in memory usage due to fragmentation, kernel-level behaviors, and allocation inconsistencies.
# While our optimizations improved consistency to a reasonable extent, achieving absolute determinism in memory usage remains challenging due to low-level system effects beyond Docker’s direct control.
