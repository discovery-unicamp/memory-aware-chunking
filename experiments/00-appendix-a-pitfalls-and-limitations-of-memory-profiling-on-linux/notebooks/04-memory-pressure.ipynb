# %% [markdown]
# # Memory Pressure Notebook

# %% [markdown]
# # Introduction
#
# This notebook aims to evaluate the results within a memory constrained context for the memory consumption experiment.
# The goals of this notebooks are:
#
# - Run experiments with memory constraints to validate `M_peak` accuracy.
# - Ensure that measured peak memory usage reflects the actual minimum required memory.

# %% [markdown]
# ## How to Use this Notebook
#
# - Run the individual cells to inspect and verify the behavior of specific parts of the component.
# - Review the expected behavior before running the full experiment via the shell script.
# - Use this notebook as a debugging and documentation tool to support future iterations of the experiment.
#
# By structuring the experiment this way, we ensure a clear separation between explanation, validation, and execution, making it easier to reason about the results while keeping the experiment reproducible and well-documented.

# %% [markdown]
# ## Components Overview

# %% [markdown]
# Before running the component, we need to setup a few variables and utils.

# %%
import os
import sys
from datetime import datetime

from loguru import logger

dirs_to_add = [
    os.path.abspath('..'),
    os.path.abspath('../../../libs/traceq'),
]

for dir_to_add in dirs_to_add:
    if dir_to_add not in sys.path:
        sys.path.insert(0, dir_to_add)

TIMESTAMP = datetime.now().strftime("%Y%m%d%H%M%S")

EXPERIMENT_IMAGE = "mac/04-memory-pressure"
RELATIVE_OUT_DIR = f"out/notebooks/04-memory-pressure-{TIMESTAMP}"
CONTAINER_OUT_DIR = f"/app/{RELATIVE_OUT_DIR}"

INLINES = "700"
XLINES = "700"
SAMPLES = "400"

logger.debug("Generated global variables")
logger.debug(f"TIMESTAMP: {TIMESTAMP}")
logger.debug(f"EXPERIMENT_IMAGE: {EXPERIMENT_IMAGE}")
logger.debug(f"RELATIVE_OUT_DIR: {RELATIVE_OUT_DIR}")
logger.debug(f"CONTAINER_OUT_DIR: {CONTAINER_OUT_DIR}")

logger.debug(f"INLINES: {INLINES}")
logger.debug(f"XLINES: {XLINES}")
logger.debug(f"SAMPLES: {SAMPLES}")

os.makedirs(f"../{RELATIVE_OUT_DIR}/docker-monitor", exist_ok=True)
# Out:
# 2025-05-09 20:24:44.449 | DEBUG    | __main__:<module>:26 - Generated global variables
# 2025-05-09 20:24:44.450 | DEBUG    | __main__:<module>:27 - TIMESTAMP: 20250509202444
# 2025-05-09 20:24:44.450 | DEBUG    | __main__:<module>:28 - EXPERIMENT_IMAGE: mac/04-memory-pressure
# 2025-05-09 20:24:44.450 | DEBUG    | __main__:<module>:29 - RELATIVE_OUT_DIR: out/notebooks/04-memory-pressure-20250509202444
# 2025-05-09 20:24:44.450 | DEBUG    | __main__:<module>:30 - CONTAINER_OUT_DIR: /app/out/notebooks/04-memory-pressure-20250509202444
# 2025-05-09 20:24:44.451 | DEBUG    | __main__:<module>:32 - INLINES: 700
# 2025-05-09 20:24:44.451 | DEBUG    | __main__:<module>:33 - XLINES: 700
# 2025-05-09 20:24:44.451 | DEBUG    | __main__:<module>:34 - SAMPLES: 400

# %%
import importlib
import tools.docker

importlib.reload(tools.docker)

vfs_client, vfs_container = tools.docker.get_vfs_client(f"../{RELATIVE_OUT_DIR}")
# Out:
# 2025-05-09 20:24:44.740 | INFO     | tools.docker:get_vfs_client:68 - Start dind dockerd...
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50910->[::1]:2375: read: connection reset by peer
# 2025-05-09 20:24:45.112 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50915->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 20:24:47.198 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50924->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 20:24:49.291 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50931->[::1]:2375: read: connection reset by peer
# 2025-05-09 20:24:51.369 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50936->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 20:24:53.997 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50945->[::1]:2375: read: connection reset by peer
# 2025-05-09 20:24:56.081 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50953->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 20:24:58.163 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:50960->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 20:25:00.245 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# [DEPRECATION NOTICE]: API is accessible on http://0.0.0.0:2375 without encryption.
#          Access to the remote API is equivalent to root access on the host. Refer
#          to the 'Docker daemon attack surface' section in the documentation for
#          more information: https://docs.docker.com/go/attack-surface/
# In future versions this will be a hard failure preventing the daemon from starting! Learn more at: https://docs.docker.com/go/api-security/
# 2025-05-09 20:25:02.325 | INFO     | tools.docker:__wait_for_dockerd:138 - Dockerd inside dind is fully operational.
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 0
#  Server Version: 28.1.1
#  Storage Driver: vfs
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.6-0-ge89a299
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Alpine Linux v3.21 (containerized)
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 16
#  Total Memory: 30.91GiB
#  Name: 08c773d16bd2
#  ID: 1767db7e-7540-4a0e-9df2-5fa5a73a4456
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false
#  Product License: Community Engine

# %% [markdown]
# Let's start by building the Docker image within the VFS client

# %%
from loguru import logger

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)
logger.info("Experiment image built successfully.")
# Out:
# 2025-05-09 20:25:02.338 | INFO     | __main__:<module>:3 - Building experiment image...
# 2025-05-09 20:25:02.339 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# 2025-05-09 20:25:37.682 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 20:25:37.684 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 20:27:03.396 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 20:27:03.399 | INFO     | __main__:<module>:5 - Experiment image built successfully.

# %% [markdown]
# With the image built, we're going to generate the test data.

# %%
memory_usage_log_file = f"docker-monitor/memory-usage--data-generation.log"
page_faults_log_file = f"docker-monitor/page-faults--data-generation.log"

logger.info("Generating test data...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "generate-data",
        "--inlines", INLINES,
        "--xlines", XLINES,
        "--samples", SAMPLES,
        "--output-dir", f"{CONTAINER_OUT_DIR}/data"
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py generate-data",
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished generating test data")
# Out:
# 2025-05-09 20:27:03.419 | INFO     | __main__:<module>:4 - Generating test data...
# 2025-05-09 20:27:09.200 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:27:09.202 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:28:43.879 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:28:43.881 | INFO     | __main__:<module>:27 - Finished generating test data

# %% [markdown]
# We'll start by running the operator without memory constraints to check the memory usage.

# %%
memory_usage_log_file = f"docker-monitor/memory-usage--0-pct-pressure.log"
page_faults_log_file = f"docker-monitor/page-faults--0-pct-pressure.log"

tools.docker.drop_caches_in_container()

logger.info("Launching experiment...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "operate",
        "envelope",
        "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
        "--memory-profiler", "psutil",
        "--memory-profile-output-dir", f"{CONTAINER_OUT_DIR}/profiler",
        "--memory-profile-session-id", f"{INLINES}-{XLINES}-{SAMPLES}-0-pct-pressure",
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished executing experiment")
# Out:
# 2025-05-09 20:28:44.198 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:28:44.199 | INFO     | __main__:<module>:6 - Launching experiment...
# 2025-05-09 20:28:44.322 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:28:44.323 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:28:53.545 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:28:53.547 | INFO     | __main__:<module>:30 - Finished executing experiment

# %%
from traceq import load_profile
import tools.conversions

importlib.reload(tools.conversions)

profiles = os.listdir(f"../{RELATIVE_OUT_DIR}/profiler")
profile_path = [profile for profile in profiles if f"{INLINES}-{XLINES}-{SAMPLES}-0-pct-pressure" in profile][0]
psutil_profile = load_profile(f"../{RELATIVE_OUT_DIR}/profiler/{profile_path}")
psutil_peak_memory_usage = tools.conversions.b_to_mb(
    max(entry["psutil_memory_usage"] for entry in psutil_profile["data"]))

logger.info(f"Tracer captured {len(psutil_profile["data"])} traces")
logger.info(f"Peak memory usage from psutil profile: {tools.conversions.mb_to_gb(psutil_peak_memory_usage)} GB")
# Out:
# 2025-05-09 20:28:53.684 | INFO     | __main__:<module>:12 - Tracer captured 234 traces
# 2025-05-09 20:28:53.684 | INFO     | __main__:<module>:13 - Peak memory usage from psutil profile: 5.2056732177734375 GB

# %% [markdown]
# Now, we're going to run the operator with memory constraints to check the memory usage.
# The idea is to execute with less memory than the peak memory usage to check if the operator breaks.

# %%
memory_usage_log_file = f"docker-monitor/memory-usage--1-pct-pressure.log"
page_faults_log_file = f"docker-monitor/page-faults--1-pct-pressure.log"

psutil_peak_memory_usage_99_pct = int(float(psutil_peak_memory_usage) * 0.99)
logger.info(f"Memory limit will be {tools.conversions.mb_to_gb(psutil_peak_memory_usage_99_pct)} GB")

tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)

logger.info("Launching experiment...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "operate",
        "envelope",
        "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
        "--memory-profiler", "psutil",
        "--memory-profile-output-dir", f"{CONTAINER_OUT_DIR}/profiler",
        "--memory-profile-session-id", f"{INLINES}-{XLINES}-{SAMPLES}-1-pct-pressure",
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        "MEMORY_LIMIT_MB": psutil_peak_memory_usage_99_pct,
        "MEMORY_PRESSURE_LOG_FILE": f"{CONTAINER_OUT_DIR}/docker-monitor/memory-pressure.log",
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished executing experiment")
# Out:
# 2025-05-09 20:28:53.691 | INFO     | __main__:<module>:5 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:28:53.692 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# 2025-05-09 20:28:54.270 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 20:28:54.271 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 20:29:02.864 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 20:29:02.865 | INFO     | __main__:<module>:9 - Launching experiment...
# 2025-05-09 20:29:03.325 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:03.327 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:29:12.486 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:29:12.487 | INFO     | __main__:<module>:35 - Finished executing experiment

# %%
import tools.monitor

importlib.reload(tools.monitor)
importlib.reload(tools.conversions)

docker_monitor_1_pct_pressure_mu_df = tools.monitor.memory_usage_log_to_df(
    f"../{RELATIVE_OUT_DIR}/docker-monitor/memory-usage--1-pct-pressure.log",
)

profiles = os.listdir(f"../{RELATIVE_OUT_DIR}/profiler")
profile_path = [profile for profile in profiles if f"{INLINES}-{XLINES}-{SAMPLES}-1-pct-pressure" in profile][0]
psutil_1_pct_pressure_profile = load_profile(
    f"../{RELATIVE_OUT_DIR}/profiler/{profile_path}")
psutil_1_pct_pressure_peak_memory_usage = tools.conversions.b_to_gb(
    max(entry["psutil_memory_usage"] for entry in psutil_1_pct_pressure_profile["data"]))

docker_monitor_1_pct_pressure_peak_memory_usage = tools.conversions.kb_to_gb(
    docker_monitor_1_pct_pressure_mu_df["memory_usage_kb"].max()
)

logger.info(f"Tracer captured {len(psutil_1_pct_pressure_profile["data"])} traces")
logger.info(f"Docker monitor captured {len(docker_monitor_1_pct_pressure_mu_df)} traces")
logger.info(f"Peak memory usage from psutil profile: {psutil_1_pct_pressure_peak_memory_usage} GB")
logger.info("Peak memory usage from Docker monitor: {} GB".format(docker_monitor_1_pct_pressure_peak_memory_usage))
logger.info(f"Docker limit memory usage: {tools.conversions.mb_to_gb(psutil_peak_memory_usage_99_pct)} GB")
# Out:
# 2025-05-09 20:29:12.507 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure.log
# 2025-05-09 20:29:12.510 | INFO     | __main__:<module>:21 - Tracer captured 224 traces
# 2025-05-09 20:29:12.510 | INFO     | __main__:<module>:22 - Docker monitor captured 410 traces
# 2025-05-09 20:29:12.511 | INFO     | __main__:<module>:23 - Peak memory usage from psutil profile: 5.098224639892578 GB
# 2025-05-09 20:29:12.511 | INFO     | __main__:<module>:24 - Peak memory usage from Docker monitor: 5.15325927734375 GB
# 2025-05-09 20:29:12.511 | INFO     | __main__:<module>:25 - Docker limit memory usage: 5.1533203125 GB

# %% [markdown]
# As we can see, even with a 1% memory constraint, the operator was able to execute successfully.
# For some reason, the profiler reports a memory usage higher than the limit set by Docker.
# Let's try with a stricter constraint.

# %%
memory_usage_log_file = f"docker-monitor/memory-usage--5-pct-pressure.log"
page_faults_log_file = f"docker-monitor/page-faults--5-pct-pressure.log"

psutil_peak_memory_usage_95_pct = int(float(psutil_peak_memory_usage) * 0.95)
logger.info(f"Memory limit will be {tools.conversions.mb_to_gb(psutil_peak_memory_usage_95_pct)} GB")

logger.info("Launching experiment...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "operate",
        "envelope",
        "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
        "--memory-profiler", "psutil",
        "--memory-profile-output-dir", f"{CONTAINER_OUT_DIR}/profiler",
        "--memory-profile-session-id", f"{INLINES}-{XLINES}-{SAMPLES}-5-pct-pressure",
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
        "MEMORY_LIMIT_MB": psutil_peak_memory_usage_95_pct,
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        }
    },
)
logger.info("Finished executing experiment")
# Out:
# 2025-05-09 20:29:12.528 | INFO     | __main__:<module>:5 - Memory limit will be 4.9453125 GB
# 2025-05-09 20:29:12.529 | INFO     | __main__:<module>:7 - Launching experiment...
# 2025-05-09 20:29:12.844 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:12.846 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:29:22.757 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:29:22.758 | INFO     | __main__:<module>:32 - Finished executing experiment

# %% [markdown]
# As we can see, even with 5% memory pressure the experiment still runs.
# In this case we can see that the profiler reports a memory usage close to the limit set by Docker, which is expected.
# Now, let's try increasing the pressure until it breaks.

# %%
# Remove the log files of the pressure experiment so far
profiler_dir_path = f"../{RELATIVE_OUT_DIR}/profiler"
docker_monitor_dir_path = f"../{RELATIVE_OUT_DIR}/docker-monitor"

profile_files = os.listdir(profiler_dir_path)
docker_monitor_files = os.listdir(docker_monitor_dir_path)

for file in profile_files:
    if "pct-pressure" in file:
        os.remove(f"{profiler_dir_path}/{file}")

for file in docker_monitor_files:
    if "pct-pressure" in file:
        os.remove(f"{docker_monitor_dir_path}/{file}")

# %%
def list_profiles(prefix: str):
    profiler_dir_path = f"../{RELATIVE_OUT_DIR}/profiler"
    profile_files = os.listdir(profiler_dir_path)
    return [file for file in profile_files if prefix in file]


def get_avg_memory_usage(prefix: str):
    profiles = list_profiles(prefix)
    peak_memory_usages = []

    for profile in profiles:
        psutil_profile = load_profile(f"../{RELATIVE_OUT_DIR}/profiler/{profile}")
        peak_memory_usages.append(
            tools.conversions.b_to_gb(
                max(entry["psutil_memory_usage"] for entry in psutil_profile["data"])
            )
        )

    return sum(peak_memory_usages) / len(peak_memory_usages)


def experiment(pressure_pct: int, peak_memory_usage: str = psutil_peak_memory_usage, iterations: int = 5):
    logger.info(f"Running experiment with {pressure_pct}% pressure")

    logger.info(
        f"Recorded peak memory usage without memory pressure was: {tools.conversions.mb_to_gb(peak_memory_usage)} GB")

    profile_prefix = f"{INLINES}-{XLINES}-{SAMPLES}-{pressure_pct}-pct-pressure"

    for i in range(iterations):
        logger.info(f"Running iteration {i + 1}...")

        memory_usage_log_file = f"docker-monitor/memory-usage--{pressure_pct}-pct-pressure-{i}.log"
        page_faults_log_file = f"docker-monitor/page-faults--{pressure_pct}-pct-pressure-{i}.log"
        memory_pressure_log_file = f"docker-monitor/memory-pressure--{pressure_pct}-pct-pressure-{i}.log"

        mem_limit = int(float(peak_memory_usage) * ((100 - pressure_pct) / 100))

        logger.info(f"Memory limit will be {tools.conversions.mb_to_gb(mem_limit)} GB")

        logger.info("Launching experiment...")
        result = tools.docker.run_isolated_container(
            client=vfs_client,
            image_name=EXPERIMENT_IMAGE,
            command=[
                "operate",
                "envelope",
                "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
                "--memory-profiler", "psutil",
                "--memory-profile-output-dir", f"{CONTAINER_OUT_DIR}/profiler",
                "--memory-profile-session-id", f"{profile_prefix}-{i}",
            ],
            environment={
                "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
                "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
                "MEMORY_PRESSURE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_pressure_log_file}",
                "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
                "MEMORY_LIMIT_MB": mem_limit,
            },
            volumes={
                "/mnt/out": {
                    "bind": CONTAINER_OUT_DIR,
                    "mode": "rw",
                }
            },
        )
        status_code = result["StatusCode"]

        try:
            logger.info(f"Container exited with code: {status_code}")
            logger.info("Finished executing experiment")

            docker_monitor_mu_df = tools.monitor.memory_usage_log_to_df(
                f"../{RELATIVE_OUT_DIR}/{memory_usage_log_file}",
            )

            profiles = os.listdir(f"../{RELATIVE_OUT_DIR}/profiler")
            profile_path = [profile for profile in profiles if f"{profile_prefix}-{i}" in profile][0]
            psutil_profile = load_profile(
                f"../{RELATIVE_OUT_DIR}/profiler/{profile_path}")
            psutil_peak_memory_usage = tools.conversions.b_to_gb(
                max(entry["psutil_memory_usage"] for entry in psutil_profile["data"]))

            docker_monitor_peak_memory_usage = tools.conversions.kb_to_gb(
                docker_monitor_mu_df["memory_usage_kb"].max()
            )

            logger.info(f"Tracer captured {len(psutil_profile["data"])} traces")
            logger.info(f"Docker monitor captured {len(docker_monitor_mu_df)} traces")
            logger.info(f"Peak memory usage from psutil profile: {psutil_peak_memory_usage} GB")
            logger.info("Peak memory usage from Docker monitor: {} GB".format(docker_monitor_peak_memory_usage))
            logger.info(f"Docker limit memory usage: {tools.conversions.mb_to_gb(mem_limit)} GB")
        except Exception as _:
            pass

        yield status_code

    avg_memory_usage = get_avg_memory_usage(profile_prefix)
    logger.info(f"Average memory usage for {pressure_pct}% pressure: {avg_memory_usage} GB")

# %%
pressure_pct = 0
pressure_step = 1

while True:
    try:
        for status_code in experiment(pressure_pct=pressure_pct):
            logger.info(f"Experiment exited with code: {status_code}")
            if status_code != 0:
                raise Exception(f"Experiment failed with {pressure_pct}% pressure")
    except Exception as e:
        logger.error(f"Experiment threw an exception with {pressure_pct}% pressure")
        logger.error(e)
        break

    pressure_pct += pressure_step
# Out:
# 2025-05-09 20:29:22.800 | INFO     | __main__:experiment:23 - Running experiment with 0% pressure
# 2025-05-09 20:29:22.800 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:29:22.800 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:29:22.800 | INFO     | __main__:experiment:39 - Memory limit will be 5.205078125 GB
# 2025-05-09 20:29:22.801 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:29:23.102 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:23.106 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:29:32.789 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:29:32.790 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:29:32.791 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:29:32.791 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-0.log
# 2025-05-09 20:29:32.796 | INFO     | __main__:experiment:88 - Tracer captured 262 traces
# 2025-05-09 20:29:32.796 | INFO     | __main__:experiment:89 - Docker monitor captured 466 traces
# 2025-05-09 20:29:32.797 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.147407531738281 GB
# 2025-05-09 20:29:32.797 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.2049713134765625 GB
# 2025-05-09 20:29:32.798 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.205078125 GB
# 2025-05-09 20:29:32.798 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:29:32.798 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:29:32.799 | INFO     | __main__:experiment:39 - Memory limit will be 5.205078125 GB
# 2025-05-09 20:29:32.800 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:29:33.298 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:33.300 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:29:42.422 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:29:42.423 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:29:42.424 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:29:42.424 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-1.log
# 2025-05-09 20:29:42.429 | INFO     | __main__:experiment:88 - Tracer captured 207 traces
# 2025-05-09 20:29:42.429 | INFO     | __main__:experiment:89 - Docker monitor captured 415 traces
# 2025-05-09 20:29:42.430 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.149707794189453 GB
# 2025-05-09 20:29:42.430 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.205055236816406 GB
# 2025-05-09 20:29:42.431 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.205078125 GB
# 2025-05-09 20:29:42.431 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:29:42.431 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:29:42.432 | INFO     | __main__:experiment:39 - Memory limit will be 5.205078125 GB
# 2025-05-09 20:29:42.433 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:29:43.025 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:43.026 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:29:52.998 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:29:52.999 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:29:52.999 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:29:53.000 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-2.log
# 2025-05-09 20:29:53.004 | INFO     | __main__:experiment:88 - Tracer captured 249 traces
# 2025-05-09 20:29:53.005 | INFO     | __main__:experiment:89 - Docker monitor captured 477 traces
# 2025-05-09 20:29:53.005 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.150962829589844 GB
# 2025-05-09 20:29:53.006 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.205036163330078 GB
# 2025-05-09 20:29:53.006 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.205078125 GB
# 2025-05-09 20:29:53.007 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:29:53.007 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:29:53.007 | INFO     | __main__:experiment:39 - Memory limit will be 5.205078125 GB
# 2025-05-09 20:29:53.008 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:29:53.434 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:29:53.435 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:03.137 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:03.138 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:03.139 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:03.140 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-3.log
# 2025-05-09 20:30:03.144 | INFO     | __main__:experiment:88 - Tracer captured 266 traces
# 2025-05-09 20:30:03.144 | INFO     | __main__:experiment:89 - Docker monitor captured 464 traces
# 2025-05-09 20:30:03.145 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.1506195068359375 GB
# 2025-05-09 20:30:03.146 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.205051422119141 GB
# 2025-05-09 20:30:03.147 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.205078125 GB
# 2025-05-09 20:30:03.147 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:03.148 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:30:03.149 | INFO     | __main__:experiment:39 - Memory limit will be 5.205078125 GB
# 2025-05-09 20:30:03.149 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:03.638 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:03.640 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:13.653 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:13.655 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:13.656 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:13.656 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-4.log
# 2025-05-09 20:30:13.661 | INFO     | __main__:experiment:88 - Tracer captured 260 traces
# 2025-05-09 20:30:13.661 | INFO     | __main__:experiment:89 - Docker monitor captured 483 traces
# 2025-05-09 20:30:13.662 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.1474761962890625 GB
# 2025-05-09 20:30:13.662 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.205047607421875 GB
# 2025-05-09 20:30:13.663 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.205078125 GB
# 2025-05-09 20:30:13.663 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:13.667 | INFO     | __main__:experiment:99 - Average memory usage for 0% pressure: 5.149234771728516 GB
# 2025-05-09 20:30:13.667 | INFO     | __main__:experiment:23 - Running experiment with 1% pressure
# 2025-05-09 20:30:13.668 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:30:13.668 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:30:13.668 | INFO     | __main__:experiment:39 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:30:13.668 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:14.048 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:14.050 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:24.071 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:24.072 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:24.073 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:24.073 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-0.log
# 2025-05-09 20:30:24.082 | INFO     | __main__:experiment:88 - Tracer captured 245 traces
# 2025-05-09 20:30:24.083 | INFO     | __main__:experiment:89 - Docker monitor captured 475 traces
# 2025-05-09 20:30:24.083 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.098381042480469 GB
# 2025-05-09 20:30:24.084 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.153133392333984 GB
# 2025-05-09 20:30:24.084 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1533203125 GB
# 2025-05-09 20:30:24.084 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:24.084 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:30:24.085 | INFO     | __main__:experiment:39 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:30:24.085 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:24.504 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:24.506 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:33.856 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:33.857 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:33.858 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:33.858 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-1.log
# 2025-05-09 20:30:33.863 | INFO     | __main__:experiment:88 - Tracer captured 251 traces
# 2025-05-09 20:30:33.864 | INFO     | __main__:experiment:89 - Docker monitor captured 444 traces
# 2025-05-09 20:30:33.865 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.097381591796875 GB
# 2025-05-09 20:30:33.865 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.1533050537109375 GB
# 2025-05-09 20:30:33.866 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1533203125 GB
# 2025-05-09 20:30:33.866 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:33.867 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:30:33.868 | INFO     | __main__:experiment:39 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:30:33.868 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:34.320 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:34.321 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:43.189 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:43.190 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:43.190 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:43.191 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-2.log
# 2025-05-09 20:30:43.195 | INFO     | __main__:experiment:88 - Tracer captured 197 traces
# 2025-05-09 20:30:43.196 | INFO     | __main__:experiment:89 - Docker monitor captured 398 traces
# 2025-05-09 20:30:43.197 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.096260070800781 GB
# 2025-05-09 20:30:43.197 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.153240203857422 GB
# 2025-05-09 20:30:43.198 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1533203125 GB
# 2025-05-09 20:30:43.198 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:43.198 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:30:43.199 | INFO     | __main__:experiment:39 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:30:43.199 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:43.693 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:43.694 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:30:52.944 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:30:52.945 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:30:52.946 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:30:52.946 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-3.log
# 2025-05-09 20:30:52.951 | INFO     | __main__:experiment:88 - Tracer captured 258 traces
# 2025-05-09 20:30:52.952 | INFO     | __main__:experiment:89 - Docker monitor captured 436 traces
# 2025-05-09 20:30:52.952 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.098236083984375 GB
# 2025-05-09 20:30:52.953 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.1532440185546875 GB
# 2025-05-09 20:30:52.954 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1533203125 GB
# 2025-05-09 20:30:52.954 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:30:52.954 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:30:52.955 | INFO     | __main__:experiment:39 - Memory limit will be 5.1533203125 GB
# 2025-05-09 20:30:52.956 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:30:53.427 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:30:53.428 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:03.143 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:03.144 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:03.145 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:03.146 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-4.log
# 2025-05-09 20:31:03.151 | INFO     | __main__:experiment:88 - Tracer captured 241 traces
# 2025-05-09 20:31:03.152 | INFO     | __main__:experiment:89 - Docker monitor captured 446 traces
# 2025-05-09 20:31:03.152 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.097419738769531 GB
# 2025-05-09 20:31:03.153 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.15325927734375 GB
# 2025-05-09 20:31:03.153 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1533203125 GB
# 2025-05-09 20:31:03.154 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:03.158 | INFO     | __main__:experiment:99 - Average memory usage for 1% pressure: 5.097535705566406 GB
# 2025-05-09 20:31:03.158 | INFO     | __main__:experiment:23 - Running experiment with 2% pressure
# 2025-05-09 20:31:03.158 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:31:03.159 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:31:03.159 | INFO     | __main__:experiment:39 - Memory limit will be 5.1005859375 GB
# 2025-05-09 20:31:03.159 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:03.542 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:03.543 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:13.260 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:13.261 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:13.262 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:13.263 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-0.log
# 2025-05-09 20:31:13.267 | INFO     | __main__:experiment:88 - Tracer captured 271 traces
# 2025-05-09 20:31:13.268 | INFO     | __main__:experiment:89 - Docker monitor captured 456 traces
# 2025-05-09 20:31:13.268 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.045200347900391 GB
# 2025-05-09 20:31:13.269 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.099769592285156 GB
# 2025-05-09 20:31:13.269 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1005859375 GB
# 2025-05-09 20:31:13.270 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:13.270 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:31:13.270 | INFO     | __main__:experiment:39 - Memory limit will be 5.1005859375 GB
# 2025-05-09 20:31:13.271 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:13.731 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:13.732 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:22.314 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:22.316 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:22.317 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:22.318 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-1.log
# 2025-05-09 20:31:22.322 | INFO     | __main__:experiment:88 - Tracer captured 194 traces
# 2025-05-09 20:31:22.323 | INFO     | __main__:experiment:89 - Docker monitor captured 383 traces
# 2025-05-09 20:31:22.324 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.043098449707031 GB
# 2025-05-09 20:31:22.325 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.100578308105469 GB
# 2025-05-09 20:31:22.326 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1005859375 GB
# 2025-05-09 20:31:22.327 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:22.327 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:31:22.328 | INFO     | __main__:experiment:39 - Memory limit will be 5.1005859375 GB
# 2025-05-09 20:31:22.328 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:22.754 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:22.756 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:32.572 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:32.573 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:32.574 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:32.575 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-2.log
# 2025-05-09 20:31:32.579 | INFO     | __main__:experiment:88 - Tracer captured 268 traces
# 2025-05-09 20:31:32.580 | INFO     | __main__:experiment:89 - Docker monitor captured 465 traces
# 2025-05-09 20:31:32.581 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.0439910888671875 GB
# 2025-05-09 20:31:32.582 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.100273132324219 GB
# 2025-05-09 20:31:32.582 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1005859375 GB
# 2025-05-09 20:31:32.583 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:32.584 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:31:32.584 | INFO     | __main__:experiment:39 - Memory limit will be 5.1005859375 GB
# 2025-05-09 20:31:32.584 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:32.934 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:32.936 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:43.396 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:43.398 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:43.399 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:43.399 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-3.log
# 2025-05-09 20:31:43.404 | INFO     | __main__:experiment:88 - Tracer captured 292 traces
# 2025-05-09 20:31:43.404 | INFO     | __main__:experiment:89 - Docker monitor captured 496 traces
# 2025-05-09 20:31:43.405 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.042064666748047 GB
# 2025-05-09 20:31:43.406 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.100528717041016 GB
# 2025-05-09 20:31:43.407 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1005859375 GB
# 2025-05-09 20:31:43.408 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:43.408 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:31:43.409 | INFO     | __main__:experiment:39 - Memory limit will be 5.1005859375 GB
# 2025-05-09 20:31:43.409 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:43.803 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:43.804 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:31:53.305 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:31:53.307 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:31:53.307 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:31:53.308 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-4.log
# 2025-05-09 20:31:53.314 | INFO     | __main__:experiment:88 - Tracer captured 230 traces
# 2025-05-09 20:31:53.315 | INFO     | __main__:experiment:89 - Docker monitor captured 423 traces
# 2025-05-09 20:31:53.316 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 5.039653778076172 GB
# 2025-05-09 20:31:53.318 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.1005859375 GB
# 2025-05-09 20:31:53.318 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.1005859375 GB
# 2025-05-09 20:31:53.318 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:31:53.322 | INFO     | __main__:experiment:99 - Average memory usage for 2% pressure: 5.0428016662597654 GB
# 2025-05-09 20:31:53.322 | INFO     | __main__:experiment:23 - Running experiment with 3% pressure
# 2025-05-09 20:31:53.323 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:31:53.323 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:31:53.323 | INFO     | __main__:experiment:39 - Memory limit will be 5.048828125 GB
# 2025-05-09 20:31:53.324 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:31:53.721 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:31:53.722 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:03.456 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:03.457 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:03.458 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:03.458 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-0.log
# 2025-05-09 20:32:03.463 | INFO     | __main__:experiment:88 - Tracer captured 259 traces
# 2025-05-09 20:32:03.463 | INFO     | __main__:experiment:89 - Docker monitor captured 469 traces
# 2025-05-09 20:32:03.464 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.990779876708984 GB
# 2025-05-09 20:32:03.465 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.048625946044922 GB
# 2025-05-09 20:32:03.465 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.048828125 GB
# 2025-05-09 20:32:03.465 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:03.466 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:32:03.466 | INFO     | __main__:experiment:39 - Memory limit will be 5.048828125 GB
# 2025-05-09 20:32:03.467 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:03.866 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:03.868 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:13.762 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:13.763 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:13.763 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:13.764 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-1.log
# 2025-05-09 20:32:13.767 | INFO     | __main__:experiment:88 - Tracer captured 251 traces
# 2025-05-09 20:32:13.768 | INFO     | __main__:experiment:89 - Docker monitor captured 483 traces
# 2025-05-09 20:32:13.768 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.996669769287109 GB
# 2025-05-09 20:32:13.768 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.048793792724609 GB
# 2025-05-09 20:32:13.769 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.048828125 GB
# 2025-05-09 20:32:13.770 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:13.770 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:32:13.770 | INFO     | __main__:experiment:39 - Memory limit will be 5.048828125 GB
# 2025-05-09 20:32:13.771 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:14.301 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:14.302 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:23.870 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:23.871 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:23.872 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:23.873 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-2.log
# 2025-05-09 20:32:23.880 | INFO     | __main__:experiment:88 - Tracer captured 248 traces
# 2025-05-09 20:32:23.882 | INFO     | __main__:experiment:89 - Docker monitor captured 455 traces
# 2025-05-09 20:32:23.882 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.992900848388672 GB
# 2025-05-09 20:32:23.883 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.048820495605469 GB
# 2025-05-09 20:32:23.883 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.048828125 GB
# 2025-05-09 20:32:23.883 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:23.884 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:32:23.884 | INFO     | __main__:experiment:39 - Memory limit will be 5.048828125 GB
# 2025-05-09 20:32:23.884 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:24.296 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:24.298 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:33.357 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:33.359 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:33.359 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:33.360 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-3.log
# 2025-05-09 20:32:33.365 | INFO     | __main__:experiment:88 - Tracer captured 219 traces
# 2025-05-09 20:32:33.365 | INFO     | __main__:experiment:89 - Docker monitor captured 393 traces
# 2025-05-09 20:32:33.366 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.992767333984375 GB
# 2025-05-09 20:32:33.366 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.048702239990234 GB
# 2025-05-09 20:32:33.367 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.048828125 GB
# 2025-05-09 20:32:33.368 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:33.368 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:32:33.369 | INFO     | __main__:experiment:39 - Memory limit will be 5.048828125 GB
# 2025-05-09 20:32:33.370 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:33.776 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:33.777 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:43.297 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:43.299 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:43.300 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:43.300 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-4.log
# 2025-05-09 20:32:43.307 | INFO     | __main__:experiment:88 - Tracer captured 254 traces
# 2025-05-09 20:32:43.307 | INFO     | __main__:experiment:89 - Docker monitor captured 456 traces
# 2025-05-09 20:32:43.308 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.992771148681641 GB
# 2025-05-09 20:32:43.308 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 5.048778533935547 GB
# 2025-05-09 20:32:43.309 | INFO     | __main__:experiment:92 - Docker limit memory usage: 5.048828125 GB
# 2025-05-09 20:32:43.309 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:43.314 | INFO     | __main__:experiment:99 - Average memory usage for 3% pressure: 4.993177795410157 GB
# 2025-05-09 20:32:43.314 | INFO     | __main__:experiment:23 - Running experiment with 4% pressure
# 2025-05-09 20:32:43.314 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:32:43.315 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:32:43.315 | INFO     | __main__:experiment:39 - Memory limit will be 4.9970703125 GB
# 2025-05-09 20:32:43.315 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:43.736 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:43.738 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:32:52.555 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:32:52.556 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:32:52.556 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:32:52.557 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-0.log
# 2025-05-09 20:32:52.559 | INFO     | __main__:experiment:88 - Tracer captured 201 traces
# 2025-05-09 20:32:52.559 | INFO     | __main__:experiment:89 - Docker monitor captured 398 traces
# 2025-05-09 20:32:52.559 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.967964172363281 GB
# 2025-05-09 20:32:52.560 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.9970550537109375 GB
# 2025-05-09 20:32:52.560 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9970703125 GB
# 2025-05-09 20:32:52.560 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:32:52.560 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:32:52.560 | INFO     | __main__:experiment:39 - Memory limit will be 4.9970703125 GB
# 2025-05-09 20:32:52.560 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:32:53.117 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:32:53.118 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:03.188 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:03.190 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:03.190 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:03.191 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-1.log
# 2025-05-09 20:33:03.196 | INFO     | __main__:experiment:88 - Tracer captured 261 traces
# 2025-05-09 20:33:03.196 | INFO     | __main__:experiment:89 - Docker monitor captured 484 traces
# 2025-05-09 20:33:03.197 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.943939208984375 GB
# 2025-05-09 20:33:03.198 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.996826171875 GB
# 2025-05-09 20:33:03.198 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9970703125 GB
# 2025-05-09 20:33:03.199 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:03.199 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:33:03.200 | INFO     | __main__:experiment:39 - Memory limit will be 4.9970703125 GB
# 2025-05-09 20:33:03.200 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:03.716 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:03.718 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:12.634 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:12.635 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:12.636 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:12.637 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-2.log
# 2025-05-09 20:33:12.642 | INFO     | __main__:experiment:88 - Tracer captured 209 traces
# 2025-05-09 20:33:12.642 | INFO     | __main__:experiment:89 - Docker monitor captured 404 traces
# 2025-05-09 20:33:12.643 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.942329406738281 GB
# 2025-05-09 20:33:12.644 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.997013092041016 GB
# 2025-05-09 20:33:12.644 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9970703125 GB
# 2025-05-09 20:33:12.645 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:12.645 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:33:12.647 | INFO     | __main__:experiment:39 - Memory limit will be 4.9970703125 GB
# 2025-05-09 20:33:12.647 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:13.088 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:13.090 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:22.432 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:22.434 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:22.434 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:22.435 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-3.log
# 2025-05-09 20:33:22.440 | INFO     | __main__:experiment:88 - Tracer captured 206 traces
# 2025-05-09 20:33:22.441 | INFO     | __main__:experiment:89 - Docker monitor captured 396 traces
# 2025-05-09 20:33:22.441 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.943279266357422 GB
# 2025-05-09 20:33:22.442 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.9970703125 GB
# 2025-05-09 20:33:22.442 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9970703125 GB
# 2025-05-09 20:33:22.443 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:22.443 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:33:22.444 | INFO     | __main__:experiment:39 - Memory limit will be 4.9970703125 GB
# 2025-05-09 20:33:22.445 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:22.857 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:22.859 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:32.784 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:32.786 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:32.787 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:32.787 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-4.log
# 2025-05-09 20:33:32.793 | INFO     | __main__:experiment:88 - Tracer captured 273 traces
# 2025-05-09 20:33:32.794 | INFO     | __main__:experiment:89 - Docker monitor captured 472 traces
# 2025-05-09 20:33:32.795 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.941867828369141 GB
# 2025-05-09 20:33:32.795 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.9968109130859375 GB
# 2025-05-09 20:33:32.796 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9970703125 GB
# 2025-05-09 20:33:32.796 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:32.800 | INFO     | __main__:experiment:99 - Average memory usage for 4% pressure: 4.9478759765625 GB
# 2025-05-09 20:33:32.800 | INFO     | __main__:experiment:23 - Running experiment with 5% pressure
# 2025-05-09 20:33:32.800 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:33:32.801 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:33:32.801 | INFO     | __main__:experiment:39 - Memory limit will be 4.9453125 GB
# 2025-05-09 20:33:32.801 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:33.152 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:33.154 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:41.961 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:41.962 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:41.963 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:41.964 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-0.log
# 2025-05-09 20:33:41.968 | INFO     | __main__:experiment:88 - Tracer captured 203 traces
# 2025-05-09 20:33:41.969 | INFO     | __main__:experiment:89 - Docker monitor captured 402 traces
# 2025-05-09 20:33:41.969 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.888332366943359 GB
# 2025-05-09 20:33:41.970 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.945274353027344 GB
# 2025-05-09 20:33:41.970 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9453125 GB
# 2025-05-09 20:33:41.971 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:41.971 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:33:41.971 | INFO     | __main__:experiment:39 - Memory limit will be 4.9453125 GB
# 2025-05-09 20:33:41.972 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:42.366 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:42.368 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:33:51.794 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:33:51.795 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:33:51.796 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:33:51.796 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-1.log
# 2025-05-09 20:33:51.801 | INFO     | __main__:experiment:88 - Tracer captured 224 traces
# 2025-05-09 20:33:51.802 | INFO     | __main__:experiment:89 - Docker monitor captured 426 traces
# 2025-05-09 20:33:51.802 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.889457702636719 GB
# 2025-05-09 20:33:51.803 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.945125579833984 GB
# 2025-05-09 20:33:51.803 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.9453125 GB
# 2025-05-09 20:33:51.803 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:33:51.804 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:33:51.804 | INFO     | __main__:experiment:39 - Memory limit will be 4.9453125 GB
# 2025-05-09 20:33:51.805 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:33:52.203 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:33:52.204 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:34:01.181 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:34:01.183 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:34:01.184 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:34:01.184 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-2.log
# 2025-05-09 20:34:01.189 | INFO     | __main__:experiment:88 - Tracer captured 211 traces
# 2025-05-09 20:34:01.189 | INFO     | __main__:experiment:89 - Docker monitor captured 406 traces
# 2025-05-09 20:34:01.190 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.892364501953125 GB
# 2025-05-09 20:34:01.191 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.945285797119141 GB
# ...
# 2025-05-09 20:43:55.310 | INFO     | __main__:experiment:88 - Tracer captured 259 traces
# 2025-05-09 20:43:55.311 | INFO     | __main__:experiment:89 - Docker monitor captured 480 traces
# 2025-05-09 20:43:55.311 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.266689300537109 GB
# 2025-05-09 20:43:55.311 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.319499969482422 GB
# 2025-05-09 20:43:55.311 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.3203125 GB
# 2025-05-09 20:43:55.312 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:43:55.312 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:43:55.312 | INFO     | __main__:experiment:39 - Memory limit will be 4.3203125 GB
# 2025-05-09 20:43:55.312 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:43:55.720 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:43:55.721 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:04.790 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:04.791 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:04.791 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:04.791 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-2.log
# 2025-05-09 20:44:04.793 | INFO     | __main__:experiment:88 - Tracer captured 205 traces
# 2025-05-09 20:44:04.794 | INFO     | __main__:experiment:89 - Docker monitor captured 413 traces
# 2025-05-09 20:44:04.794 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.298419952392578 GB
# 2025-05-09 20:44:04.794 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.32012939453125 GB
# 2025-05-09 20:44:04.794 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.3203125 GB
# 2025-05-09 20:44:04.794 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:04.794 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:44:04.795 | INFO     | __main__:experiment:39 - Memory limit will be 4.3203125 GB
# 2025-05-09 20:44:04.795 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:05.231 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:05.232 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:14.590 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:14.591 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:14.592 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:14.592 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-3.log
# 2025-05-09 20:44:14.594 | INFO     | __main__:experiment:88 - Tracer captured 221 traces
# 2025-05-09 20:44:14.594 | INFO     | __main__:experiment:89 - Docker monitor captured 435 traces
# 2025-05-09 20:44:14.595 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.298366546630859 GB
# 2025-05-09 20:44:14.595 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.320068359375 GB
# 2025-05-09 20:44:14.595 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.3203125 GB
# 2025-05-09 20:44:14.595 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:14.595 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:44:14.596 | INFO     | __main__:experiment:39 - Memory limit will be 4.3203125 GB
# 2025-05-09 20:44:14.596 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:15.008 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:15.009 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:24.820 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:24.820 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:24.820 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:24.821 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-4.log
# 2025-05-09 20:44:24.823 | INFO     | __main__:experiment:88 - Tracer captured 232 traces
# 2025-05-09 20:44:24.823 | INFO     | __main__:experiment:89 - Docker monitor captured 472 traces
# 2025-05-09 20:44:24.823 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.300098419189453 GB
# 2025-05-09 20:44:24.824 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.320262908935547 GB
# 2025-05-09 20:44:24.824 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.3203125 GB
# 2025-05-09 20:44:24.824 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:24.826 | INFO     | __main__:experiment:99 - Average memory usage for 17% pressure: 4.286316680908203 GB
# 2025-05-09 20:44:24.826 | INFO     | __main__:experiment:23 - Running experiment with 18% pressure
# 2025-05-09 20:44:24.826 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:44:24.826 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:44:24.826 | INFO     | __main__:experiment:39 - Memory limit will be 4.2685546875 GB
# 2025-05-09 20:44:24.827 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:25.236 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:25.237 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:34.836 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:34.837 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:34.837 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:34.837 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-0.log
# 2025-05-09 20:44:34.840 | INFO     | __main__:experiment:88 - Tracer captured 264 traces
# 2025-05-09 20:44:34.840 | INFO     | __main__:experiment:89 - Docker monitor captured 463 traces
# 2025-05-09 20:44:34.840 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.241676330566406 GB
# 2025-05-09 20:44:34.840 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.268486022949219 GB
# 2025-05-09 20:44:34.840 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.2685546875 GB
# 2025-05-09 20:44:34.841 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:34.841 | INFO     | __main__:experiment:31 - Running iteration 2...
# 2025-05-09 20:44:34.841 | INFO     | __main__:experiment:39 - Memory limit will be 4.2685546875 GB
# 2025-05-09 20:44:34.841 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:35.260 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:35.261 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:44.711 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:44.712 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:44.712 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:44.712 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-1.log
# 2025-05-09 20:44:44.715 | INFO     | __main__:experiment:88 - Tracer captured 224 traces
# 2025-05-09 20:44:44.715 | INFO     | __main__:experiment:89 - Docker monitor captured 433 traces
# 2025-05-09 20:44:44.715 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.241996765136719 GB
# 2025-05-09 20:44:44.715 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.268424987792969 GB
# 2025-05-09 20:44:44.716 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.2685546875 GB
# 2025-05-09 20:44:44.716 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:44.716 | INFO     | __main__:experiment:31 - Running iteration 3...
# 2025-05-09 20:44:44.716 | INFO     | __main__:experiment:39 - Memory limit will be 4.2685546875 GB
# 2025-05-09 20:44:44.716 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:45.126 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:45.127 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:44:55.022 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:44:55.022 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:44:55.022 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:44:55.023 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-2.log
# 2025-05-09 20:44:55.025 | INFO     | __main__:experiment:88 - Tracer captured 245 traces
# 2025-05-09 20:44:55.025 | INFO     | __main__:experiment:89 - Docker monitor captured 484 traces
# 2025-05-09 20:44:55.025 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.241916656494141 GB
# 2025-05-09 20:44:55.025 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.268299102783203 GB
# 2025-05-09 20:44:55.025 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.2685546875 GB
# 2025-05-09 20:44:55.026 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:44:55.026 | INFO     | __main__:experiment:31 - Running iteration 4...
# 2025-05-09 20:44:55.026 | INFO     | __main__:experiment:39 - Memory limit will be 4.2685546875 GB
# 2025-05-09 20:44:55.026 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:44:55.430 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:44:55.431 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:45:04.825 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:45:04.826 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:45:04.826 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:45:04.826 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-3.log
# 2025-05-09 20:45:04.828 | INFO     | __main__:experiment:88 - Tracer captured 234 traces
# 2025-05-09 20:45:04.829 | INFO     | __main__:experiment:89 - Docker monitor captured 444 traces
# 2025-05-09 20:45:04.829 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.2291259765625 GB
# 2025-05-09 20:45:04.829 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.268455505371094 GB
# 2025-05-09 20:45:04.829 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.2685546875 GB
# 2025-05-09 20:45:04.829 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:45:04.830 | INFO     | __main__:experiment:31 - Running iteration 5...
# 2025-05-09 20:45:04.830 | INFO     | __main__:experiment:39 - Memory limit will be 4.2685546875 GB
# 2025-05-09 20:45:04.830 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:45:05.305 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:45:05.306 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:45:14.909 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:45:14.909 | INFO     | __main__:experiment:70 - Container exited with code: 0
# 2025-05-09 20:45:14.910 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:45:14.910 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-4.log
# 2025-05-09 20:45:14.912 | INFO     | __main__:experiment:88 - Tracer captured 254 traces
# 2025-05-09 20:45:14.912 | INFO     | __main__:experiment:89 - Docker monitor captured 452 traces
# 2025-05-09 20:45:14.913 | INFO     | __main__:experiment:90 - Peak memory usage from psutil profile: 4.234565734863281 GB
# 2025-05-09 20:45:14.913 | INFO     | __main__:experiment:91 - Peak memory usage from Docker monitor: 4.2685546875 GB
# 2025-05-09 20:45:14.913 | INFO     | __main__:experiment:92 - Docker limit memory usage: 4.2685546875 GB
# 2025-05-09 20:45:14.913 | INFO     | __main__:<module>:7 - Experiment exited with code: 0
# 2025-05-09 20:45:14.915 | INFO     | __main__:experiment:99 - Average memory usage for 18% pressure: 4.23785629272461 GB
# 2025-05-09 20:45:14.915 | INFO     | __main__:experiment:23 - Running experiment with 19% pressure
# 2025-05-09 20:45:14.915 | INFO     | __main__:experiment:25 - Recorded peak memory usage without memory pressure was: 5.2056732177734375 GB
# 2025-05-09 20:45:14.916 | INFO     | __main__:experiment:31 - Running iteration 1...
# 2025-05-09 20:45:14.916 | INFO     | __main__:experiment:39 - Memory limit will be 4.2158203125 GB
# 2025-05-09 20:45:14.916 | INFO     | __main__:experiment:41 - Launching experiment...
# 2025-05-09 20:45:15.311 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 20:45:15.312 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 20:45:24.511 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 20:45:24.512 | INFO     | __main__:experiment:70 - Container exited with code: 247
# 2025-05-09 20:45:24.512 | INFO     | __main__:experiment:71 - Finished executing experiment
# 2025-05-09 20:45:24.513 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--19-pct-pressure-0.log
# 2025-05-09 20:45:24.514 | INFO     | __main__:<module>:7 - Experiment exited with code: 247
# 2025-05-09 20:45:24.515 | ERROR    | __main__:<module>:11 - Experiment threw an exception with 19% pressure
# 2025-05-09 20:45:24.515 | ERROR    | __main__:<module>:12 - Experiment failed with 19% pressure

# %% [markdown]
# As we can see, the experiment was able to run even with a large amount of memory pressure.
# It only breaks after 90% pressure.
# Let's now evaluate the results.

# %%
# Removes the log files for the pressure that failed
docker_monitor_dir_path = f"../{RELATIVE_OUT_DIR}/docker-monitor"
docker_monitor_files = os.listdir(docker_monitor_dir_path)

for file in profile_files:
    if f"{pressure_pct}-pct-pressure" in file:
        os.remove(f"{profiler_dir_path}/{file}")

# %%
importlib.reload(tools.monitor)

filtered_profile_files = list_profiles("pressure")
captured_profile_names = [(file.split("-")[3], file.split("-")[6].split('.')[0]) for file in filtered_profile_files]
sorted_captured_profile_names = sorted(captured_profile_names, key=lambda x: (int(x[0]), int(x[1])))

docker_monitor_mu_dfs = [
    tools.monitor.memory_usage_log_to_df(
        f"../{RELATIVE_OUT_DIR}/docker-monitor/memory-usage--{pressure}-pct-pressure-{iteration}.log",
    ) for pressure, iteration in sorted_captured_profile_names
]

docker_monitor_pf_dfs = [
    tools.monitor.page_faults_log_to_df(
        f"../{RELATIVE_OUT_DIR}/docker-monitor/page-faults--{pressure}-pct-pressure-{iteration}.log",
    ) for pressure, iteration in sorted_captured_profile_names
]

docker_monitor_pressure_dfs = [
    tools.monitor.memory_pressure_log_to_df(
        f"../{RELATIVE_OUT_DIR}/docker-monitor/memory-pressure--{pressure}-pct-pressure-{iteration}.log",
    ) for pressure, iteration in sorted_captured_profile_names
]

memory_usage_profiles = [
    load_profile(
        f"../{RELATIVE_OUT_DIR}/profiler/{[profile for profile in os.listdir(f'../{RELATIVE_OUT_DIR}/profiler') if f'{pressure}-pct-pressure-{iteration}' in profile][0]}")
    for pressure, iteration in sorted_captured_profile_names
]

profiles = list(
    zip(
        sorted_captured_profile_names,
        docker_monitor_mu_dfs,
        docker_monitor_pf_dfs,
        docker_monitor_pressure_dfs,
        memory_usage_profiles,
    ),
)
# Out:
# 2025-05-09 20:59:23.987 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-0.log
# 2025-05-09 20:59:23.988 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-1.log
# 2025-05-09 20:59:23.989 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-2.log
# 2025-05-09 20:59:23.990 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-3.log
# 2025-05-09 20:59:23.992 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--0-pct-pressure-4.log
# 2025-05-09 20:59:23.993 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-0.log
# 2025-05-09 20:59:23.994 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-1.log
# 2025-05-09 20:59:23.995 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-2.log
# 2025-05-09 20:59:23.996 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-3.log
# 2025-05-09 20:59:23.997 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--1-pct-pressure-4.log
# 2025-05-09 20:59:23.998 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-0.log
# 2025-05-09 20:59:23.999 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-1.log
# 2025-05-09 20:59:24.000 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-2.log
# 2025-05-09 20:59:24.000 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-3.log
# 2025-05-09 20:59:24.001 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--2-pct-pressure-4.log
# 2025-05-09 20:59:24.002 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-0.log
# 2025-05-09 20:59:24.003 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-1.log
# 2025-05-09 20:59:24.003 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-2.log
# 2025-05-09 20:59:24.004 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-3.log
# 2025-05-09 20:59:24.005 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--3-pct-pressure-4.log
# 2025-05-09 20:59:24.005 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-0.log
# 2025-05-09 20:59:24.006 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-1.log
# 2025-05-09 20:59:24.007 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-2.log
# 2025-05-09 20:59:24.008 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-3.log
# 2025-05-09 20:59:24.008 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--4-pct-pressure-4.log
# 2025-05-09 20:59:24.009 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-0.log
# 2025-05-09 20:59:24.010 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-1.log
# 2025-05-09 20:59:24.010 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-2.log
# 2025-05-09 20:59:24.011 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-3.log
# 2025-05-09 20:59:24.012 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--5-pct-pressure-4.log
# 2025-05-09 20:59:24.012 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--6-pct-pressure-0.log
# 2025-05-09 20:59:24.013 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--6-pct-pressure-1.log
# 2025-05-09 20:59:24.014 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--6-pct-pressure-2.log
# 2025-05-09 20:59:24.015 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--6-pct-pressure-3.log
# 2025-05-09 20:59:24.016 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--6-pct-pressure-4.log
# 2025-05-09 20:59:24.016 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--7-pct-pressure-0.log
# 2025-05-09 20:59:24.017 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--7-pct-pressure-1.log
# 2025-05-09 20:59:24.018 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--7-pct-pressure-2.log
# 2025-05-09 20:59:24.019 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--7-pct-pressure-3.log
# 2025-05-09 20:59:24.020 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--7-pct-pressure-4.log
# 2025-05-09 20:59:24.020 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--8-pct-pressure-0.log
# 2025-05-09 20:59:24.021 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--8-pct-pressure-1.log
# 2025-05-09 20:59:24.022 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--8-pct-pressure-2.log
# 2025-05-09 20:59:24.022 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--8-pct-pressure-3.log
# 2025-05-09 20:59:24.023 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--8-pct-pressure-4.log
# 2025-05-09 20:59:24.024 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--9-pct-pressure-0.log
# 2025-05-09 20:59:24.024 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--9-pct-pressure-1.log
# 2025-05-09 20:59:24.025 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--9-pct-pressure-2.log
# 2025-05-09 20:59:24.026 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--9-pct-pressure-3.log
# 2025-05-09 20:59:24.026 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--9-pct-pressure-4.log
# 2025-05-09 20:59:24.027 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--10-pct-pressure-0.log
# 2025-05-09 20:59:24.028 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--10-pct-pressure-1.log
# 2025-05-09 20:59:24.029 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--10-pct-pressure-2.log
# 2025-05-09 20:59:24.029 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--10-pct-pressure-3.log
# 2025-05-09 20:59:24.030 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--10-pct-pressure-4.log
# 2025-05-09 20:59:24.031 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--11-pct-pressure-0.log
# 2025-05-09 20:59:24.031 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--11-pct-pressure-1.log
# 2025-05-09 20:59:24.032 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--11-pct-pressure-2.log
# 2025-05-09 20:59:24.033 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--11-pct-pressure-3.log
# 2025-05-09 20:59:24.033 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--11-pct-pressure-4.log
# 2025-05-09 20:59:24.034 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--12-pct-pressure-0.log
# 2025-05-09 20:59:24.035 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--12-pct-pressure-1.log
# 2025-05-09 20:59:24.035 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--12-pct-pressure-2.log
# 2025-05-09 20:59:24.036 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--12-pct-pressure-3.log
# 2025-05-09 20:59:24.037 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--12-pct-pressure-4.log
# 2025-05-09 20:59:24.038 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--13-pct-pressure-0.log
# 2025-05-09 20:59:24.038 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--13-pct-pressure-1.log
# 2025-05-09 20:59:24.039 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--13-pct-pressure-2.log
# 2025-05-09 20:59:24.040 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--13-pct-pressure-3.log
# 2025-05-09 20:59:24.040 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--13-pct-pressure-4.log
# 2025-05-09 20:59:24.041 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--14-pct-pressure-0.log
# 2025-05-09 20:59:24.042 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--14-pct-pressure-1.log
# 2025-05-09 20:59:24.042 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--14-pct-pressure-2.log
# 2025-05-09 20:59:24.043 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--14-pct-pressure-3.log
# 2025-05-09 20:59:24.044 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--14-pct-pressure-4.log
# 2025-05-09 20:59:24.044 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--15-pct-pressure-0.log
# 2025-05-09 20:59:24.045 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--15-pct-pressure-1.log
# 2025-05-09 20:59:24.046 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--15-pct-pressure-2.log
# 2025-05-09 20:59:24.046 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--15-pct-pressure-3.log
# 2025-05-09 20:59:24.047 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--15-pct-pressure-4.log
# 2025-05-09 20:59:24.048 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--16-pct-pressure-0.log
# 2025-05-09 20:59:24.049 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--16-pct-pressure-1.log
# 2025-05-09 20:59:24.049 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--16-pct-pressure-2.log
# 2025-05-09 20:59:24.050 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--16-pct-pressure-3.log
# 2025-05-09 20:59:24.051 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--16-pct-pressure-4.log
# 2025-05-09 20:59:24.051 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-0.log
# 2025-05-09 20:59:24.052 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-1.log
# 2025-05-09 20:59:24.053 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-2.log
# 2025-05-09 20:59:24.054 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-3.log
# 2025-05-09 20:59:24.054 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--17-pct-pressure-4.log
# 2025-05-09 20:59:24.055 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-0.log
# 2025-05-09 20:59:24.056 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-1.log
# 2025-05-09 20:59:24.056 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-2.log
# 2025-05-09 20:59:24.057 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-3.log
# 2025-05-09 20:59:24.057 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-usage--18-pct-pressure-4.log
# 2025-05-09 20:59:24.058 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--0-pct-pressure-0.log
# 2025-05-09 20:59:24.059 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--0-pct-pressure-1.log
# 2025-05-09 20:59:24.060 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--0-pct-pressure-2.log
# 2025-05-09 20:59:24.061 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--0-pct-pressure-3.log
# 2025-05-09 20:59:24.062 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--0-pct-pressure-4.log
# 2025-05-09 20:59:24.062 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--1-pct-pressure-0.log
# 2025-05-09 20:59:24.063 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--1-pct-pressure-1.log
# 2025-05-09 20:59:24.064 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--1-pct-pressure-2.log
# 2025-05-09 20:59:24.065 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--1-pct-pressure-3.log
# 2025-05-09 20:59:24.065 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--1-pct-pressure-4.log
# 2025-05-09 20:59:24.066 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--2-pct-pressure-0.log
# 2025-05-09 20:59:24.067 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--2-pct-pressure-1.log
# 2025-05-09 20:59:24.067 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--2-pct-pressure-2.log
# 2025-05-09 20:59:24.068 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--2-pct-pressure-3.log
# 2025-05-09 20:59:24.069 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--2-pct-pressure-4.log
# 2025-05-09 20:59:24.069 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--3-pct-pressure-0.log
# 2025-05-09 20:59:24.070 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--3-pct-pressure-1.log
# 2025-05-09 20:59:24.071 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--3-pct-pressure-2.log
# 2025-05-09 20:59:24.072 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--3-pct-pressure-3.log
# 2025-05-09 20:59:24.072 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--3-pct-pressure-4.log
# 2025-05-09 20:59:24.073 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--4-pct-pressure-0.log
# 2025-05-09 20:59:24.074 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--4-pct-pressure-1.log
# 2025-05-09 20:59:24.074 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--4-pct-pressure-2.log
# 2025-05-09 20:59:24.075 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--4-pct-pressure-3.log
# 2025-05-09 20:59:24.075 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--4-pct-pressure-4.log
# 2025-05-09 20:59:24.076 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--5-pct-pressure-0.log
# 2025-05-09 20:59:24.077 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--5-pct-pressure-1.log
# 2025-05-09 20:59:24.078 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--5-pct-pressure-2.log
# 2025-05-09 20:59:24.078 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--5-pct-pressure-3.log
# 2025-05-09 20:59:24.079 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--5-pct-pressure-4.log
# 2025-05-09 20:59:24.080 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--6-pct-pressure-0.log
# 2025-05-09 20:59:24.080 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--6-pct-pressure-1.log
# 2025-05-09 20:59:24.081 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--6-pct-pressure-2.log
# 2025-05-09 20:59:24.082 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--6-pct-pressure-3.log
# 2025-05-09 20:59:24.083 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--6-pct-pressure-4.log
# 2025-05-09 20:59:24.084 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--7-pct-pressure-0.log
# 2025-05-09 20:59:24.084 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--7-pct-pressure-1.log
# 2025-05-09 20:59:24.085 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--7-pct-pressure-2.log
# 2025-05-09 20:59:24.086 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--7-pct-pressure-3.log
# 2025-05-09 20:59:24.086 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--7-pct-pressure-4.log
# 2025-05-09 20:59:24.087 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--8-pct-pressure-0.log
# 2025-05-09 20:59:24.088 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--8-pct-pressure-1.log
# 2025-05-09 20:59:24.088 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--8-pct-pressure-2.log
# 2025-05-09 20:59:24.089 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--8-pct-pressure-3.log
# 2025-05-09 20:59:24.090 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--8-pct-pressure-4.log
# 2025-05-09 20:59:24.091 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--9-pct-pressure-0.log
# 2025-05-09 20:59:24.091 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--9-pct-pressure-1.log
# 2025-05-09 20:59:24.092 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--9-pct-pressure-2.log
# 2025-05-09 20:59:24.093 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--9-pct-pressure-3.log
# 2025-05-09 20:59:24.094 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--9-pct-pressure-4.log
# 2025-05-09 20:59:24.095 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--10-pct-pressure-0.log
# 2025-05-09 20:59:24.095 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--10-pct-pressure-1.log
# 2025-05-09 20:59:24.096 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--10-pct-pressure-2.log
# 2025-05-09 20:59:24.097 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--10-pct-pressure-3.log
# 2025-05-09 20:59:24.098 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--10-pct-pressure-4.log
# 2025-05-09 20:59:24.098 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--11-pct-pressure-0.log
# 2025-05-09 20:59:24.099 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--11-pct-pressure-1.log
# 2025-05-09 20:59:24.100 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--11-pct-pressure-2.log
# 2025-05-09 20:59:24.100 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--11-pct-pressure-3.log
# 2025-05-09 20:59:24.101 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--11-pct-pressure-4.log
# 2025-05-09 20:59:24.102 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--12-pct-pressure-0.log
# 2025-05-09 20:59:24.102 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--12-pct-pressure-1.log
# 2025-05-09 20:59:24.103 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--12-pct-pressure-2.log
# 2025-05-09 20:59:24.104 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--12-pct-pressure-3.log
# 2025-05-09 20:59:24.105 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--12-pct-pressure-4.log
# 2025-05-09 20:59:24.105 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--13-pct-pressure-0.log
# 2025-05-09 20:59:24.106 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--13-pct-pressure-1.log
# 2025-05-09 20:59:24.107 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--13-pct-pressure-2.log
# 2025-05-09 20:59:24.107 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--13-pct-pressure-3.log
# 2025-05-09 20:59:24.108 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--13-pct-pressure-4.log
# 2025-05-09 20:59:24.109 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--14-pct-pressure-0.log
# 2025-05-09 20:59:24.109 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--14-pct-pressure-1.log
# 2025-05-09 20:59:24.110 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--14-pct-pressure-2.log
# 2025-05-09 20:59:24.111 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--14-pct-pressure-3.log
# 2025-05-09 20:59:24.112 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--14-pct-pressure-4.log
# 2025-05-09 20:59:24.112 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--15-pct-pressure-0.log
# 2025-05-09 20:59:24.113 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--15-pct-pressure-1.log
# 2025-05-09 20:59:24.114 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--15-pct-pressure-2.log
# 2025-05-09 20:59:24.114 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--15-pct-pressure-3.log
# 2025-05-09 20:59:24.115 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--15-pct-pressure-4.log
# 2025-05-09 20:59:24.116 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--16-pct-pressure-0.log
# 2025-05-09 20:59:24.117 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--16-pct-pressure-1.log
# 2025-05-09 20:59:24.118 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--16-pct-pressure-2.log
# 2025-05-09 20:59:24.118 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--16-pct-pressure-3.log
# 2025-05-09 20:59:24.119 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--16-pct-pressure-4.log
# 2025-05-09 20:59:24.120 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--17-pct-pressure-0.log
# 2025-05-09 20:59:24.120 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--17-pct-pressure-1.log
# 2025-05-09 20:59:24.121 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--17-pct-pressure-2.log
# 2025-05-09 20:59:24.122 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--17-pct-pressure-3.log
# 2025-05-09 20:59:24.122 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--17-pct-pressure-4.log
# 2025-05-09 20:59:24.123 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--18-pct-pressure-0.log
# 2025-05-09 20:59:24.124 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--18-pct-pressure-1.log
# 2025-05-09 20:59:24.124 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--18-pct-pressure-2.log
# 2025-05-09 20:59:24.125 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--18-pct-pressure-3.log
# 2025-05-09 20:59:24.125 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/page-faults--18-pct-pressure-4.log
# 2025-05-09 20:59:24.127 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--0-pct-pressure-0.log
# 2025-05-09 20:59:24.128 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--0-pct-pressure-1.log
# 2025-05-09 20:59:24.129 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--0-pct-pressure-2.log
# 2025-05-09 20:59:24.130 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--0-pct-pressure-3.log
# 2025-05-09 20:59:24.131 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--0-pct-pressure-4.log
# 2025-05-09 20:59:24.132 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--1-pct-pressure-0.log
# 2025-05-09 20:59:24.132 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--1-pct-pressure-1.log
# 2025-05-09 20:59:24.133 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--1-pct-pressure-2.log
# 2025-05-09 20:59:24.134 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--1-pct-pressure-3.log
# 2025-05-09 20:59:24.135 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--1-pct-pressure-4.log
# 2025-05-09 20:59:24.136 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--2-pct-pressure-0.log
# 2025-05-09 20:59:24.136 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--2-pct-pressure-1.log
# 2025-05-09 20:59:24.137 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--2-pct-pressure-2.log
# 2025-05-09 20:59:24.138 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--2-pct-pressure-3.log
# 2025-05-09 20:59:24.139 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--2-pct-pressure-4.log
# 2025-05-09 20:59:24.140 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--3-pct-pressure-0.log
# 2025-05-09 20:59:24.140 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--3-pct-pressure-1.log
# 2025-05-09 20:59:24.141 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--3-pct-pressure-2.log
# 2025-05-09 20:59:24.142 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--3-pct-pressure-3.log
# 2025-05-09 20:59:24.143 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--3-pct-pressure-4.log
# 2025-05-09 20:59:24.144 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--4-pct-pressure-0.log
# 2025-05-09 20:59:24.145 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--4-pct-pressure-1.log
# 2025-05-09 20:59:24.146 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--4-pct-pressure-2.log
# 2025-05-09 20:59:24.147 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--4-pct-pressure-3.log
# 2025-05-09 20:59:24.147 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--4-pct-pressure-4.log
# 2025-05-09 20:59:24.148 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--5-pct-pressure-0.log
# 2025-05-09 20:59:24.149 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--5-pct-pressure-1.log
# 2025-05-09 20:59:24.150 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--5-pct-pressure-2.log
# 2025-05-09 20:59:24.150 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--5-pct-pressure-3.log
# 2025-05-09 20:59:24.151 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--5-pct-pressure-4.log
# 2025-05-09 20:59:24.152 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--6-pct-pressure-0.log
# 2025-05-09 20:59:24.153 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--6-pct-pressure-1.log
# 2025-05-09 20:59:24.154 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--6-pct-pressure-2.log
# 2025-05-09 20:59:24.155 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--6-pct-pressure-3.log
# 2025-05-09 20:59:24.156 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--6-pct-pressure-4.log
# 2025-05-09 20:59:24.156 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--7-pct-pressure-0.log
# 2025-05-09 20:59:24.157 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--7-pct-pressure-1.log
# 2025-05-09 20:59:24.158 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--7-pct-pressure-2.log
# 2025-05-09 20:59:24.159 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--7-pct-pressure-3.log
# 2025-05-09 20:59:24.160 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--7-pct-pressure-4.log
# 2025-05-09 20:59:24.160 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--8-pct-pressure-0.log
# 2025-05-09 20:59:24.161 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--8-pct-pressure-1.log
# 2025-05-09 20:59:24.162 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--8-pct-pressure-2.log
# 2025-05-09 20:59:24.163 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--8-pct-pressure-3.log
# 2025-05-09 20:59:24.163 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--8-pct-pressure-4.log
# 2025-05-09 20:59:24.164 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--9-pct-pressure-0.log
# 2025-05-09 20:59:24.165 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--9-pct-pressure-1.log
# 2025-05-09 20:59:24.166 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--9-pct-pressure-2.log
# 2025-05-09 20:59:24.167 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--9-pct-pressure-3.log
# 2025-05-09 20:59:24.168 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--9-pct-pressure-4.log
# 2025-05-09 20:59:24.169 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--10-pct-pressure-0.log
# 2025-05-09 20:59:24.170 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--10-pct-pressure-1.log
# 2025-05-09 20:59:24.170 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--10-pct-pressure-2.log
# 2025-05-09 20:59:24.171 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--10-pct-pressure-3.log
# 2025-05-09 20:59:24.172 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--10-pct-pressure-4.log
# 2025-05-09 20:59:24.173 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--11-pct-pressure-0.log
# 2025-05-09 20:59:24.174 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--11-pct-pressure-1.log
# 2025-05-09 20:59:24.174 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--11-pct-pressure-2.log
# 2025-05-09 20:59:24.175 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--11-pct-pressure-3.log
# 2025-05-09 20:59:24.176 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--11-pct-pressure-4.log
# 2025-05-09 20:59:24.177 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--12-pct-pressure-0.log
# 2025-05-09 20:59:24.178 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--12-pct-pressure-1.log
# 2025-05-09 20:59:24.178 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--12-pct-pressure-2.log
# 2025-05-09 20:59:24.179 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--12-pct-pressure-3.log
# 2025-05-09 20:59:24.180 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--12-pct-pressure-4.log
# 2025-05-09 20:59:24.181 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--13-pct-pressure-0.log
# 2025-05-09 20:59:24.182 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--13-pct-pressure-1.log
# 2025-05-09 20:59:24.182 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--13-pct-pressure-2.log
# 2025-05-09 20:59:24.183 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--13-pct-pressure-3.log
# 2025-05-09 20:59:24.184 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--13-pct-pressure-4.log
# 2025-05-09 20:59:24.185 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--14-pct-pressure-0.log
# 2025-05-09 20:59:24.186 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--14-pct-pressure-1.log
# 2025-05-09 20:59:24.187 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--14-pct-pressure-2.log
# 2025-05-09 20:59:24.188 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--14-pct-pressure-3.log
# 2025-05-09 20:59:24.188 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--14-pct-pressure-4.log
# 2025-05-09 20:59:24.189 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--15-pct-pressure-0.log
# 2025-05-09 20:59:24.190 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--15-pct-pressure-1.log
# 2025-05-09 20:59:24.191 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--15-pct-pressure-2.log
# 2025-05-09 20:59:24.192 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--15-pct-pressure-3.log
# 2025-05-09 20:59:24.192 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--15-pct-pressure-4.log
# 2025-05-09 20:59:24.193 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--16-pct-pressure-0.log
# 2025-05-09 20:59:24.194 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--16-pct-pressure-1.log
# 2025-05-09 20:59:24.195 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--16-pct-pressure-2.log
# 2025-05-09 20:59:24.195 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--16-pct-pressure-3.log
# 2025-05-09 20:59:24.196 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--16-pct-pressure-4.log
# 2025-05-09 20:59:24.197 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--17-pct-pressure-0.log
# 2025-05-09 20:59:24.198 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--17-pct-pressure-1.log
# 2025-05-09 20:59:24.198 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--17-pct-pressure-2.log
# 2025-05-09 20:59:24.199 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--17-pct-pressure-3.log
# 2025-05-09 20:59:24.200 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--17-pct-pressure-4.log
# 2025-05-09 20:59:24.201 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--18-pct-pressure-0.log
# 2025-05-09 20:59:24.202 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--18-pct-pressure-1.log
# 2025-05-09 20:59:24.203 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--18-pct-pressure-2.log
# 2025-05-09 20:59:24.203 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--18-pct-pressure-3.log
# 2025-05-09 20:59:24.204 | INFO     | tools.monitor:memory_pressure_log_to_df:53 - Reading memory pressure log file: ../out/notebooks/04-memory-pressure-20250509202444/docker-monitor/memory-pressure--18-pct-pressure-4.log

# %%
profiles[0][0]
# Out:
# ('0', '0')

# %%
profiles[0][1]
# Out:
#                    timestamp  memory_usage_kb
# 0    2025-05-09 23:29:26.454            27268
# 1    2025-05-09 23:29:26.467            33152
# 2    2025-05-09 23:29:26.480            34356
# 3    2025-05-09 23:29:26.492            37780
# 4    2025-05-09 23:29:26.505            39104
# ..                       ...              ...
# 461  2025-05-09 23:29:32.542            91864
# 462  2025-05-09 23:29:32.555            10500
# 463  2025-05-09 23:29:32.568             8652
# 464  2025-05-09 23:29:32.581            12080
# 465  2025-05-09 23:29:32.593            10276
#
# [466 rows x 2 columns]

# %%
profiles[0][2]
# Out:
#                    timestamp  minor_page_faults  major_page_faults
# 0    2025-05-09 23:29:26.454                652                  0
# 1    2025-05-09 23:29:26.469               1162                  0
# 2    2025-05-09 23:29:26.483               2053                  0
# 3    2025-05-09 23:29:26.501               2816                  0
# 4    2025-05-09 23:29:26.519               3250                  0
# ..                       ...                ...                ...
# 401  2025-05-09 23:29:32.471              51232              11935
# 402  2025-05-09 23:29:32.488              51893              11980
# 403  2025-05-09 23:29:32.504              53933              12025
# 404  2025-05-09 23:29:32.517              55112              12078
# 405  2025-05-09 23:29:32.532              55335              12148
#
# [406 rows x 3 columns]

# %%
profiles[0][3]
# Out:
#                    timestamp  some10  some60  some300  full10  full60  \
# 0    2025-05-09 23:29:26.466    0.00    0.00      0.0    0.00    0.00
# 1    2025-05-09 23:29:26.492    0.00    0.00      0.0    0.00    0.00
# 2    2025-05-09 23:29:26.519    0.00    0.00      0.0    0.00    0.00
# 3    2025-05-09 23:29:26.546    0.00    0.00      0.0    0.00    0.00
# 4    2025-05-09 23:29:26.574    0.00    0.00      0.0    0.00    0.00
# ..                       ...     ...     ...      ...     ...     ...
# 242  2025-05-09 23:29:32.509    7.97    1.43      0.3    4.16    0.75
# 243  2025-05-09 23:29:32.532    7.97    1.43      0.3    4.16    0.75
# 244  2025-05-09 23:29:32.556    7.97    1.43      0.3    4.16    0.75
# 245  2025-05-09 23:29:32.575    7.97    1.43      0.3    4.16    0.75
# 246  2025-05-09 23:29:32.597    7.97    1.43      0.3    4.16    0.75
#
#      full300  oom_kills  oom_failures
# 0       0.00          0             0
# 1       0.00          0             0
# 2       0.00          0             0
# 3       0.00          0             0
# 4       0.00          0             0
# ..       ...        ...           ...
# 242     0.15          0             0
# 243     0.15          0             0
# 244     0.15          0             0
# 245     0.15          0             0
# 246     0.15          0             0
#
# [247 rows x 9 columns]

# %%
profiles[0][4]
# Out:
# {'metadata': {'entrypoint_data': '[[[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]\n\n [[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]\n\n [[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]\n\n ...\n\n [[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]\n\n [[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]\n\n [[-0.29300344 -0.29300344 -0.29300344 ... -0.29300344 -0.29300344\n   -0.29300344]\n  [-0.4479553  -0.4479553  -0.4479553  ... -0.4479553  -0.4479553\n   -0.4479553 ]\n  [-0.4824505  -0.4824505  -0.4824505  ... -0.4824505  -0.4824505\n   -0.4824505 ]\n  ...\n  [-0.01582184 -0.01582184 -0.01582184 ... -0.01582184 -0.01582184\n   -0.01582184]\n  [-0.695319   -0.695319   -0.695319   ... -0.695319   -0.695319\n   -0.695319  ]\n  [-0.95219535 -0.95219535 -0.95219535 ... -0.95219535 -0.95219535\n   -0.95219535]]]',
#   'kernel_memory_usage_unit': 'kb',
#   'psutil_memory_usage_unit': 'b',
#   'resource_memory_usage_unit': 'kb',
#   'tracemalloc_memory_usage_unit': 'b',
#   'unix_timestamp_unit': 'ns'},
#  'data': [{'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 911937536.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368314788085},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 966463488.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368325089585},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 987435008.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368336078419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1050349568.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368347071294},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1100681216.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368358102835},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1142624256.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368369285085},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1203441664.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368381153210},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1226510336.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368392084627},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1304104960.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368405363252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1331367936.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368416079002},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1390088192.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368427087419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1421545472.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368438062252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1473974272.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368449061252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1520111616.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368460062002},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1562054656.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368471068919},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1624969216.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368482098252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1679495168.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368495749335},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1727729664.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368506066960},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1752895488.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368517081044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1805324288.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368528084502},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1859850240.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368539168210},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1889210368.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368550069252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1956319232.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368561066419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2008748032.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368574113669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2052788224.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368585073752},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2103119872.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368596862377},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2147160064.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368607072794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2201686016.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368619210502},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2228948992.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368630102252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2296057856.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368641061294},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2335903744.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368654150919},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2394624000.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368665069419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2438664192.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368677122794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368688076627},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368699057086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368710065669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368721061169},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368732059044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368743089377},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368754839877},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368765544711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368776293711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368787075419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368802176669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368813090586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368824084127},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368835067294},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368846210336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368857499419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368870166794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368881076502},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368892076377},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368903060419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368914068586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368928101752},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368939077877},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368950063461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368961201961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368972063544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368983060544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833368994177502},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369005104127},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369016614127},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369027303586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369039043961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369050172252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369061082669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369072091336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369084820461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369095135127},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369109140419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369120093377},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369131111711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369142086461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369153078586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369166137669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369177067419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369190118294},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369201085086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369212222086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369223065961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369234088502},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369245118002},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369256201044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369267217044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369278070794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369291103044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2454654976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369302066169},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2589167616.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369313541336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2698219520.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369324213294},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2819854336.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369335070461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2889060352.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369346064252},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3027472384.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369357594628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3092484096.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369368074253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3279130624.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369383056503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3358822400.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369394083378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3474165760.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369405177628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3595800576.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369416160836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3665006592.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369427094836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3822292992.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369438070128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 3910373376.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369449105044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4022177792.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369460081169},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4060700672.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369471170128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4077477888.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369482153669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4113129472.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369493067503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4142489600.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369506105128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4173946880.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369517106336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4207501312.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369528310794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4232667136.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369539079628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4257832960.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369550060544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4280901632.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369561066878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4320747520.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369572163378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4352204800.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369584186878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4379467776.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369595236753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4408827904.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369606122836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4440285184.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369620036336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4478033920.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369631109919},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4494811136.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369642186503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4532559872.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369653085919},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4559822848.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369665359419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4591280128.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369676073086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4622737408.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369689109961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4647903232.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369700074544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4681457664.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369712110836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4702429184.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369723088253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4725497856.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369734093711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4744372224.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369745173878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4775829504.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369756102919},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4788412416.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369767247711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4826161152.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369778204336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4842938368.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369789661169},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4861812736.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369800175128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4886978560.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369811099878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4907950080.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369822112794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4941504512.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369833079419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4951990272.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369844054003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4989739008.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369855108211},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5006516224.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369866661669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5029584896.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369877941711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5056847872.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369888084044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5077819392.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369899797503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5107179520.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369910134544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5121859584.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369921072461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5157511168.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369932103044},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5176385536.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369943101669},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5201551360.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369954080419},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5226717184.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369965237961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5245591552.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369976089753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5262368768.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369987223794},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5268660224.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833369998072961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5283340288.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370009097169},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5295923200.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370021110253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5308506112.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370032093461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5323186176.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370043121544},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5331574784.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370054249461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5352546304.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370065201128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5360934912.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370076090503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5373517824.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370087081586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5388197888.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370098079128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5398683648.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370109990086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5419655168.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370122089920},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5425946624.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370133123961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5440626688.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370144083670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5453209600.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370155453336},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5461598208.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370166106961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5478375424.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370177683211},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5486764032.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370188454670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5505638400.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370199917670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5514027008.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370210076961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5526609920.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370222300878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5526986752.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370234213711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5524627456.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370245302378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5520302080.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370258088711},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5511127040.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370269119295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5496446976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370280217878},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5480325120.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370291988461},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5467873280.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370304366920},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5448474624.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370316164961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5439823872.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370327125295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5416886272.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370339170628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5402992640.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370350534628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5381365760.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370363075128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5359214592.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370374089836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5345320960.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370385080378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5322514432.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370396125253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5312290816.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370407080836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5290795008.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370418088753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5280571392.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370429084420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5257502720.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370440176253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5238497280.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370451214378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5227880448.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370462150628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5204811776.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370473074086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5192228864.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370484118170},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5168766976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370495164836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5150285824.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370506263420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5136392192.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370517155170},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5120008192.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370528101586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5109653504.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370539112836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5081604096.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370550302586},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5069938688.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370561231503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5054341120.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370572721086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5036777472.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370583447836},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5019344896.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370594295045},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 5000863744.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370605113545},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4988805120.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370616187670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4967309312.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370627123378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4953546752.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370638077211},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4935852032.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370649128086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4907016192.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370660388003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4898627584.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370671146003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4878311424.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370682137503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4863369216.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370693138128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4845412352.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370704078420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4829028352.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370715106128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4809760768.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370726398961},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4781973504.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370737214253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4772536320.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370748132086},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4751826944.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370759073003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4735705088.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370770059003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4719190016.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370781102295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4693499904.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370796151670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4679999488.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370807092420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4660862976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370818815753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4629798912.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370832242920},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4595851264.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370843099295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4557185024.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370856164753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4533198848.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370867113587},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4496760832.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370879272378},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4496760832.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370890061753},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4496760832.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370901292253},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4496760832.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370912383837},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4505202688.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370923914670},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4528271360.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370934401462},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 4554747904.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370946734462},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2987089920.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370957069503},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2518077440.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370969388128},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1603588096.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370980091170},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1622462464.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833370991069420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1670696960.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371002103170},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1714737152.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371013075337},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1739902976.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371024106837},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1788137472.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371035101212},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1821691904.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371046170628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1872023552.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371057111837},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1899286528.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371068148087},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1937035264.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371079079628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 1991561216.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371090063295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2012532736.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371101058587},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2064961536.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371112094420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2094321664.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371123171628},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2136264704.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371134066295},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2184499200.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371146209962},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2218053632.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371157114087},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2249510912.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371168106920},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2289356800.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371179188003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2343882752.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371190063462},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2364461056.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371201163003},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2365509632.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371212064045},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2365640704.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371474655837},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 2366558208.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371485525379},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 15085568.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371496086420},
#   {'signature': 'unknown::unknown:0::unknown',
#    'kernel_memory_usage': 0,
#    'psutil_memory_usage': 15347712.0,
#    'resource_memory_usage': 0,
#    'tracemalloc_memory_usage': 0,
#    'unix_timestamp': 1746833371507591212}]}

# %%
import matplotlib.pyplot as plt

labels = []
peaks = {}

for (pct_pressure, _), docker_mu_df, docker_pf_df, docker_mp_df, traceq_profile in profiles:
    peak_docker_mu = tools.conversions.kb_to_gb(docker_mu_df["memory_usage_kb"].max())
    peak_docker_minor_pf = docker_pf_df["minor_page_faults"].max()
    peak_docker_major_pf = docker_pf_df["major_page_faults"].max()
    peak_docker_mp_some10 = docker_mp_df["some10"].max()
    peak_docker_mp_full10 = docker_mp_df["full10"].max()
    peak_traceq_mu = tools.conversions.b_to_gb(
        max(entry["psutil_memory_usage"] for entry in traceq_profile["data"])
    )
    timestamps = [entry["unix_timestamp"] for entry in traceq_profile["data"]]
    execution_time = (max(timestamps) - min(timestamps)) / 1000  # Compute execution time in seconds

    peak_record = peaks.get(pct_pressure)
    if not peak_record:
        peak_record = {
            'docker_mus': [],
            'docker_minor_pfs': [],
            'docker_major_pfs': [],
            'docker_mps_some10': [],
            'docker_mps_full10': [],
            'traceq_mus': [],
            'traceq_et': [],
        }

    peak_record["docker_mus"].append(peak_docker_mu)
    peak_record["docker_minor_pfs"].append(peak_docker_minor_pf)
    peak_record["docker_major_pfs"].append(peak_docker_major_pf)
    peak_record["docker_mps_some10"].append(peak_docker_mp_some10)
    peak_record["docker_mps_full10"].append(peak_docker_mp_full10)
    peak_record["traceq_mus"].append(peak_traceq_mu)
    peak_record['traceq_et'].append(execution_time)

    peaks[pct_pressure] = peak_record

    if pct_pressure not in labels:
        labels.append(pct_pressure)

peaks_sorted = sorted([(pct, record) for pct, record in peaks.items()], key=lambda x: int(x[0]))
peak_records = [record for _, record in peaks_sorted]

average_peak_docker_mus = [sum(record['docker_mus']) / len(record['docker_mus']) for record in peak_records]
average_peak_docker_minor_pfs = [sum(record['docker_minor_pfs']) / len(record['docker_minor_pfs']) for record in
                                 peak_records]
average_peak_docker_major_pfs = [sum(record['docker_major_pfs']) / len(record['docker_major_pfs']) for record in
                                 peak_records]
average_peak_docker_mps_some10 = [sum(record['docker_mps_some10']) / len(record['docker_mps_some10']) for record in
                                  peak_records]
average_peak_docker_mps_full10 = [sum(record['docker_mps_full10']) / len(record['docker_mps_full10']) for record in
                                  peak_records]
average_peak_traceq_mus = [sum(record['traceq_mus']) / len(record['traceq_mus']) for record in peak_records]
average_traceq_et = [sum(record['traceq_et']) / len(record['traceq_et']) for record in peak_records]

fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot Memory Usage (MU) on the left y-axis
ax1.set_xlabel("Pressure (%)")
ax1.set_ylabel("Memory Usage (GB)", color="tab:blue")
ax1.plot(labels, average_peak_docker_mus, "o-", color="tab:blue", label="Docker MU")
ax1.plot(labels, average_peak_traceq_mus, "s-", color="tab:cyan", label="TraceQ MU")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Create a secondary y-axis for Page Faults (PF)
ax2 = ax1.twinx()
ax2.set_ylabel("Minor Page Faults", color="tab:red")
ax2.plot(labels, average_peak_docker_minor_pfs, "x--", color="tab:orange", label="Docker Minor Page Faults")
ax2.plot(labels, average_peak_docker_major_pfs, "d--", color="tab:orange", label="Docker Major Page Faults")
ax2.tick_params(axis="y", labelcolor="tab:red")

# Add legends
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

# Title and layout
plt.title("Memory Usage and Page Faults per Profile")
plt.xticks(rotation=45)
plt.grid(True, which="both", linestyle="--", linewidth=0.5)

os.makedirs(f"../{RELATIVE_OUT_DIR}/charts", exist_ok=True)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/memory_usage_and_page_faults.pdf")
plt.show()

# %%
# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot execution time
ax.plot(labels, average_peak_docker_major_pfs, "o--", color="tab:orange", label="Major Page Faults")
ax.set_xlabel("Pressure (%)")
ax.set_ylabel("Major Page Faults", color="tab:orange")
ax.tick_params(axis="y", labelcolor="tab:orange")
ax.set_title("")
ax.legend()
ax.grid(True, linestyle="--", linewidth=0.5)
plt.xticks(rotation=45)

plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/major_page_faults.pdf")
plt.show()

# %%
# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot execution time
ax.plot(labels, average_traceq_et, "o--", color="tab:purple", label="Execution Time (s)")
ax.set_xlabel("Pressure (%)")
ax.set_ylabel("Execution Time (s)", color="tab:purple")
ax.tick_params(axis="y", labelcolor="tab:purple")
ax.set_title("Execution Time per Profile")
ax.legend()
ax.grid(True, linestyle="--", linewidth=0.5)
plt.xticks(rotation=45)

plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/execution_time.pdf")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(labels, average_peak_docker_mps_some10, "o--", color="tab:green", label="Some10 (%)")
ax.plot(labels, average_peak_docker_mps_full10, "x--", color="tab:blue", label="Full10 (%)")
ax.set_xlabel("Pressure (%)")
ax.set_ylabel("Recorded Kernel Memory Pressure (%)", color="tab:green")
ax.tick_params(axis="y", labelcolor="tab:green")
ax.set_title("Memory Pressure Recorded per Profile")
ax.legend()
ax.grid(True, linestyle="--", linewidth=0.5)
plt.xticks(rotation=45)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/kernel_memory_pressure.pdf")
plt.show()

# %%
import pandas as pd
import seaborn as sns

data = {
    "Memory Usage (Docker)": average_peak_docker_mus,
    "Memory Usage (TraceQ)": average_peak_traceq_mus,
    "Some10 Memory Pressure (%)": average_peak_docker_mps_some10,
    "Full10 Memory Pressure (%)": average_peak_docker_mps_full10,
    "Execution Time": average_traceq_et,
    "Major Page Faults": average_peak_docker_major_pfs,
    "Minor Page Faults": average_peak_docker_minor_pfs,
}
df = pd.DataFrame(data, index=labels)

correlation_matrix = df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Performance Metrics")
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/correlation_matrix.pdf")
plt.show()

# %%
vfs_container.stop()

# %% [markdown]
# ## Summary of Findings
#
# ### 1. Impact of Memory Pressure on Execution Time
#
# The correlation matrix analysis, as well as the recorded execution time per profile charts, indicate a strong **positive correlation (0.71 - 0.77)** between **memory pressure** and **execution time**.
# This suggests that as available memory decreases due to imposed constraints, execution time increases significantly.
# The trend observed in the charts confirms this behavior, where execution time steadily increases as memory pressure intensifies, reflecting the additional overhead imposed by memory constraints, likely due to an increased rate of memory paging and context switching.
#
# ### 2. Relationship Between Memory Usage and Memory Pressure
#
# The data analysed provided insights into the interaction between **memory usage** and **memory pressure**.
# The **negative correlation (-0.72 to -0.79) between memory usage and recorded kernel memory pressure** in the correlation matrix suggests that when more memory is allocated, kernel memory pressure decreases.
# This is further supported by the evaluated memory charts, where memory usage (both Docker MU and TraceQ MU) decreases as pressure increases, while recorded memory pressure rises.
# This relationship highlights that constraining memory availability leads to **higher system contention** and forces processes to operate under constrained memory conditions, increasing system-wide pressure.
#
# ### 3. Behavior of Page Faults Under Memory Constraints
#
# The relationship between **major page faults and minor page faults** is characterized by a **strong negative correlation (-0.85)** in the correlation matrix.
# This indicates a shift in fault-handling behavior as memory pressure increases.
# One of the charts, which tracks major page faults across varying pressure levels, suggests that **major page faults increase at higher pressure levels**, although the response is nonlinear.
# A critical observation is the temporary drop in page faults at **pressure levels between 3% and 4%**, which could indicate system optimizations attempting to compensate for resource starvation.
# The presence of **increased memory pressure, but fluctuating page faults** suggests that under constrained conditions, the system prioritizes certain memory regions for eviction, leading to **potential performance instability**.
#
# ### 4. Execution Efficiency Under Increasing Memory Constraints
#
# The correlation matrix indicates a **strong negative correlation (-0.83)** between **memory usage** and **execution time**, suggesting that processes executing under higher memory availability tend to complete faster.
# We can confirm this behavior based on the evaluated data, where execution time increases with greater memory pressure.
# This aligns with expectations, as memory constraints force processes to rely more on virtual memory, increasing latency due to paging and slower memory access operations.
# The findings demonstrate that beyond a critical threshold of memory pressure, the degradation in execution efficiency is unavoidable, which has implications for system tuning in resource-constrained environments.
#
# ### 5. Implications for System Optimization
#
# The findings collectively emphasize the necessity of **dynamic memory allocation strategies** in memory-constrained environments.
# The observed trade-offs between **memory pressure, execution time, and fault-handling mechanisms** highlight that resource allocation policies must be adapted dynamically to avoid severe performance degradation.
# The non-monotonic trend in **major page faults** suggests that static allocation strategies may not be optimal, and that incorporating **adaptive memory management techniques** could help mitigate unexpected performance degradation under high-pressure conditions.
#
# ## 6. Key Takeaways
# - **Higher memory pressure results in increased execution time** due to the overhead of memory contention.
# - **Memory usage and pressure exhibit a strong inverse relationship**, with lower memory availability leading to heightened pressure.
# - **Page faults do not scale linearly with memory pressure**, indicating the presence of system optimizations that manage memory access under constraints.
# - **Execution efficiency is strongly dependent on available memory**, reinforcing the importance of optimizing memory allocation for performance-sensitive applications.
#
# These findings provide a detailed understanding of how memory constraints influence execution dynamics, which is critical for designing **resilient, performance-efficient computing systems** in constrained environments.
