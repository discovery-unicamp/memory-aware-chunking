# %% [markdown]
# # Memory Profiling Notebook

# %% [markdown]
# # Introduction
#
# This notebook aims to demonstrate the memory profiling process for the memory consumption experiment.
# The goals of this notebooks are:
#
# - Test and compare memory measurement tools (`psutil`, `resource`, `tracemalloc`, `/proc` filesystem).
# - Validate consistency between internal and external profiling data.

# %% [markdown]
# ## How to Use this Notebook
#
# - Run the individual cells to inspect and verify the behavior of specific parts of the component.
# - Review the expected behavior before running the full experiment via the shell script.
# - Use this notebook as a debugging and documentation tool to support future iterations of the experiment.
#
# By structuring the experiment this way, we ensure a clear separation between explanation, validation, and execution, making it easier to reason about the results while keeping the experiment reproducible and well-documented.

# %% [markdown]
# ## Components Overview

# %% [markdown]
# Before running the component, we need to setup a few variables and utils.

# %%
import os
import sys
from datetime import datetime

from loguru import logger

dirs_to_add = [
    os.path.abspath('../'),
    os.path.abspath('../../../libs/traceq'),
]

for dir_to_add in dirs_to_add:
    if dir_to_add not in sys.path:
        sys.path.insert(0, dir_to_add)

TIMESTAMP = datetime.now().strftime("%Y%m%d%H%M%S")

EXPERIMENT_IMAGE = "mac/03-memory-profiling"
RELATIVE_OUT_DIR = f"out/notebooks/03-memory-profiling-{TIMESTAMP}"
CONTAINER_OUT_DIR = f"/app/{RELATIVE_OUT_DIR}"

INLINES = "700"
XLINES = "700"
SAMPLES = "400"

logger.debug("Generated global variables")
logger.debug(f"TIMESTAMP: {TIMESTAMP}")
logger.debug(f"EXPERIMENT_IMAGE: {EXPERIMENT_IMAGE}")
logger.debug(f"RELATIVE_OUT_DIR: {RELATIVE_OUT_DIR}")
logger.debug(f"CONTAINER_OUT_DIR: {CONTAINER_OUT_DIR}")

logger.debug(f"INLINES: {INLINES}")
logger.debug(f"XLINES: {XLINES}")
logger.debug(f"SAMPLES: {SAMPLES}")

os.makedirs(f"../{RELATIVE_OUT_DIR}/docker-monitor", exist_ok=True)
# Out:
# 2025-05-09 18:57:06.459 | DEBUG    | __main__:<module>:26 - Generated global variables
# 2025-05-09 18:57:06.460 | DEBUG    | __main__:<module>:27 - TIMESTAMP: 20250509185706
# 2025-05-09 18:57:06.460 | DEBUG    | __main__:<module>:28 - EXPERIMENT_IMAGE: mac/03-memory-profiling
# 2025-05-09 18:57:06.460 | DEBUG    | __main__:<module>:29 - RELATIVE_OUT_DIR: out/notebooks/03-memory-profiling-20250509185706
# 2025-05-09 18:57:06.461 | DEBUG    | __main__:<module>:30 - CONTAINER_OUT_DIR: /app/out/notebooks/03-memory-profiling-20250509185706
# 2025-05-09 18:57:06.461 | DEBUG    | __main__:<module>:32 - INLINES: 700
# 2025-05-09 18:57:06.461 | DEBUG    | __main__:<module>:33 - XLINES: 700
# 2025-05-09 18:57:06.461 | DEBUG    | __main__:<module>:34 - SAMPLES: 400

# %%
import importlib
import tools.docker

importlib.reload(tools.docker)

vfs_client, vfs_container = tools.docker.get_vfs_client(f"../{RELATIVE_OUT_DIR}")
# Out:
# 2025-05-09 18:57:06.611 | INFO     | tools.docker:get_vfs_client:68 - Start dind dockerd...
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60457->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 18:57:06.740 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60465->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:08.828 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60472->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:10.889 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60479->[::1]:2375: read: connection reset by peer
# errors pretty printing info
# 2025-05-09 18:57:13.669 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60489->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:15.750 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# errors pretty printing info
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60494->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:17.831 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60503->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:19.923 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# ERROR: error during connect: Get "http://localhost:2375/v1.47/info": read tcp [::1]:60510->[::1]:2375: read: connection reset by peer
# 2025-05-09 18:57:22.010 | INFO     | tools.docker:__wait_for_dockerd:141 - Waiting for dockerd to start...
# errors pretty printing info
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
# WARNING: Plugin "/Users/delucca/.docker/cli-plugins/docker-feedback" is not valid: failed to fetch metadata: fork/exec /Users/delucca/.docker/cli-plugins/docker-feedback: no such file or directory
# [DEPRECATION NOTICE]: API is accessible on http://0.0.0.0:2375 without encryption.
#          Access to the remote API is equivalent to root access on the host. Refer
#          to the 'Docker daemon attack surface' section in the documentation for
#          more information: https://docs.docker.com/go/attack-surface/
# In future versions this will be a hard failure preventing the daemon from starting! Learn more at: https://docs.docker.com/go/api-security/
# 2025-05-09 18:57:24.090 | INFO     | tools.docker:__wait_for_dockerd:138 - Dockerd inside dind is fully operational.
# Client: Docker Engine - Community
#  Version:    27.3.1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.1.7
#     Path:     /Users/delucca/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.23.0-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.3.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.35.1-desktop.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.38
#     Path:     /Users/delucca/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.1.8
#     Path:     /Users/delucca/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/delucca/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.27
#     Path:     /Users/delucca/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  dev
#     Path:     /Users/delucca/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.11
#     Path:     /Users/delucca/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/delucca/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.17.1
#     Path:     /Users/delucca/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 0
#  Server Version: 28.1.1
#  Storage Driver: vfs
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.6-0-ge89a299
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Alpine Linux v3.21 (containerized)
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 16
#  Total Memory: 30.91GiB
#  Name: 7cc6e4f6029c
#  ID: d5ef7067-8280-4cbb-9801-6352ec35723f
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false
#  Product License: Community Engine

# %% [markdown]
# Let's start by building the Docker image within the VFS client

# %%
from loguru import logger

logger.info("Building experiment image...")
experiment_image = tools.docker.build_image(EXPERIMENT_IMAGE, vfs_client)
logger.info("Experiment image built successfully.")
# Out:
# 2025-05-09 18:57:24.108 | INFO     | __main__:<module>:3 - Building experiment image...
# 2025-05-09 18:57:24.109 | INFO     | tools.docker:build_image:21 - Building TraceQ image...
# 2025-05-09 18:57:45.544 | INFO     | tools.docker:build_image:27 - TraceQ image built.
# 2025-05-09 18:57:45.545 | INFO     | tools.docker:build_image:29 - Building experiment image...
# 2025-05-09 18:59:12.094 | INFO     | tools.docker:build_image:37 - Experiment image built.
# 2025-05-09 18:59:12.097 | INFO     | __main__:<module>:5 - Experiment image built successfully.

# %% [markdown]
# With the image built, we're going to generate the test data.

# %%
importlib.reload(tools.docker)

memory_usage_log_file = f"docker-monitor/memory-usage--data-generation.log"
page_faults_log_file = f"docker-monitor/page-faults--data-generation.log"

logger.info("Generating test data...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "generate-data",
        "--inlines", INLINES,
        "--xlines", XLINES,
        "--samples", SAMPLES,
        "--output-dir", f"{CONTAINER_OUT_DIR}/data"
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py generate-data",
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        },
    },
)
logger.info("Finished generating test data")
# Out:
# 2025-05-09 18:59:12.136 | INFO     | __main__:<module>:6 - Generating test data...
# 2025-05-09 18:59:18.380 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 18:59:18.380 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:00:54.120 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:00:54.121 | INFO     | __main__:<module>:29 - Finished generating test data

# %% [markdown]
# We'll start by running the memory profiling for the envelope operator.

# %%
importlib.reload(tools.docker)

memory_usage_log_file = f"docker-monitor/memory-usage--experiment.log"
page_faults_log_file = f"docker-monitor/page-faults--experiment.log"

tools.docker.drop_caches_in_container()

logger.info("Launching experiment...")
tools.docker.run_isolated_container(
    client=vfs_client,
    image_name=EXPERIMENT_IMAGE,
    command=[
        "operate",
        "envelope",
        "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
        "--memory-profiler", "psutil",
        "--memory-profile-output-dir", f"{CONTAINER_OUT_DIR}/profiler",
        "--memory-profile-session-id", f"{INLINES}-{XLINES}-{SAMPLES}-psutil",
    ],
    environment={
        "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{memory_usage_log_file}",
        "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{page_faults_log_file}",
        "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
    },
    volumes={
        "/mnt/out": {
            "bind": CONTAINER_OUT_DIR,
            "mode": "rw",
        },
    },
)
logger.info("Finished executing experiment")
# Out:
# 2025-05-09 19:00:54.543 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:00:54.544 | INFO     | __main__:<module>:8 - Launching experiment...
# 2025-05-09 19:00:54.724 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:00:54.725 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:01:04.165 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:01:04.166 | INFO     | __main__:<module>:32 - Finished executing experiment

# %%
import importlib
import tools.monitor

importlib.reload(tools.monitor)

docker_monitor_mu_df = tools.monitor.memory_usage_log_to_df(
    f"../{RELATIVE_OUT_DIR}/docker-monitor/memory-usage--experiment.log",
)

docker_monitor_mu_df.head()
# Out:
# 2025-05-09 19:01:04.183 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment.log
#                  timestamp  memory_usage_kb
# 0  2025-05-09 22:00:58.144            27200
# 1  2025-05-09 22:00:58.157            33264
# 2  2025-05-09 22:00:58.169            33144
# 3  2025-05-09 22:00:58.182            37228
# 4  2025-05-09 22:00:58.195            37612

# %%
import tools.conversions

importlib.reload(tools.conversions)

docker_monitor_peak_memory_usage = tools.conversions.kb_to_gb(
    docker_monitor_mu_df["memory_usage_kb"].max()
)

logger.info(f"Docker monitor captured {len(docker_monitor_mu_df)} traces")
logger.info("Peak memory usage from Docker monitor: {} GB".format(docker_monitor_peak_memory_usage))
# Out:
# 2025-05-09 19:01:04.234 | INFO     | __main__:<module>:9 - Docker monitor captured 421 traces
# 2025-05-09 19:01:04.235 | INFO     | __main__:<module>:10 - Peak memory usage from Docker monitor: 6.040889739990234 GB

# %%
from traceq import load_profile
import tools.conversions

importlib.reload(tools.conversions)

profiles = os.listdir(f"../{RELATIVE_OUT_DIR}/profiler")
psutil_profile_path = [profile for profile in profiles if profile.endswith(("prof"))][0]
psutil_profile = load_profile(f"../{RELATIVE_OUT_DIR}/profiler/{psutil_profile_path}")
psutil_peak_memory_usage = tools.conversions.b_to_gb(
    max(entry["psutil_memory_usage"] for entry in psutil_profile["data"]))

logger.info(f"Tracer captured {len(psutil_profile["data"])} traces")
logger.info(f"Peak memory usage from psutil profile: {psutil_peak_memory_usage} GB")
# Out:
# 2025-05-09 19:07:26.348 | INFO     | __main__:<module>:12 - Tracer captured 256 traces
# 2025-05-09 19:07:26.348 | INFO     | __main__:<module>:13 - Peak memory usage from psutil profile: 5.1978607177734375 GB

# %% [markdown]
# Now that we've saw that the profiling structure is working using TraceQ, let's do some experiments with different profilers.
# For each profile we will run against the same data, multiple times, in an isolated environment.

# %%
mu_conversion_handlers_by_unit = {
    "b": tools.conversions.b_to_gb,
    "kb": tools.conversions.kb_to_gb,
}


def experiment(iterations: int, traceq_profiler: str):
    docker_monitor_mu_history = []
    docker_monitor_pf_history = []
    traceq_history = []

    peak_docker_monitor_mu_history = []
    peak_docker_monitor_minor_pf_history = []
    peak_docker_monitor_major_pf_history = []
    peak_traceq_mu_history = []

    for i in range(iterations):
        logger.info(f"Iteration {i + 1}/{iterations}")

        tools.docker.drop_caches_in_container()

        docker_monitor_mu_log_file = f"docker-monitor/memory-usage--experiment-{traceq_profiler}-{i}.log"
        docker_monitor_pf_log_file = f"docker-monitor/page-faults-log-{traceq_profiler}-{i}.log"
        traceq_profile_output_dir = f"{CONTAINER_OUT_DIR}/profiler"
        traceq_profile_session_id = f"{INLINES}-{XLINES}-{SAMPLES}-{traceq_profiler}-{i}"

        tools.docker.run_isolated_container(
            client=vfs_client,
            image_name=EXPERIMENT_IMAGE,
            command=[
                "operate",
                "envelope",
                "--segy-path", f"{CONTAINER_OUT_DIR}/data/{INLINES}-{XLINES}-{SAMPLES}.segy",
                "--memory-profiler", traceq_profiler,
                "--memory-profile-output-dir", traceq_profile_output_dir,
                "--memory-profile-session-id", traceq_profile_session_id,
            ],
            environment={
                "MEMORY_USAGE_LOG_FILE": f"{CONTAINER_OUT_DIR}/{docker_monitor_mu_log_file}",
                "PAGE_FAULTS_LOG_FILE": f"{CONTAINER_OUT_DIR}/{docker_monitor_pf_log_file}",
                "PAGE_FAULTS_MONITORED_PROCESS_NAME": "main.py operate",
            },
            volumes={
                "/mnt/out": {
                    "bind": CONTAINER_OUT_DIR,
                    "mode": "rw",
                },
            },
        )

        docker_monitor_mu_df = tools.monitor.memory_usage_log_to_df(
            f"../{RELATIVE_OUT_DIR}/{docker_monitor_mu_log_file}",
        )
        docker_monitor_pf_df = tools.monitor.page_faults_log_to_df(
            f"../{RELATIVE_OUT_DIR}/{docker_monitor_pf_log_file}",
        )

        docker_monitor_peak_mu = tools.conversions.kb_to_gb(
            docker_monitor_mu_df["memory_usage_kb"].max()
        )
        peak_docker_monitor_minor_pf = docker_monitor_pf_df["minor_page_faults"].max()
        peak_docker_monitor_major_pf = docker_monitor_pf_df["major_page_faults"].max()

        docker_monitor_mu_history.append(docker_monitor_mu_df)
        docker_monitor_pf_history.append(docker_monitor_pf_df)
        peak_docker_monitor_mu_history.append(docker_monitor_peak_mu)
        peak_docker_monitor_minor_pf_history.append(peak_docker_monitor_minor_pf)
        peak_docker_monitor_major_pf_history.append(peak_docker_monitor_major_pf)

        logger.info(f"Peak memory usage from Docker monitor: {docker_monitor_peak_mu} GB")
        logger.info(f"Peak minor page faults from Docker monitor: {peak_docker_monitor_minor_pf}")
        logger.info(f"Peak major page faults from Docker monitor: {peak_docker_monitor_major_pf}")

        profiles = os.listdir(f"../{RELATIVE_OUT_DIR}/profiler")
        profile_path = [profile for profile in profiles if traceq_profile_session_id in profile][0]
        traceq_profile = load_profile(f"../{RELATIVE_OUT_DIR}/profiler/{profile_path}")
        traceq_profile_data = traceq_profile["data"]
        traceq_profile_metadata = traceq_profile["metadata"]
        convert = mu_conversion_handlers_by_unit[traceq_profile_metadata[f"{traceq_profiler}_memory_usage_unit"]]

        peak_traceq_mu = convert(
            max(entry[f"{traceq_profiler}_memory_usage"] for entry in traceq_profile_data)
        )

        traceq_history.append(traceq_profile)
        peak_traceq_mu_history.append(peak_traceq_mu)

        logger.info(f"Peak memory usage from TraceQ: {peak_traceq_mu} GB")

    return {
        "docker_monitor_mu_history": docker_monitor_mu_history,
        "docker_monitor_pf_history": docker_monitor_pf_history,
        "traceq_history": traceq_history,
        "peak_docker_monitor_mu_history": peak_docker_monitor_mu_history,
        "peak_docker_monitor_minor_pf_history": peak_docker_monitor_minor_pf_history,
        "peak_docker_monitor_major_pf_history": peak_docker_monitor_major_pf_history,
        "peak_traceq_mu_history": peak_traceq_mu_history,
    }

# %%
iterations = 10

psutil_experiment_history = experiment(iterations, "psutil")
# Out:
# 2025-05-09 19:18:59.842 | INFO     | __main__:experiment:18 - Iteration 1/10
# 2025-05-09 19:19:00.099 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:00.206 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:00.207 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:08.319 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:08.320 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-0.log
# 2025-05-09 19:19:08.322 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-0.log
# 2025-05-09 19:19:08.325 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.03912353515625 GB
# 2025-05-09 19:19:08.325 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47779
# 2025-05-09 19:19:08.326 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:08.328 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.190025329589844 GB
# 2025-05-09 19:19:08.329 | INFO     | __main__:experiment:18 - Iteration 2/10
# 2025-05-09 19:19:08.910 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:09.048 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:09.049 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:17.694 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:17.695 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-1.log
# 2025-05-09 19:19:17.700 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-1.log
# 2025-05-09 19:19:17.703 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.02435302734375 GB
# 2025-05-09 19:19:17.705 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 48240
# 2025-05-09 19:19:17.705 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:17.707 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.1978607177734375 GB
# 2025-05-09 19:19:17.708 | INFO     | __main__:experiment:18 - Iteration 3/10
# 2025-05-09 19:19:18.266 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:18.398 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:18.399 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:26.056 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:26.057 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-2.log
# 2025-05-09 19:19:26.059 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-2.log
# 2025-05-09 19:19:26.060 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.035789489746094 GB
# 2025-05-09 19:19:26.060 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47393
# 2025-05-09 19:19:26.060 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:26.061 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.188037872314453 GB
# 2025-05-09 19:19:26.062 | INFO     | __main__:experiment:18 - Iteration 4/10
# 2025-05-09 19:19:26.499 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:26.632 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:26.634 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:34.520 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:34.520 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-3.log
# 2025-05-09 19:19:34.522 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-3.log
# 2025-05-09 19:19:34.523 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.039314270019531 GB
# 2025-05-09 19:19:34.523 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47767
# 2025-05-09 19:19:34.523 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:34.525 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.191974639892578 GB
# 2025-05-09 19:19:34.525 | INFO     | __main__:experiment:18 - Iteration 5/10
# 2025-05-09 19:19:34.933 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:35.060 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:35.061 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:43.050 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:43.051 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-4.log
# 2025-05-09 19:19:43.053 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-4.log
# 2025-05-09 19:19:43.056 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.037570953369141 GB
# 2025-05-09 19:19:43.056 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47472
# 2025-05-09 19:19:43.056 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:43.057 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205665588378906 GB
# 2025-05-09 19:19:43.058 | INFO     | __main__:experiment:18 - Iteration 6/10
# 2025-05-09 19:19:43.484 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:43.606 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:43.607 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:51.358 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:51.359 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-5.log
# 2025-05-09 19:19:51.361 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-5.log
# 2025-05-09 19:19:51.366 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.038867950439453 GB
# 2025-05-09 19:19:51.367 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47981
# 2025-05-09 19:19:51.367 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:51.370 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.203697204589844 GB
# 2025-05-09 19:19:51.370 | INFO     | __main__:experiment:18 - Iteration 7/10
# 2025-05-09 19:19:51.791 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:51.926 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:19:51.927 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:19:59.752 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:19:59.753 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-6.log
# 2025-05-09 19:19:59.757 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-6.log
# 2025-05-09 19:19:59.759 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.018848419189453 GB
# 2025-05-09 19:19:59.759 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 48236
# 2025-05-09 19:19:59.760 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:19:59.761 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205638885498047 GB
# 2025-05-09 19:19:59.762 | INFO     | __main__:experiment:18 - Iteration 8/10
# 2025-05-09 19:20:00.165 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:00.288 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:00.289 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:20:08.139 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:20:08.140 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-7.log
# 2025-05-09 19:20:08.142 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-7.log
# 2025-05-09 19:20:08.145 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.050407409667969 GB
# 2025-05-09 19:20:08.146 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47795
# 2025-05-09 19:20:08.146 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:20:08.148 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205665588378906 GB
# 2025-05-09 19:20:08.149 | INFO     | __main__:experiment:18 - Iteration 9/10
# 2025-05-09 19:20:08.660 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:08.781 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:08.782 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:20:16.416 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:20:16.418 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-8.log
# 2025-05-09 19:20:16.421 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-8.log
# 2025-05-09 19:20:16.423 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.040378570556641 GB
# 2025-05-09 19:20:16.423 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47564
# 2025-05-09 19:20:16.424 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:20:16.425 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.206478118896484 GB
# 2025-05-09 19:20:16.426 | INFO     | __main__:experiment:18 - Iteration 10/10
# 2025-05-09 19:20:16.811 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:16.935 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:20:16.935 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:20:25.613 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:20:25.615 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-psutil-9.log
# 2025-05-09 19:20:25.618 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-psutil-9.log
# 2025-05-09 19:20:25.623 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.052558898925781 GB
# 2025-05-09 19:20:25.624 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47652
# 2025-05-09 19:20:25.624 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:20:25.626 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.1919708251953125 GB

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


def plot_variability(peaks: list[float], metric: str, unit: str = "", suffix: str = ""):
    unit = unit.strip() if unit else ""
    metric_with_unit = f"{metric}{f' ({unit})' if unit != '' else ''}"
    snake_cased_metric = metric.lower().replace(" ", "_")

    mean_peak = np.mean(peaks)
    std_dev_peak = np.std(peaks)
    median_peak = np.median(peaks)
    min_peak = np.min(peaks)
    max_peak = np.max(peaks)
    coefficient_of_variation = (std_dev_peak / mean_peak) * 100

    # Create a figure to visualize peak memory usage and its variability
    fig, ax = plt.subplots(figsize=(10, 5))

    # Plot peak memory usage
    ax.plot(peaks, marker='s', linestyle='-', color='r', alpha=0.7, label=f"Peak {metric_with_unit}")

    # Plot mean and standard deviation bands
    ax.axhline(mean_peak, color='b', linestyle='--', label=f'Mean: {mean_peak:.2f} {unit}')
    ax.fill_between(range(len(peaks)), mean_peak - std_dev_peak, mean_peak + std_dev_peak,
                    color='blue', alpha=0.2, label=f'Standard Deviation: ±{std_dev_peak:.2f} {unit}')

    # Annotate min and max values
    ax.scatter(np.argmin(peaks), min_peak, color='green', label=f'Min: {min_peak:.2f} {unit}', zorder=3)
    ax.scatter(np.argmax(peaks), max_peak, color='purple', label=f'Max: {max_peak:.2f} {unit}', zorder=3)

    # Labels and title
    ax.set_xlabel("Run Number")
    ax.set_ylabel(metric_with_unit)
    ax.set_title(f"Peak {metric} Across Runs with Variability")
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.plot([], [], ' ', label=f'Coefficient of Variation (CV): {coefficient_of_variation:.2f}%')
    ax.legend()
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/peak_{snake_cased_metric}_{suffix}.pdf")
    plt.show()

    # Histogram to visualize distribution
    plt.figure(figsize=(8, 4))
    sns.histplot(peaks, bins=10, kde=True, color='r', alpha=0.7)
    plt.axvline(mean_peak, color='b', linestyle='--', label=f'Mean: {mean_peak:.2f} {unit}')
    plt.axvline(median_peak, color='g', linestyle='--', label=f'Median: {median_peak:.2f} {unit}')
    plt.xlabel(f"Peak {metric_with_unit}")
    plt.ylabel("Frequency")
    plt.title(f"Distribution of Peak {metric}")
    plt.legend()
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/distribution_{snake_cased_metric}_{suffix}.pdf")
    plt.show()


def plot_experiment(experiment_history, traceq_profiler: str):
    docker_monitor_mu_history = experiment_history['docker_monitor_mu_history']
    traceq_history = experiment_history['traceq_history']
    convert = mu_conversion_handlers_by_unit[traceq_history[0]["metadata"][f"{traceq_profiler}_memory_usage_unit"]]

    peak_docker_monitor_mu = experiment_history['peak_docker_monitor_mu_history']
    peak_traceq_mu = experiment_history['peak_traceq_mu_history']
    docker_monitor_pf_history = experiment_history['docker_monitor_pf_history']
    peak_major_pf = experiment_history['peak_docker_monitor_major_pf_history']
    peak_minor_pf = experiment_history['peak_docker_monitor_minor_pf_history']

    # Memory Usage Over Time
    for i, (traceq_history_df, docker_monitor_mu_df) in enumerate(zip(traceq_history, docker_monitor_mu_history)):
        memory_traceq = [tools.conversions.kb_to_gb(entry) for entry in docker_monitor_mu_df['memory_usage_kb']]
        memory_docker = [convert(entry[f"{traceq_profiler}_memory_usage"]) for entry in traceq_history_df["data"]]

        plt.plot(memory_traceq, label=f"{traceq_profiler} Run {i + 1}", linestyle="-")
        plt.plot(memory_docker, label=f"Docker cgroup Run {i + 1}", linestyle="dashed")

    os.makedirs(f"../{RELATIVE_OUT_DIR}/charts", exist_ok=True)

    plt.xlabel("Time")
    plt.ylabel(f"Memory Usage (GB)")
    plt.title(f"Memory Usage Over Time ({traceq_profiler} vs. Docker cgroup)")
    plt.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/memory_usage_over_time_vs_cgroup_{traceq_profiler}.pdf")

    # Peak Memory Usage Comparison (Bar Chart)
    labels = [f"Run {i + 1}" for i in range(len(peak_docker_monitor_mu))]
    x = np.arange(len(labels))
    width = 0.35

    fig, ax = plt.subplots(figsize=(12, 6))
    ax.bar(x - width / 2, peak_docker_monitor_mu, width, label="Docker Monitor (cgroup)")
    ax.bar(x + width / 2, peak_traceq_mu, width, label=traceq_profiler)

    ax.set_xlabel("Experiment Run")
    ax.set_ylabel("Peak Memory Usage (GB)")
    ax.set_title("Peak Memory Usage Comparison")
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45)
    ax.legend()
    ax.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/peak_memory_usage_comparison_{traceq_profiler}.pdf")

    # Memory Profiling vs. Docker Monitor (Line Plot)
    plt.figure(figsize=(12, 6))
    plt.plot(peak_docker_monitor_mu, label="Docker Monitor (cgroup)", marker="o")
    plt.plot(peak_traceq_mu, label=traceq_profiler, marker="s")
    plt.xlabel("Experiment Run")
    plt.ylabel("Peak Memory Usage (GB)")
    plt.title(f"Comparison of {traceq_profiler} vs. Docker cgroup Memory Profiling")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/comparisson_of_vs_cgroup_profiler_{traceq_profiler}.pdf")

    # Major & Minor Page Faults Over Time
    plt.figure(figsize=(12, 6))
    for i, df in enumerate(docker_monitor_pf_history):
        plt.plot(df["major_page_faults"], label=f"Major PF Run {i + 1}", linestyle="dashed")
        plt.plot(df["minor_page_faults"], label=f"Minor PF Run {i + 1}")

    plt.ylabel("Page Faults")
    plt.title("Major & Minor Page Faults Over Time")
    plt.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/minor_major_pfs_{traceq_profiler}.pdf")

    # Peak Major & Minor Page Faults (Bar Chart)
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.bar(x - width / 2, peak_major_pf, width, label="Peak Major Page Faults", color="red")
    ax.bar(x + width / 2, peak_minor_pf, width, label="Peak Minor Page Faults", color="blue")

    ax.set_xlabel("Experiment Run")
    ax.set_ylabel("Page Faults")
    ax.set_title("Peak Major & Minor Page Faults")
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=45)
    ax.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/peak_minor_major_pfs_{traceq_profiler}.pdf")

    # Correlation Between Profilers and Docker Monitor (Scatter Plot)
    plt.figure(figsize=(12, 6))
    plt.scatter(peak_docker_monitor_mu, peak_traceq_mu, alpha=0.7)
    plt.xlabel("Peak Memory Usage (Docker Monitor, GB)")
    plt.ylabel(f"Peak Memory Usage ({traceq_profiler}, GB)")
    plt.title("Correlation Between Docker Monitor and TraceQ Profiler")
    plt.grid(True)
    plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/correlation_with_docker_monitor_{traceq_profiler}.pdf")

    # TraceQ Memory Usage Variability
    plot_variability(peak_traceq_mu, f"Memory Usage {traceq_profiler}", "GB", suffix=traceq_profiler)

    # Docker Monitor Memory Usage Variability
    plot_variability(peak_docker_monitor_mu, "Memory Usage Docker (cgroup)", "GB",
                     suffix=f"{traceq_profiler}_docker_mponitor_memory_usage")

    # Minor Page Faults Variability
    plot_variability(peak_minor_pf, "Minor Page Faults", suffix=f"{traceq_profiler}_docker_monitor_minor_page_faults")

# %%
plot_experiment(psutil_experiment_history, "psutil")

# %% [markdown]
# Now, since we finished, let's cleanup the containers.

# %% [markdown]
# As we can see, the experiment is pretty stable.
# We have small standard deviations, and small CVs, specially when it comes to the profiler itself.
# Now, we'll run with another profiler, and check the results.

# %%
iterations = 10

resource_experiment_history = experiment(iterations, "resource")
# Out:
# 2025-05-09 19:26:43.388 | INFO     | __main__:experiment:18 - Iteration 1/10
# 2025-05-09 19:26:43.640 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:26:43.759 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:26:43.760 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:26:51.825 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:26:51.826 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-0.log
# 2025-05-09 19:26:51.827 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-0.log
# 2025-05-09 19:26:51.829 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.0198822021484375 GB
# 2025-05-09 19:26:51.829 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47143
# 2025-05-09 19:26:51.829 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:26:51.830 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205970764160156 GB
# 2025-05-09 19:26:51.831 | INFO     | __main__:experiment:18 - Iteration 2/10
# 2025-05-09 19:26:52.369 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:26:52.505 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:26:52.506 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:00.219 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:00.220 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-1.log
# 2025-05-09 19:27:00.222 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-1.log
# 2025-05-09 19:27:00.225 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.046955108642578 GB
# 2025-05-09 19:27:00.225 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47019
# 2025-05-09 19:27:00.226 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:00.227 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205966949462891 GB
# 2025-05-09 19:27:00.228 | INFO     | __main__:experiment:18 - Iteration 3/10
# 2025-05-09 19:27:00.717 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:00.850 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:00.851 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:09.158 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:09.159 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-2.log
# 2025-05-09 19:27:09.161 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-2.log
# 2025-05-09 19:27:09.163 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.042144775390625 GB
# 2025-05-09 19:27:09.164 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47214
# 2025-05-09 19:27:09.164 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:09.166 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205955505371094 GB
# 2025-05-09 19:27:09.167 | INFO     | __main__:experiment:18 - Iteration 4/10
# 2025-05-09 19:27:09.596 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:09.725 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:09.726 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:17.534 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:17.535 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-3.log
# 2025-05-09 19:27:17.537 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-3.log
# 2025-05-09 19:27:17.539 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.028537750244141 GB
# 2025-05-09 19:27:17.540 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47607
# 2025-05-09 19:27:17.540 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:17.542 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.2059326171875 GB
# 2025-05-09 19:27:17.542 | INFO     | __main__:experiment:18 - Iteration 5/10
# 2025-05-09 19:27:17.941 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:18.065 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:18.066 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:25.721 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:25.722 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-4.log
# 2025-05-09 19:27:25.725 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-4.log
# 2025-05-09 19:27:25.727 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.042461395263672 GB
# 2025-05-09 19:27:25.727 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47429
# 2025-05-09 19:27:25.728 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:25.729 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205970764160156 GB
# 2025-05-09 19:27:25.730 | INFO     | __main__:experiment:18 - Iteration 6/10
# 2025-05-09 19:27:26.162 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:26.284 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:26.285 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:34.246 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:34.247 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-5.log
# 2025-05-09 19:27:34.249 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-5.log
# 2025-05-09 19:27:34.251 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.036106109619141 GB
# 2025-05-09 19:27:34.252 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47211
# 2025-05-09 19:27:34.252 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:34.254 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.2059326171875 GB
# 2025-05-09 19:27:34.254 | INFO     | __main__:experiment:18 - Iteration 7/10
# 2025-05-09 19:27:34.731 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:34.860 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:34.861 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:42.687 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:42.688 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-6.log
# 2025-05-09 19:27:42.689 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-6.log
# 2025-05-09 19:27:42.690 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.047710418701172 GB
# 2025-05-09 19:27:42.690 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47240
# 2025-05-09 19:27:42.691 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:42.692 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205921173095703 GB
# 2025-05-09 19:27:42.692 | INFO     | __main__:experiment:18 - Iteration 8/10
# 2025-05-09 19:27:43.205 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:43.331 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:43.332 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:51.391 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:51.391 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-7.log
# 2025-05-09 19:27:51.393 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-7.log
# 2025-05-09 19:27:51.394 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.049510955810547 GB
# 2025-05-09 19:27:51.394 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47215
# 2025-05-09 19:27:51.394 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:51.395 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205921173095703 GB
# 2025-05-09 19:27:51.395 | INFO     | __main__:experiment:18 - Iteration 9/10
# 2025-05-09 19:27:51.840 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:51.964 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:27:51.965 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:27:59.647 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:27:59.648 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-8.log
# 2025-05-09 19:27:59.650 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-8.log
# 2025-05-09 19:27:59.653 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.030403137207031 GB
# 2025-05-09 19:27:59.654 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47379
# 2025-05-09 19:27:59.654 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:27:59.656 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.2059173583984375 GB
# 2025-05-09 19:27:59.656 | INFO     | __main__:experiment:18 - Iteration 10/10
# 2025-05-09 19:28:00.052 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:28:00.173 | INFO     | tools.docker:drop_caches_in_container:131 - Dropped caches inside docker:dind container
# 2025-05-09 19:28:00.174 | INFO     | tools.docker:run_isolated_container:97 - Launching in isolated container...
# 2025-05-09 19:28:07.679 | INFO     | tools.docker:run_isolated_container:111 - Finished running in isolated container
# 2025-05-09 19:28:07.681 | INFO     | tools.monitor:memory_usage_log_to_df:12 - Reading memory usage log) file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/memory-usage--experiment-resource-9.log
# 2025-05-09 19:28:07.684 | INFO     | tools.monitor:page_faults_log_to_df:32 - Reading page faults log file: ../out/notebooks/03-memory-profiling-20250509185706/docker-monitor/page-faults-log-resource-9.log
# 2025-05-09 19:28:07.687 | INFO     | __main__:experiment:70 - Peak memory usage from Docker monitor: 6.0093994140625 GB
# 2025-05-09 19:28:07.687 | INFO     | __main__:experiment:71 - Peak minor page faults from Docker monitor: 47681
# 2025-05-09 19:28:07.688 | INFO     | __main__:experiment:72 - Peak major page faults from Docker monitor: 0
# 2025-05-09 19:28:07.690 | INFO     | __main__:experiment:88 - Peak memory usage from TraceQ: 5.205928802490234 GB

# %%
plot_experiment(resource_experiment_history, "resource")

# %% [markdown]
# Now, the final step is to compare both profiles.

# %%
psutil_convert = mu_conversion_handlers_by_unit[
    psutil_experiment_history['traceq_history'][0]["metadata"]["psutil_memory_usage_unit"]]
resource_convert = mu_conversion_handlers_by_unit[
    resource_experiment_history['traceq_history'][0]["metadata"]["resource_memory_usage_unit"]]


def percentile_moving_average(data, percentile=90, window_size=5):
    return [
        np.percentile(data[max(0, i - window_size):i + 1], percentile)
        for i in range(len(data))
    ]


# Step 1: Determine the longest run (to standardize time steps)
max_psutil_time_steps = max(len(entry['data']) for entry in psutil_experiment_history['traceq_history'])
max_resource_time_steps = max(len(entry['data']) for entry in resource_experiment_history['traceq_history'])

# Step 2: Aggregate per time index across runs
psutil_time_aligned = [[] for _ in range(max_psutil_time_steps)]
resource_time_aligned = [[] for _ in range(max_resource_time_steps)]

for entry in psutil_experiment_history['traceq_history']:
    for i, value in enumerate(entry['data']):
        psutil_time_aligned[i].append(psutil_convert(value['psutil_memory_usage']))

for entry in resource_experiment_history['traceq_history']:
    for i, value in enumerate(entry['data']):
        resource_time_aligned[i].append(resource_convert(value["resource_memory_usage"]))

# Step 3: Compute the per-time-point aggregation (90th percentile & variance)
psutil_aggregated = [
    np.percentile(timestep_values, 90) if len(timestep_values) > 1 else np.nan
    for timestep_values in psutil_time_aligned
]
resource_aggregated = [
    np.percentile(timestep_values, 90) if len(timestep_values) > 1 else np.nan
    for timestep_values in resource_time_aligned
]

psutil_variance = [
    np.var(timestep_values) if len(timestep_values) > 1 else np.nan
    for timestep_values in psutil_time_aligned
]
resource_variance = [
    np.var(timestep_values) if len(timestep_values) > 1 else np.nan
    for timestep_values in resource_time_aligned
]

# Remove NaNs (only keep meaningful values)
psutil_valid_indices = ~np.isnan(psutil_aggregated)
resource_valid_indices = ~np.isnan(resource_aggregated)
psutil_aggregated = np.array(psutil_aggregated)[psutil_valid_indices]
resource_aggregated = np.array(resource_aggregated)[resource_valid_indices]
psutil_variance = np.array(psutil_variance)[psutil_valid_indices]
resource_variance = np.array(resource_variance)[resource_valid_indices]

# Step 4: Apply moving average
psutil_p90_ma = percentile_moving_average(psutil_aggregated, percentile=90)
resource_p90_ma = percentile_moving_average(resource_aggregated, percentile=90)

# Plot: Percentile Moving Average with Variance Shading
plt.figure(figsize=(10, 5))
plt.plot(psutil_p90_ma, label="psutil (90th percentile MA)", color='blue', alpha=0.7)
plt.plot(resource_p90_ma, label="resource (90th percentile MA)", color='orange', alpha=0.7)

# Adding variance shading (± standard deviation)
plt.fill_between(range(len(psutil_p90_ma)),
                 np.array(psutil_p90_ma) - np.sqrt(psutil_variance[:len(psutil_p90_ma)]),
                 np.array(psutil_p90_ma) + np.sqrt(psutil_variance[:len(psutil_p90_ma)]),
                 color='blue', alpha=0.2)

plt.fill_between(range(len(resource_p90_ma)),
                 np.array(resource_p90_ma) - np.sqrt(resource_variance[:len(resource_p90_ma)]),
                 np.array(resource_p90_ma) + np.sqrt(resource_variance[:len(resource_p90_ma)]),
                 color='orange', alpha=0.2)

plt.xlabel("Time")
plt.ylabel("Memory Usage (GB)")
plt.title("Memory Usage Over Time (Peak-Preserving View with Variance)")
plt.legend()
plt.grid(True)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/memory_usage_over_time.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(psutil_experiment_history['peak_traceq_mu_history'], kde=True, color='blue', label="psutil", alpha=0.6,
             bins=3)
sns.histplot(resource_experiment_history['peak_traceq_mu_history'], kde=True, color='orange', label="resource",
             alpha=0.6, bins=3)
plt.axvline(np.mean(psutil_experiment_history['peak_traceq_mu_history']), color='blue', linestyle='dashed',
            label="psutil mean")
plt.axvline(np.mean(psutil_experiment_history['peak_docker_monitor_mu_history']), color='cyan', linestyle='dashed',
            label="psutil cgroup mean")
plt.axvline(np.mean(resource_experiment_history['peak_traceq_mu_history']), color='orange', linestyle='dashed',
            label="resource mean")
plt.axvline(np.mean(resource_experiment_history['peak_docker_monitor_mu_history']), color='red', linestyle='dashed',
            label="resource cgroup mean")
plt.xlabel("Peak Memory Usage (GB)")
plt.ylabel("Density")
plt.title("Peak Memory Usage Distribution")
plt.legend()
plt.grid(True)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/peak_memory_usage_distribution.pdf")
plt.show()

# %%
psutil_minor_pfs = [entry['minor_page_faults'].tolist() for entry in
                    psutil_experiment_history['docker_monitor_pf_history']]
resource_minor_pfs = [entry['minor_page_faults'].tolist() for entry in
                      resource_experiment_history['docker_monitor_pf_history']]

# Step 1: Determine the longest run (to standardize time steps)
max_psutil_time_steps = max([len(history) for history in psutil_minor_pfs])
max_resource_time_steps = max([len(history) for history in resource_minor_pfs])

# Step 2: Aggregate per time index across runs
psutil_time_aligned = [[0 for _ in range(max_psutil_time_steps)] for _ in psutil_minor_pfs]
resource_time_aligned = [[0 for _ in range(max_resource_time_steps)] for _ in resource_minor_pfs]

for i, entry in enumerate(psutil_minor_pfs):
    for f, value in enumerate(entry):
        psutil_time_aligned[i][f] = value

for i, entry in enumerate(resource_minor_pfs):
    for f, value in enumerate(entry):
        resource_time_aligned[i][f] = value

# Step 3: Compute the per-time-point aggregation (90th percentile & variance)
psutil_aggregated = [
    np.percentile(timestep_values, 90) if len(timestep_values) > 1 else np.nan
    for timestep_values in psutil_time_aligned
]
resource_aggregated = [
    np.percentile(timestep_values, 90) if len(timestep_values) > 1 else np.nan
    for timestep_values in resource_time_aligned
]

psutil_variance = [
    np.var(timestep_values) if len(timestep_values) > 1 else np.nan
    for timestep_values in psutil_time_aligned
]
resource_variance = [
    np.var(timestep_values) if len(timestep_values) > 1 else np.nan
    for timestep_values in resource_time_aligned
]

# Remove NaNs (only keep meaningful values)
valid_indices = ~np.isnan(psutil_aggregated) & ~np.isnan(resource_aggregated)
psutil_aggregated = np.array(psutil_aggregated)[valid_indices]
resource_aggregated = np.array(resource_aggregated)[valid_indices]
psutil_variance = np.array(psutil_variance)[valid_indices]
resource_variance = np.array(resource_variance)[valid_indices]

# Step 4: Apply moving average
psutil_p90_ma = percentile_moving_average(psutil_aggregated, percentile=90)
resource_p90_ma = percentile_moving_average(resource_aggregated, percentile=90)

# Plot: Percentile Moving Average with Variance Shading
plt.figure(figsize=(10, 5))
plt.plot(psutil_p90_ma, label="psutil (90th percentile MA)", color='blue', alpha=0.7)
plt.plot(resource_p90_ma, label="resource (90th percentile MA)", color='orange', alpha=0.7)

# Adding variance shading (± standard deviation)
plt.fill_between(range(len(psutil_p90_ma)),
                 np.array(psutil_p90_ma) - np.sqrt(psutil_variance[:len(psutil_p90_ma)]),
                 np.array(psutil_p90_ma) + np.sqrt(psutil_variance[:len(psutil_p90_ma)]),
                 color='blue', alpha=0.2)

plt.fill_between(range(len(resource_p90_ma)),
                 np.array(resource_p90_ma) - np.sqrt(resource_variance[:len(resource_p90_ma)]),
                 np.array(resource_p90_ma) + np.sqrt(resource_variance[:len(resource_p90_ma)]),
                 color='orange', alpha=0.2)

plt.xlabel("Time")
plt.ylabel("Minor Page Faults")
plt.title(" (Peak-Preserving View with Variance)")
plt.legend()
plt.grid(True)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/peak_preserving_view_with_variance.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(psutil_experiment_history['peak_traceq_mu_history'],
            psutil_experiment_history['peak_docker_monitor_minor_pf_history'], color='blue', alpha=0.6,
            label="psutil minor faults")
plt.scatter(resource_experiment_history['peak_traceq_mu_history'],
            resource_experiment_history['peak_docker_monitor_minor_pf_history'], color='orange', alpha=0.6,
            label="resource minor faults")
plt.xlabel("Memory Usage (GB)")
plt.ylabel("Minor Page Faults")
plt.yscale("log")
plt.title("Minor Page Faults vs. Memory Usage")
plt.legend()
plt.grid(True)
plt.savefig(f"../{RELATIVE_OUT_DIR}/charts/minor_pf_vs_memory_usage.pdf")
plt.show()

# %%
vfs_container.stop()

# %% [markdown]
# ## Summary of Findings
#
# ### Overview
# During our analysis, we observed significant differences in behavior between the memory profilers (`psutil`, `resource`, and `cgroup`).
# Each profiler reported memory usage differently, indicating that their methodologies and measurement techniques impact the results. Below are the key findings from our investigation.
#
# ### Differences in Memory Profiler Behavior
# One of the most striking findings was the difference in reported memory usage between `psutil` and `resource`.
# The `resource` profiler demonstrated remarkable stability, consistently reporting nearly identical memory usage values across runs, regardless of workload variations.
# In contrast, `psutil` showed noticeable fluctuations, reflecting dynamic memory allocation and potential transient memory spikes.
#
# #### `psutil`
# - Captured transient memory fluctuations more accurately.
# - Displayed notable variance across runs, indicating it reacts to temporary memory usage patterns.
# - Showed a more **real-time process memory consumption**, including allocations and deallocations.
#
# #### `resource`
# - Reported **stable and consistent** memory usage across runs.
# - Less responsive to transient allocations and deallocations, suggesting it might be capturing a more averaged-out or static snapshot.
# - Likely includes only resident memory, ignoring temporary allocations.
# - Captured only the peak memory usage so far (ignoring current memory usage on each point).
#
# ### Docker cgroup Memory Allocation
# In our comparative analysis, we included Docker's cgroup-based memory tracking.
# A key finding was that Docker consistently allocated **more memory** than the amount measured by both profilers (`psutil` and `resource`).
# This discrepancy highlights a common challenge when monitoring memory usage within containerized environments:
#
# - **cgroup Memory Usage > Reported Memory Usage**:
#   - Docker reserves additional memory overhead beyond what the process actively uses.
#   - This may be due to reserved buffers, memory fragmentation, or kernel-managed caches.
#   - Ensuring adequate memory limits for containers requires considering this discrepancy.
#
# ### Technical Summary of Key Charts
#
# #### Peak Memory Usage Distribution
# - **Finding:** The peak memory usage reported by `resource` remained stable across runs, while `psutil` showed variability.
# - **Insight:** Indicates that `resource` captures a **more static view of memory**, whereas `psutil` is more **sensitive to dynamic allocations**.
#
# ### Minor vs. Major Page Faults Over Time
#
# - **Finding:** Page faults were measured using kernel `/proc` data, yet `resource` reported more page faults and higher variability than expected.
# = **Insight:** This discrepancy suggests `resource` may be interpreting memory accesses differently, or it could be including additional system-level memory behaviors not captured by `psutil`.
#
# ### psutil vs. resource vs. cgroup Memory Usage Over Time
# - **Finding:** cgroup consistently tracked higher memory usage than either profiler.
# - **Insight:** Docker’s memory allocation strategy includes additional overhead.
#
# ### Correlating Page Faults with Memory Usage
# - **Finding:** No clear correlation between page faults and memory usage was identified.
# - **Insight:** This suggests that page faults are not necessarily driven by increased memory consumption, but could instead be influenced by other system-level behaviors, memory access patterns, or kernel memory management policies.
#
# ## Conclusion
# - **Profiler Selection Matters:** Different memory profilers serve different purposes. `psutil` is more dynamic, while `resource` provides a stable baseline.
# - **Docker Overhead Must Be Considered:** cgroup reports higher memory consumption than `psutil` or `resource`, likely due to container overhead.
# - **Memory Tracking Strategy Depends on Use Case:** If detecting transient memory spikes is important, `psutil` is better. If aiming for a stable estimate, `resource` is preferable.
#
# Further optimizations and profiling techniques can help refine memory tracking strategies, especially in containerized environments.
